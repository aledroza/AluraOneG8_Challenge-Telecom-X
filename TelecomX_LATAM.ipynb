# %% [markdown]
# <a href="https://colab.research.google.com/github/aledroza/AluraOneG8_Challenge-Telecom-X/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# %%
url='https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json'
df_telecom_X=pd.read_json(url)
df_telecom_X
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 0     {'Contract': 'One year', 'PaperlessBilling': '...
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...
# ...                                                 ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...
#
# [7267 rows x 6 columns]

# %%
df_telecom_X.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %%
df_telecom_X.tail()
# Out:
#       customerID Churn                                           customer  \
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...

# %%
df_telecom_X.head(10)
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 5  0013-MHZWF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6  0013-SMEOE    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 7  0014-BMAQU    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 8  0015-UOCOJ    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 9  0016-QLJIS    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 5   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 6   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 8   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 9  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 5  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 6  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 8  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 9  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 5  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 6  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7  {'Contract': 'Two year', 'PaperlessBilling': '...
# 8  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 9  {'Contract': 'Two year', 'PaperlessBilling': '...

# %%
df_telecom_X.sample(10)
# Out:
#       customerID Churn                                           customer  \
# 4148  5687-DKDTV   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4249  5844-QVTAT    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7062  9724-BFUOP        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 3137  4373-MAVJG   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 559   0795-XCCTE    No  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 94    0148-DCDOS   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7070  9734-YWGEX   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4394  6017-PPLPX   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 5129  7005-CYUIL    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 5515  7560-QRBXH    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                 phone  \
# 4148   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4249   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7062  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 3137  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 559   {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 94    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7070  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 4394   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 5129   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 5515   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                                internet  \
# 4148  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 4249  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7062  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3137  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 559   {'InternetService': 'No', 'OnlineSecurity': 'N...
# 94    {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7070  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4394  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 5129  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 5515  {'InternetService': 'No', 'OnlineSecurity': 'N...
#
#                                                 account
# 4148  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4249  {'Contract': 'One year', 'PaperlessBilling': '...
# 7062  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3137  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 559   {'Contract': 'Two year', 'PaperlessBilling': '...
# 94    {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7070  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4394  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 5129  {'Contract': 'Two year', 'PaperlessBilling': '...
# 5515  {'Contract': 'One year', 'PaperlessBilling': '...

# %%
type(df_telecom_X)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Normalizando los dicionarios en Json

# %%
df_normalized_customer = pd.json_normalize(df_telecom_X['customer'])
df_normalized_customer
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
df_normalized_phone = pd.json_normalize(df_telecom_X['phone'])
df_normalized_phone
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
df_normalized_internet = pd.json_normalize(df_telecom_X['internet'])
df_normalized_internet
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# 0            Yes              No
# 1             No             Yes
# 2             No              No
# 3            Yes             Yes
# 4            Yes              No
# ...          ...             ...
# 7262          No              No
# 7263          No             Yes
# 7264          No              No
# 7265          No             Yes
# 7266         Yes             Yes
#
# [7267 rows x 7 columns]

# %%
df_normalized_account = pd.json_normalize(df_telecom_X['account'])
df_normalized_account
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# 3          1237.85
# 4            267.4
# ...            ...
# 7262         742.9
# 7263        1873.7
# 7264         92.75
# 7265       4627.65
# 7266        3707.6
#
# [7267 rows x 5 columns]

# %% [markdown]
# #### ESCRIBIENDO JSON NORMALIZADO

# %%
df_normalized_customer.to_json('telecom_X_customer_normalizado.json')
df_normalized_phone.to_json('telecom_X_phone_normalizado.json')
df_normalized_internet.to_json('telecom_X_internet_normalizado.json')
df_normalized_account.to_json('telecom_X_account_normalizado.json')

# %%
pd.read_json('telecom_X_customer_normalizado.json')
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
pd.read_json('telecom_X_phone_normalizado.json')
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
pd.read_json('telecom_X_internet_normalizado.json')
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# 0            Yes              No
# 1             No             Yes
# 2             No              No
# 3            Yes             Yes
# 4            Yes              No
# ...          ...             ...
# 7262          No              No
# 7263          No             Yes
# 7264          No              No
# 7265          No             Yes
# 7266         Yes             Yes
#
# [7267 rows x 7 columns]

# %%
pd.read_json('telecom_X_account_normalizado.json')
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# 3          1237.85
# 4            267.4
# ...            ...
# 7262         742.9
# 7263        1873.7
# 7264         92.75
# 7265       4627.65
# 7266        3707.6
#
# [7267 rows x 5 columns]

# %%
df_telecom_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# ###**Conociendo los Datos**

# %% [markdown]
# ####**Tipo Dataframe**

# %%
df_telecom_X.dtypes
# Out:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %%
df_normalized_customer.dtypes
# Out:
# gender           object
# SeniorCitizen     int64
# Partner          object
# Dependents       object
# tenure            int64
# dtype: object

# %%
df_normalized_phone.dtypes
# Out:
# PhoneService     object
# MultipleLines    object
# dtype: object

# %%
df_normalized_internet.dtypes
# Out:
# InternetService     object
# OnlineSecurity      object
# OnlineBackup        object
# DeviceProtection    object
# TechSupport         object
# StreamingTV         object
# StreamingMovies     object
# dtype: object

# %%
df_normalized_account.dtypes
# Out:
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Charges.Monthly     float64
# Charges.Total        object
# dtype: object

# %% [markdown]
# ####**Info de los dataframe**

# %%
df_telecom_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
df_normalized_account.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contract          7267 non-null   object
#  1   PaperlessBilling  7267 non-null   object
#  2   PaymentMethod     7267 non-null   object
#  3   Charges.Monthly   7267 non-null   float64
#  4   Charges.Total     7267 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 284.0+ KB

# %%
df_normalized_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   object
#  3   Dependents     7267 non-null   object
#  4   tenure         7267 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 284.0+ KB

# %%
df_normalized_internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   InternetService   7267 non-null   object
#  1   OnlineSecurity    7267 non-null   object
#  2   OnlineBackup      7267 non-null   object
#  3   DeviceProtection  7267 non-null   object
#  4   TechSupport       7267 non-null   object
#  5   StreamingTV       7267 non-null   object
#  6   StreamingMovies   7267 non-null   object
# dtypes: object(7)
# memory usage: 397.5+ KB

# %%
df_normalized_phone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PhoneService   7267 non-null   object
#  1   MultipleLines  7267 non-null   object
# dtypes: object(2)
# memory usage: 113.7+ KB

# %%
df_telecom_X.describe()
# Out:
#         customerID Churn                                           customer  \
# count         7267  7267                                               7267
# unique        7267     3                                                891
# top     9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# freq             1  5174                                                223
#
#                                                  phone  \
# count                                             7267
# unique                                               3
# top     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# freq                                              3495
#
#                                                  internet  \
# count                                                7267
# unique                                                129
# top     {'InternetService': 'No', 'OnlineSecurity': 'N...
# freq                                                 1581
#
#                                                   account
# count                                                7267
# unique                                               6931
# top     {'Contract': 'Month-to-month', 'PaperlessBilli...
# freq                                                    6

# %% [markdown]
# ####**Filas y columnas en los dataframe**

# %%
df_telecom_X.shape
# Out:
# (7267, 6)

# %%
df_normalized_customer.shape
# Out:
# (7267, 5)

# %%
df_normalized_phone.shape
# Out:
# (7267, 2)

# %%
df_normalized_internet.shape
# Out:
# (7267, 7)

# %%
df_normalized_account.shape
# Out:
# (7267, 5)

# %% [markdown]
# ####**cuales son las columnas en los dataframe**
#
#
# ---

# %%
df1= df_telecom_X.columns
df1
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
df2=df_normalized_customer.columns
df2
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure'], dtype='object')

# %%
df3= df_normalized_phone.columns
df3
# Out:
# Index(['PhoneService', 'MultipleLines'], dtype='object')

# %%
df4= df_normalized_internet.columns
df4
# Out:
# Index(['InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies'],
#       dtype='object')

# %%
df5= df_normalized_account.columns
df5
# Out:
# Index(['Contract', 'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ####**Que hay en cada columna**

# %%
df_telecom_X['customerID']
# Out:
# 0       0002-ORFBO
# 1       0003-MKNFE
# 2       0004-TLHLJ
# 3       0011-IGKFF
# 4       0013-EXCHZ
#            ...
# 7262    9987-LUTYD
# 7263    9992-RRAMN
# 7264    9992-UJOEL
# 7265    9993-LHIEB
# 7266    9995-HOTOH
# Name: customerID, Length: 7267, dtype: object

# %%
df_telecom_X['Churn']
# Out:
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7262     No
# 7263    Yes
# 7264     No
# 7265     No
# 7266     No
# Name: Churn, Length: 7267, dtype: object

# %%
df_telecom_X['customer']
# Out:
# 0       {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1       {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2       {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3       {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4       {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#                               ...
# 7262    {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# Name: customer, Length: 7267, dtype: object

# %%
df_telecom_X['phone']
# Out:
# 0          {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1         {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2          {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3          {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4          {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#                               ...
# 7262       {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263      {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264       {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265       {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266    {'PhoneService': 'No', 'MultipleLines': 'No ph...
# Name: phone, Length: 7267, dtype: object

# %%
df_telecom_X['internet']
# Out:
# 0       {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1       {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2       {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3       {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4       {'InternetService': 'Fiber optic', 'OnlineSecu...
#                               ...
# 7262    {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263    {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264    {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265    {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266    {'InternetService': 'DSL', 'OnlineSecurity': '...
# Name: internet, Length: 7267, dtype: object

# %%
df_telecom_X['account']
# Out:
# 0       {'Contract': 'One year', 'PaperlessBilling': '...
# 1       {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2       {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3       {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4       {'Contract': 'Month-to-month', 'PaperlessBilli...
#                               ...
# 7262    {'Contract': 'One year', 'PaperlessBilling': '...
# 7263    {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264    {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265    {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266    {'Contract': 'Two year', 'PaperlessBilling': '...
# Name: account, Length: 7267, dtype: object

# %%
df_telecom_X[['customerID','Churn']]
# Out:
#       customerID Churn
# 0     0002-ORFBO    No
# 1     0003-MKNFE    No
# 2     0004-TLHLJ   Yes
# 3     0011-IGKFF   Yes
# 4     0013-EXCHZ   Yes
# ...          ...   ...
# 7262  9987-LUTYD    No
# 7263  9992-RRAMN   Yes
# 7264  9992-UJOEL    No
# 7265  9993-LHIEB    No
# 7266  9995-HOTOH    No
#
# [7267 rows x 2 columns]

# %% [markdown]
# ####**Valores no Repetidos**

# %%
customerID_unique=df_telecom_X['customerID'].unique()
customerID_unique
# Out:
# array(['0002-ORFBO', '0003-MKNFE', '0004-TLHLJ', ..., '9992-UJOEL',
#        '9993-LHIEB', '9995-HOTOH'], dtype=object)

# %% [markdown]
# ####**Buscando Valores no Repetidos en la columna CustomerID, analizada**

# %%
df_telecom_X.query('@customerID_unique in customerID')
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 0     {'Contract': 'One year', 'PaperlessBilling': '...
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...
# ...                                                 ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...
#
# [7267 rows x 6 columns]

# %% [markdown]
# ####**Valores nulos**

# %%
df_telecom_X.isnull()
# Out:
#       customerID  Churn  customer  phone  internet  account
# 0          False  False     False  False     False    False
# 1          False  False     False  False     False    False
# 2          False  False     False  False     False    False
# 3          False  False     False  False     False    False
# 4          False  False     False  False     False    False
# ...          ...    ...       ...    ...       ...      ...
# 7262       False  False     False  False     False    False
# 7263       False  False     False  False     False    False
# 7264       False  False     False  False     False    False
# 7265       False  False     False  False     False    False
# 7266       False  False     False  False     False    False
#
# [7267 rows x 6 columns]

# %%
df_telecom_X.isnull().sum()
# Out:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64

# %%
df_normalized_customer.isnull().sum()
# Out:
# gender           0
# SeniorCitizen    0
# Partner          0
# Dependents       0
# tenure           0
# dtype: int64

# %%
df_normalized_account.isnull().sum()
# Out:
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# dtype: int64

# %%
df_normalized_internet.isnull().sum()
# Out:
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# dtype: int64

# %%
df_normalized_phone.isnull().sum()
# Out:
# PhoneService     0
# MultipleLines    0
# dtype: int64

# %%
df_normalized_internet.isnull().sum()
# Out:
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# dtype: int64

# %% [markdown]
# ####**Manejo de incosistencias, letra minuscula, rellenando espacios en blanco**

# %%
telecomx_coloumnslow= df_telecom_X.columns.str.lower()
telecomx_coloumnslow
# Out:
# Index(['customerid', 'churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
df_telecom_X.columns = df_telecom_X.columns.str.lower().str.replace(' ', '_')
df_telecom_X.columns
# Out:
# Index(['customerid', 'churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
df_telecom_X.columns
# Out:
# Index(['customerid', 'churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
df_telecom_X.head()
# Out:
#    customerid churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %% [markdown]
# ###**Añadiendo Columnas**

# %%
df_telecom_X['gender']= df_normalized_customer['gender']
df_telecom_X
# Out:
#       customerid churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account  gender
# 0     {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
# ...                                                 ...     ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
#
# [7267 rows x 7 columns]

# %%
df_telecom_X[['InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
       'TechSupport', 'StreamingTV', 'StreamingMovies']]= df_normalized_internet[['InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
       'TechSupport', 'StreamingTV', 'StreamingMovies']]
df_telecom_X
# Out:
#       customerid churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account  gender  \
# 0     {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
# ...                                                 ...     ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# 0            Yes              No
# 1             No             Yes
# 2             No              No
# 3            Yes             Yes
# 4            Yes              No
# ...          ...             ...
# 7262          No              No
# 7263          No             Yes
# 7264          No              No
# 7265          No             Yes
# 7266         Yes             Yes
#
# [7267 rows x 14 columns]

# %%
df_telecom_X['phone_service']= df_normalized_phone['PhoneService']
df_telecom_X
# Out:
#       customerid churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account  gender  \
# 0     {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
# ...                                                 ...     ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies phone_service
# 0            Yes              No           Yes
# 1             No             Yes           Yes
# 2             No              No           Yes
# 3            Yes             Yes           Yes
# 4            Yes              No           Yes
# ...          ...             ...           ...
# 7262          No              No           Yes
# 7263          No             Yes           Yes
# 7264          No              No           Yes
# 7265          No             Yes           Yes
# 7266         Yes             Yes            No
#
# [7267 rows x 15 columns]

# %%
df_telecom_X['contract']= df_normalized_account['Contract']
df_telecom_X
# Out:
#       customerid churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account  gender  \
# 0     {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
# ...                                                 ...     ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies phone_service        contract
# 0            Yes              No           Yes        One year
# 1             No             Yes           Yes  Month-to-month
# 2             No              No           Yes  Month-to-month
# 3            Yes             Yes           Yes  Month-to-month
# 4            Yes              No           Yes  Month-to-month
# ...          ...             ...           ...             ...
# 7262          No              No           Yes        One year
# 7263          No             Yes           Yes  Month-to-month
# 7264          No              No           Yes  Month-to-month
# 7265          No             Yes           Yes        Two year
# 7266         Yes             Yes            No        Two year
#
# [7267 rows x 16 columns]

# %%
df_telecom_X[['paperless_billing','PaymentMethod']]= df_normalized_account[['PaperlessBilling','PaymentMethod']]
df_telecom_X
# Out:
#       customerid churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account  gender  \
# 0     {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
# ...                                                 ...     ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies phone_service        contract  \
# 0            Yes              No           Yes        One year
# 1             No             Yes           Yes  Month-to-month
# 2             No              No           Yes  Month-to-month
# 3            Yes             Yes           Yes  Month-to-month
# 4            Yes              No           Yes  Month-to-month
# ...          ...             ...           ...             ...
# 7262          No              No           Yes        One year
# 7263          No             Yes           Yes  Month-to-month
# 7264          No              No           Yes  Month-to-month
# 7265          No             Yes           Yes        Two year
# 7266         Yes             Yes            No        Two year
#
#      paperless_billing     PaymentMethod
# 0                  Yes      Mailed check
# 1                   No      Mailed check
# 2                  Yes  Electronic check
# 3                  Yes  Electronic check
# 4                  Yes      Mailed check
# ...                ...               ...
# 7262                No      Mailed check
# 7263               Yes  Electronic check
# 7264               Yes      Mailed check
# 7265                No      Mailed check
# 7266                No  Electronic check
#
# [7267 rows x 18 columns]

# %%
df_telecom_X['charges.monthly']= df_normalized_account['Charges.Monthly']
df_telecom_X
# Out:
#       customerid churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account  gender  \
# 0     {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
# ...                                                 ...     ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies phone_service        contract  \
# 0            Yes              No           Yes        One year
# 1             No             Yes           Yes  Month-to-month
# 2             No              No           Yes  Month-to-month
# 3            Yes             Yes           Yes  Month-to-month
# 4            Yes              No           Yes  Month-to-month
# ...          ...             ...           ...             ...
# 7262          No              No           Yes        One year
# 7263          No             Yes           Yes  Month-to-month
# 7264          No              No           Yes  Month-to-month
# 7265          No             Yes           Yes        Two year
# 7266         Yes             Yes            No        Two year
#
#      paperless_billing     PaymentMethod  charges.monthly
# 0                  Yes      Mailed check            65.60
# 1                   No      Mailed check            59.90
# 2                  Yes  Electronic check            73.90
# 3                  Yes  Electronic check            98.00
# 4                  Yes      Mailed check            83.90
# ...                ...               ...              ...
# 7262                No      Mailed check            55.15
# 7263               Yes  Electronic check            85.10
# 7264               Yes      Mailed check            50.30
# 7265                No      Mailed check            67.85
# 7266                No  Electronic check            59.00
#
# [7267 rows x 19 columns]

# %%
df_telecom_X['charges.total']= df_normalized_account['Charges.Total']
df_telecom_X
# Out:
#       customerid churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account  gender  \
# 0     {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
# ...                                                 ...     ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies phone_service        contract  \
# 0            Yes              No           Yes        One year
# 1             No             Yes           Yes  Month-to-month
# 2             No              No           Yes  Month-to-month
# 3            Yes             Yes           Yes  Month-to-month
# 4            Yes              No           Yes  Month-to-month
# ...          ...             ...           ...             ...
# 7262          No              No           Yes        One year
# 7263          No             Yes           Yes  Month-to-month
# 7264          No              No           Yes  Month-to-month
# 7265          No             Yes           Yes        Two year
# 7266         Yes             Yes            No        Two year
#
#      paperless_billing     PaymentMethod  charges.monthly charges.total
# 0                  Yes      Mailed check            65.60         593.3
# 1                   No      Mailed check            59.90         542.4
# 2                  Yes  Electronic check            73.90        280.85
# 3                  Yes  Electronic check            98.00       1237.85
# 4                  Yes      Mailed check            83.90         267.4
# ...                ...               ...              ...           ...
# 7262                No      Mailed check            55.15         742.9
# 7263               Yes  Electronic check            85.10        1873.7
# 7264               Yes      Mailed check            50.30         92.75
# 7265                No      Mailed check            67.85       4627.65
# 7266                No  Electronic check            59.00        3707.6
#
# [7267 rows x 20 columns]

# %%
df_telecom_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customerid         7267 non-null   object
#  1   churn              7267 non-null   object
#  2   customer           7267 non-null   object
#  3   phone              7267 non-null   object
#  4   internet           7267 non-null   object
#  5   account            7267 non-null   object
#  6   gender             7267 non-null   object
#  7   InternetService    7267 non-null   object
#  8   OnlineSecurity     7267 non-null   object
#  9   OnlineBackup       7267 non-null   object
#  10  DeviceProtection   7267 non-null   object
#  11  TechSupport        7267 non-null   object
#  12  StreamingTV        7267 non-null   object
#  13  StreamingMovies    7267 non-null   object
#  14  phone_service      7267 non-null   object
#  15  contract           7267 non-null   object
#  16  paperless_billing  7267 non-null   object
#  17  PaymentMethod      7267 non-null   object
#  18  charges.monthly    7267 non-null   float64
#  19  charges.total      7267 non-null   object
# dtypes: float64(1), object(19)
# memory usage: 1.1+ MB

# %% [markdown]
# ####**Creando Columna Contract in Numbers**

# %%
df_telecom_X['Tiempo_de_Contrato']= df_normalized_account['Contract'].map({'Month-to-month':1, 'One year':12, 'Two year':24}).astype(np.int64)
df_telecom_X
# Out:
#       customerid churn                                           customer  \
# 4988  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7090  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 579   0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 434   0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7233  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# ...          ...   ...                                                ...
# 5998  8199-ZLLSA   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 4366  5989-AXPUC    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4182  5734-EJKXG    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6537  8984-HPEMB    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5523  7569-NMZYQ    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                 phone  \
# 4988   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7090   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 579    {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 434    {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7233   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                               ...
# 5998  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 4366  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 4182  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 6537  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 5523  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                                internet  \
# 4988  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 7090  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 579   {'InternetService': 'No', 'OnlineSecurity': 'N...
# 434   {'InternetService': 'No', 'OnlineSecurity': 'N...
# 7233  {'InternetService': 'No', 'OnlineSecurity': 'N...
# ...                                                 ...
# 5998  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4366  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4182  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 6537  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 5523  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                                 account  gender  \
# 4988  {'Contract': 'One year', 'PaperlessBilling': '...    Male
# 7090  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 579   {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 434   {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 7233  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# ...                                                 ...     ...
# 5998  {'Contract': 'One year', 'PaperlessBilling': '...    Male
# 4366  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 4182  {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 6537  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 5523  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
#
#      InternetService       OnlineSecurity         OnlineBackup  ...  \
# 4988              No  No internet service  No internet service  ...
# 7090              No  No internet service  No internet service  ...
# 579               No  No internet service  No internet service  ...
# 434               No  No internet service  No internet service  ...
# 7233              No  No internet service  No internet service  ...
# ...              ...                  ...                  ...  ...
# 5998     Fiber optic                  Yes                  Yes  ...
# 4366     Fiber optic                  Yes                  Yes  ...
# 4182     Fiber optic                  Yes                  Yes  ...
# 6537     Fiber optic                  Yes                  Yes  ...
# 5523     Fiber optic                  Yes                  Yes  ...
#
#           StreamingMovies phone_service  contract paperless_billing  \
# 4988  No internet service           Yes  One year                No
# 7090  No internet service           Yes  Two year                No
# 579   No internet service           Yes  Two year               Yes
# 434   No internet service           Yes  Two year                No
# 7233  No internet service           Yes  Two year               Yes
# ...                   ...           ...       ...               ...
# 5998                  Yes           Yes  One year               Yes
# 4366                  Yes           Yes  Two year                No
# 4182                  Yes           Yes  One year               Yes
# 6537                  Yes           Yes  Two year               Yes
# 5523                  Yes           Yes  Two year               Yes
#
#                   PaymentMethod charges.monthly charges.total  \
# 4988    Credit card (automatic)           18.25        534.70
# 7090  Bank transfer (automatic)           18.40       1057.85
# 579     Credit card (automatic)           18.55        689.00
# 434                Mailed check           18.70       1005.70
# 7233               Mailed check           18.70        383.65
# ...                         ...             ...           ...
# 5998  Bank transfer (automatic)          118.35       7804.15
# 4366               Mailed check          118.60       7990.05
# 4182           Electronic check          118.60       7365.70
# 6537           Electronic check          118.65       8477.60
# 5523  Bank transfer (automatic)          118.75       8672.45
#
#      contract_in_numbers  cuentas_diarias  Tiempo_de_Contrato
# 4988                  12         0.608333                  12
# 7090                  24         0.613333                  24
# 579                   24         0.618333                  24
# 434                   24         0.623333                  24
# 7233                  24         0.623333                  24
# ...                  ...              ...                 ...
# 5998                  12         3.945000                  12
# 4366                  24         3.953333                  24
# 4182                  12         3.953333                  12
# 6537                  24         3.955000                  24
# 5523                  24         3.958333                  24
#
# [7267 rows x 23 columns]

# %% [markdown]
# ####**Creando Columna cuentas Diarias**

# %%
df_telecom_X['cuentas_diarias']= df_normalized_account['Charges.Monthly']/30
df_telecom_X
# Out:
#       customerid churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account  gender  \
# 0     {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
# ...                                                 ...     ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
#
#      InternetService OnlineSecurity OnlineBackup  ... StreamingTV  \
# 0                DSL             No          Yes  ...         Yes
# 1                DSL             No           No  ...          No
# 2        Fiber optic             No           No  ...          No
# 3        Fiber optic             No          Yes  ...         Yes
# 4        Fiber optic             No           No  ...         Yes
# ...              ...            ...          ...  ...         ...
# 7262             DSL            Yes           No  ...          No
# 7263     Fiber optic             No           No  ...          No
# 7264             DSL             No          Yes  ...          No
# 7265             DSL            Yes           No  ...          No
# 7266             DSL            Yes          Yes  ...         Yes
#
#      StreamingMovies phone_service        contract paperless_billing  \
# 0                 No           Yes        One year               Yes
# 1                Yes           Yes  Month-to-month                No
# 2                 No           Yes  Month-to-month               Yes
# 3                Yes           Yes  Month-to-month               Yes
# 4                 No           Yes  Month-to-month               Yes
# ...              ...           ...             ...               ...
# 7262              No           Yes        One year                No
# 7263             Yes           Yes  Month-to-month               Yes
# 7264              No           Yes  Month-to-month               Yes
# 7265             Yes           Yes        Two year                No
# 7266             Yes            No        Two year                No
#
#          PaymentMethod charges.monthly charges.total  contract_in_numbers  \
# 0         Mailed check           65.60         593.3                   12
# 1         Mailed check           59.90         542.4                    1
# 2     Electronic check           73.90        280.85                    1
# 3     Electronic check           98.00       1237.85                    1
# 4         Mailed check           83.90         267.4                    1
# ...                ...             ...           ...                  ...
# 7262      Mailed check           55.15         742.9                   12
# 7263  Electronic check           85.10        1873.7                    1
# 7264      Mailed check           50.30         92.75                    1
# 7265      Mailed check           67.85       4627.65                   24
# 7266  Electronic check           59.00        3707.6                   24
#
#      cuentas_diarias
# 0           2.186667
# 1           1.996667
# 2           2.463333
# 3           3.266667
# 4           2.796667
# ...              ...
# 7262        1.838333
# 7263        2.836667
# 7264        1.676667
# 7265        2.261667
# 7266        1.966667
#
# [7267 rows x 22 columns]

# %% [markdown]
# ####**Total_a_Pagar/Contracto**

# %%
df_telecom_X['total_contracto']= df_telecom_X['charges.total']*df_telecom_X['Tiempo_de_Contrato']
df_telecom_X.head()
# Out:
#       customerid churn                                           customer  \
# 4988  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7090  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 579   0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 434   0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7233  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                phone  \
# 4988  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7090  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 579   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 434   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7233  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                                internet  \
# 4988  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 7090  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 579   {'InternetService': 'No', 'OnlineSecurity': 'N...
# 434   {'InternetService': 'No', 'OnlineSecurity': 'N...
# 7233  {'InternetService': 'No', 'OnlineSecurity': 'N...
#
#                                                 account  gender  \
# 4988  {'Contract': 'One year', 'PaperlessBilling': '...    Male
# 7090  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 579   {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 434   {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 7233  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
#
#      InternetService       OnlineSecurity         OnlineBackup  ...  \
# 4988              No  No internet service  No internet service  ...
# 7090              No  No internet service  No internet service  ...
# 579               No  No internet service  No internet service  ...
# 434               No  No internet service  No internet service  ...
# 7233              No  No internet service  No internet service  ...
#
#           StreamingMovies phone_service  contract paperless_billing  \
# 4988  No internet service           Yes  One year                No
# 7090  No internet service           Yes  Two year                No
# 579   No internet service           Yes  Two year               Yes
# 434   No internet service           Yes  Two year                No
# 7233  No internet service           Yes  Two year               Yes
#
#                   PaymentMethod charges.monthly charges.total cuentas_diarias  \
# 4988    Credit card (automatic)           18.25        534.70        0.608333
# 7090  Bank transfer (automatic)           18.40       1057.85        0.613333
# 579     Credit card (automatic)           18.55        689.00        0.618333
# 434                Mailed check           18.70       1005.70        0.623333
# 7233               Mailed check           18.70        383.65        0.623333
#
#       Tiempo_de_Contrato  total_contracto
# 4988                  12           6416.4
# 7090                  24          25388.4
# 579                   24          16536.0
# 434                   24          24136.8
# 7233                  24           9207.6
#
# [5 rows x 23 columns]

# %%
df_telecom_X.drop(columns=['contract_in_numbers'], inplace=True)

# %%
df_telecom_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7267 entries, 4988 to 5523
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customerid          7267 non-null   object
#  1   churn               7267 non-null   object
#  2   customer            7267 non-null   object
#  3   phone               7267 non-null   object
#  4   internet            7267 non-null   object
#  5   account             7267 non-null   object
#  6   gender              7267 non-null   object
#  7   InternetService     7267 non-null   object
#  8   OnlineSecurity      7267 non-null   object
#  9   OnlineBackup        7267 non-null   object
#  10  DeviceProtection    7267 non-null   object
#  11  TechSupport         7267 non-null   object
#  12  StreamingTV         7267 non-null   object
#  13  StreamingMovies     7267 non-null   object
#  14  phone_service       7267 non-null   object
#  15  contract            7267 non-null   object
#  16  paperless_billing   7267 non-null   object
#  17  PaymentMethod       7267 non-null   object
#  18  charges.monthly     7267 non-null   float64
#  19  charges.total       7267 non-null   float64
#  20  cuentas_diarias     7267 non-null   float64
#  21  Tiempo_de_Contrato  7267 non-null   int64
#  22  total_contracto     7267 non-null   float64
# dtypes: float64(4), int64(1), object(18)
# memory usage: 1.6+ MB

# %% [markdown]
# ###**reseteando index**

# %%
df_telecom_X.reset_index(inplace=True, drop=True)
df_telecom_X.head()
# Out:
#    customerid churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                              account  gender InternetService  \
# 0  {'Contract': 'One year', 'PaperlessBilling': '...  Female             DSL
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male             DSL
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male     Fiber optic
# 3  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male     Fiber optic
# 4  {'Contract': 'Month-to-month', 'PaperlessBilli...  Female     Fiber optic
#
#   OnlineSecurity OnlineBackup  ... StreamingTV StreamingMovies phone_service  \
# 0             No          Yes  ...         Yes              No           Yes
# 1             No           No  ...          No             Yes           Yes
# 2             No           No  ...          No              No           Yes
# 3             No          Yes  ...         Yes             Yes           Yes
# 4             No           No  ...         Yes              No           Yes
#
#          contract paperless_billing     PaymentMethod charges.monthly  \
# 0        One year               Yes      Mailed check            65.6
# 1  Month-to-month                No      Mailed check            59.9
# 2  Month-to-month               Yes  Electronic check            73.9
# 3  Month-to-month               Yes  Electronic check            98.0
# 4  Month-to-month               Yes      Mailed check            83.9
#
#   charges.total  contract_in_numbers cuentas_diarias
# 0         593.3                   12        2.186667
# 1         542.4                    1        1.996667
# 2        280.85                    1        2.463333
# 3       1237.85                    1        3.266667
# 4         267.4                    1        2.796667
#
# [5 rows x 22 columns]

# %% [markdown]
# ###**Organizando el dataframe df_telecom_X, en orden ascendente de menor a mayor, para la columna '***charges.monthly***'**

# %%
df_telecom_X = df_telecom_X.sort_values('charges.monthly', ascending=True)
df_telecom_X.head()
# Out:
#       customerid churn                                           customer  \
# 4988  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7090  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 579   0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 434   0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7233  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                phone  \
# 4988  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7090  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 579   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 434   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7233  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                                internet  \
# 4988  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 7090  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 579   {'InternetService': 'No', 'OnlineSecurity': 'N...
# 434   {'InternetService': 'No', 'OnlineSecurity': 'N...
# 7233  {'InternetService': 'No', 'OnlineSecurity': 'N...
#
#                                                 account  gender  \
# 4988  {'Contract': 'One year', 'PaperlessBilling': '...    Male
# 7090  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 579   {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 434   {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 7233  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
#
#      InternetService       OnlineSecurity         OnlineBackup  ...  \
# 4988              No  No internet service  No internet service  ...
# 7090              No  No internet service  No internet service  ...
# 579               No  No internet service  No internet service  ...
# 434               No  No internet service  No internet service  ...
# 7233              No  No internet service  No internet service  ...
#
#               StreamingTV      StreamingMovies phone_service  contract  \
# 4988  No internet service  No internet service           Yes  One year
# 7090  No internet service  No internet service           Yes  Two year
# 579   No internet service  No internet service           Yes  Two year
# 434   No internet service  No internet service           Yes  Two year
# 7233  No internet service  No internet service           Yes  Two year
#
#      paperless_billing              PaymentMethod charges.monthly  \
# 4988                No    Credit card (automatic)           18.25
# 7090                No  Bank transfer (automatic)           18.40
# 579                Yes    Credit card (automatic)           18.55
# 434                 No               Mailed check           18.70
# 7233               Yes               Mailed check           18.70
#
#      charges.total  contract_in_numbers cuentas_diarias
# 4988         534.7                   12        0.608333
# 7090       1057.85                   24        0.613333
# 579            689                   24        0.618333
# 434         1005.7                   24        0.623333
# 7233        383.65                   24        0.623333
#
# [5 rows x 22 columns]

# %% [markdown]
# ###**definiendo tipo de dato por columna**

# %%
df_telecom_X['InternetService'].value_counts()
# Out:
# InternetService
# Fiber optic    3198
# DSL            2488
# No             1581
# Name: count, dtype: int64

# %%
df_telecom_X['churn'].value_counts()
# Out:
# churn
# No     5174
# Yes    1869
#         224
# Name: count, dtype: int64

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# ####**Describing all columns of a DataFrame regardless of data type.**

# %%
df_telecom_X.describe(include='all')
# Out:
#         customerid churn                                           customer  \
# count         7267  7267                                               7267
# unique        7267     3                                                891
# top     7569-NMZYQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# freq             1  5174                                                223
# mean           NaN   NaN                                                NaN
# std            NaN   NaN                                                NaN
# min            NaN   NaN                                                NaN
# 25%            NaN   NaN                                                NaN
# 50%            NaN   NaN                                                NaN
# 75%            NaN   NaN                                                NaN
# max            NaN   NaN                                                NaN
#
#                                                  phone  \
# count                                             7267
# unique                                               3
# top     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# freq                                              3495
# mean                                               NaN
# std                                                NaN
# min                                                NaN
# 25%                                                NaN
# 50%                                                NaN
# 75%                                                NaN
# max                                                NaN
#
#                                                  internet  \
# count                                                7267
# unique                                                129
# top     {'InternetService': 'No', 'OnlineSecurity': 'N...
# freq                                                 1581
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                   account gender  \
# count                                                7267   7267
# unique                                               6931      2
# top     {'Contract': 'Month-to-month', 'PaperlessBilli...   Male
# freq                                                    6   3675
# mean                                                  NaN    NaN
# std                                                   NaN    NaN
# min                                                   NaN    NaN
# 25%                                                   NaN    NaN
# 50%                                                   NaN    NaN
# 75%                                                   NaN    NaN
# max                                                   NaN    NaN
#
#        InternetService OnlineSecurity OnlineBackup  ... StreamingTV  \
# count             7267           7267         7267  ...        7267
# unique               3              3            3  ...           3
# top        Fiber optic             No           No  ...          No
# freq              3198           3608         3182  ...        2896
# mean               NaN            NaN          NaN  ...         NaN
# std                NaN            NaN          NaN  ...         NaN
# min                NaN            NaN          NaN  ...         NaN
# 25%                NaN            NaN          NaN  ...         NaN
# 50%                NaN            NaN          NaN  ...         NaN
# 75%                NaN            NaN          NaN  ...         NaN
# max                NaN            NaN          NaN  ...         NaN
#
#        StreamingMovies phone_service        contract paperless_billing  \
# count             7267          7267            7267              7267
# unique               3             2               3                 2
# top                 No           Yes  Month-to-month               Yes
# freq              2870          6560            4005              4311
# mean               NaN           NaN             NaN               NaN
# std                NaN           NaN             NaN               NaN
# min                NaN           NaN             NaN               NaN
# 25%                NaN           NaN             NaN               NaN
# 50%                NaN           NaN             NaN               NaN
# 75%                NaN           NaN             NaN               NaN
# max                NaN           NaN             NaN               NaN
#
#            PaymentMethod charges.monthly charges.total  contract_in_numbers  \
# count               7267     7267.000000          7267          7267.000000
# unique                 4             NaN          6531                  NaN
# top     Electronic check             NaN          20.2                  NaN
# freq                2445             NaN            11                  NaN
# mean                 NaN       64.720098           NaN             8.815880
# std                  NaN       30.129572           NaN             9.544539
# min                  NaN       18.250000           NaN             1.000000
# 25%                  NaN       35.425000           NaN             1.000000
# 50%                  NaN       70.300000           NaN             1.000000
# 75%                  NaN       89.875000           NaN            12.000000
# max                  NaN      118.750000           NaN            24.000000
#
#        cuentas_diarias
# count      7267.000000
# unique             NaN
# top                NaN
# freq               NaN
# mean          2.157337
# std           1.004319
# min           0.608333
# 25%           1.180833
# 50%           2.343333
# 75%           2.995833
# max           3.958333
#
# [11 rows x 22 columns]

# %% [markdown]
# ####**Including only numeric columns in a DataFrame description.**

# %%
import numpy as np

df_telecom_X.describe(include=[np.number])
# Out:
#        charges.monthly  contract_in_numbers  cuentas_diarias
# count      7267.000000          7267.000000      7267.000000
# mean         64.720098             8.815880         2.157337
# std          30.129572             9.544539         1.004319
# min          18.250000             1.000000         0.608333
# 25%          35.425000             1.000000         1.180833
# 50%          70.300000             1.000000         2.343333
# 75%          89.875000            12.000000         2.995833
# max         118.750000            24.000000         3.958333

# %% [markdown]
# ####**Including only string columns in a DataFrame description.**

# %%
df_telecom_X.describe(include=[object])
# Out:
#         customerid churn                                           customer  \
# count         7267  7267                                               7267
# unique        7267     3                                                891
# top     7569-NMZYQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# freq             1  5174                                                223
#
#                                                  phone  \
# count                                             7267
# unique                                               3
# top     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# freq                                              3495
#
#                                                  internet  \
# count                                                7267
# unique                                                129
# top     {'InternetService': 'No', 'OnlineSecurity': 'N...
# freq                                                 1581
#
#                                                   account gender  \
# count                                                7267   7267
# unique                                               6931      2
# top     {'Contract': 'Month-to-month', 'PaperlessBilli...   Male
# freq                                                    6   3675
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7267           7267         7267             7267
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3198           3608         3182             3195
#
#        TechSupport StreamingTV StreamingMovies phone_service        contract  \
# count         7267        7267            7267          7267            7267
# unique           3           3               3             2               3
# top             No          No              No           Yes  Month-to-month
# freq          3582        2896            2870          6560            4005
#
#        paperless_billing     PaymentMethod charges.total
# count               7267              7267          7267
# unique                 2                 4          6531
# top                  Yes  Electronic check          20.2
# freq                4311              2445            11

# %% [markdown]
# ####**Including only categorical columns from a DataFrame description.**

# %%
df_telecom_X.describe(include=['object'])
# Out:
#         customerid churn                                           customer  \
# count         7267  7267                                               7267
# unique        7267     3                                                891
# top     7569-NMZYQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# freq             1  5174                                                223
#
#                                                  phone  \
# count                                             7267
# unique                                               3
# top     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# freq                                              3495
#
#                                                  internet  \
# count                                                7267
# unique                                                129
# top     {'InternetService': 'No', 'OnlineSecurity': 'N...
# freq                                                 1581
#
#                                                   account gender  \
# count                                                7267   7267
# unique                                               6931      2
# top     {'Contract': 'Month-to-month', 'PaperlessBilli...   Male
# freq                                                    6   3675
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7267           7267         7267             7267
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3198           3608         3182             3195
#
#        TechSupport StreamingTV StreamingMovies phone_service        contract  \
# count         7267        7267            7267          7267            7267
# unique           3           3               3             2               3
# top             No          No              No           Yes  Month-to-month
# freq          3582        2896            2870          6560            4005
#
#        paperless_billing     PaymentMethod charges.total
# count               7267              7267          7267
# unique                 2                 4          6531
# top                  Yes  Electronic check          20.2
# freq                4311              2445            11

# %% [markdown]
# #####**Calculando la Media**

# %% [markdown]
# ######**La mediana en estadística es el valor medio en un conjunto de datos ordenados. Representa el punto medio, donde la mitad de los datos son menores y la otra mitad son mayores.
# ¿Cómo se calcula la mediana?
# Ordena los datos: Organiza el conjunto de datos de menor a mayor.
# Encuentra el valor medio:
# Si el número de datos es impar, la mediana es el valor central.
# Si el número de datos es par, la mediana es el promedio de los dos valores centrales, según Khan Academy.
# Ejemplo:
# Para los datos: 2, 3, 3, 5, 7, 10, la mediana es 4 (el promedio de 3 y 5). **

# %% [markdown]
# ####**Cargo Mensual, la mediana 64.72009770194028**

# %%
df_telecom_X['charges.monthly'].mean()
# Out:
# np.float64(64.72009770194028)

# %%
df_telecom_X.groupby('customerid')[['charges.monthly']].mean().sort_values('charges.monthly', ascending=True)
# Out:
#             charges.monthly
# customerid
# 6823-SIDFQ            18.25
# 9764-REAFF            18.40
# 0827-ITJPH            18.55
# 0621-CXBKL            18.70
# 9945-PSVIP            18.70
# ...                     ...
# 8199-ZLLSA           118.35
# 5989-AXPUC           118.60
# 5734-EJKXG           118.60
# 8984-HPEMB           118.65
# 7569-NMZYQ           118.75
#
# [7267 rows x 1 columns]

# %% [markdown]
# ####**Cargo Total, la mediana 2280.6342130650496**

# %%
# Convert 'charges.total' to numeric, coercing errors to NaN
df_telecom_X['charges.total'] = pd.to_numeric(df_telecom_X['charges.total'], errors='coerce')

# Calculate the mean of the numeric column, skipping NaN values
df_telecom_X['charges.total'].mean()
# Out:
# np.float64(2280.6342130650496)

# %%
df_telecom_X['charges.total'].isnull().sum()
# Out:
# np.int64(11)

# %%
df_telecom_X['charges.total'].fillna(0, inplace=True)
# Out:
# /tmp/ipython-input-107880294.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_telecom_X['charges.total'].fillna(0, inplace=True)

# %%
df_telecom_X.groupby(['customerid','contract'])[['charges.total']].mean().sort_values('charges.total', ascending=False)
# Out:
#                      charges.total
# customerid contract
# 2889-FPWRM One year        8684.80
# 7569-NMZYQ Two year        8672.45
# 9739-JLPQJ Two year        8670.10
# 9788-HNGUT Two year        8594.40
# 8879-XUAHX Two year        8564.75
# ...                            ...
# 5709-LVOEQ Two year           0.00
# 3213-VVOLG Two year           0.00
# 2775-SEFEE Two year           0.00
# 3115-CZMZD Two year           0.00
# 7644-OMVMY Two year           0.00
#
# [7267 rows x 1 columns]

# %% [markdown]
# ####**Cuentas Diarias, la mediana 2.1573365900646757**

# %%
df_telecom_X['cuentas_diarias'].mean()
# Out:
# np.float64(2.1573365900646757)

# %%
df_telecom_X.groupby(['customerid','charges.monthly'])[['cuentas_diarias']].mean().sort_values('cuentas_diarias', ascending=True)
# Out:
#                             cuentas_diarias
# customerid charges.monthly
# 6823-SIDFQ 18.25                   0.608333
# 9764-REAFF 18.40                   0.613333
# 0827-ITJPH 18.55                   0.618333
# 0621-CXBKL 18.70                   0.623333
# 9945-PSVIP 18.70                   0.623333
# ...                                     ...
# 8199-ZLLSA 118.35                  3.945000
# 5989-AXPUC 118.60                  3.953333
# 5734-EJKXG 118.60                  3.953333
# 8984-HPEMB 118.65                  3.955000
# 7569-NMZYQ 118.75                  3.958333
#
# [7267 rows x 1 columns]

# %% [markdown]
# ###**Resumen**
#
#
# *   charges.monthly	64.755423
# *   charges.total	2280.634213
# *   cuentas_diarias	2.158514

# %%
df_median = (df_telecom_X['charges.total']>0)
df_telecom_X[df_median].select_dtypes(include='number').mean()
# Out:
# charges.monthly          64.755423
# charges.total          2280.634213
# contract_in_numbers       8.794515
# cuentas_diarias           2.158514
# dtype: float64

# %% [markdown]
# #####**El minimo**

# %% [markdown]
# ######**El minimo cargo mensual es de 18.25**

# %%
df_telecom_X['charges.monthly'].min()
# Out:
# 18.25

# %%
df_telecom_X.query('`charges.monthly`== 18.25').index
# Out:
# Index([4988], dtype='int64')

# %%
df_telecom_X.iloc[4988].to_dict()
# Out:
# {'customerid': '0362-ZBZWJ',
#  'churn': 'Yes',
#  'customer': {'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 36},
#  'phone': {'PhoneService': 'Yes', 'MultipleLines': 'Yes'},
#  'internet': {'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'Yes'},
#  'account': {'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'Charges': {'Monthly': 84.9, 'Total': '3067.2'}},
#  'gender': 'Male',
#  'InternetService': 'Fiber optic',
#  'OnlineSecurity': 'No',
#  'OnlineBackup': 'No',
#  'DeviceProtection': 'No',
#  'TechSupport': 'No',
#  'StreamingTV': 'No',
#  'StreamingMovies': 'Yes',
#  'phone_service': 'Yes',
#  'contract': 'Month-to-month',
#  'paperless_billing': 'Yes',
#  'PaymentMethod': 'Electronic check',
#  'charges.monthly': 84.9,
#  'charges.total': 3067.2,
#  'contract_in_numbers': 1,
#  'cuentas_diarias': 2.83}

# %% [markdown]
# ######**El minimo cargo total es de 18.80**

# %%
df_monthly_min = (df_telecom_X['charges.total']>0)

# %%
df_telecom_X[df_monthly_min].select_dtypes(include='number').min()
# Out:
# charges.monthly        18.250000
# charges.total          18.800000
# contract_in_numbers     1.000000
# cuentas_diarias         0.608333
# dtype: float64

# %%
df_telecom_X.query('`charges.total`== 18.80').index
# Out:
# Index([2111], dtype='int64')

# %%
df_telecom_X.iloc[2111].to_dict()
# Out:
# {'customerid': '4193-ORFCL',
#  'churn': 'Yes',
#  'customer': {'gender': 'Female',
#   'SeniorCitizen': 1,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 1},
#  'phone': {'PhoneService': 'Yes', 'MultipleLines': 'No'},
#  'internet': {'InternetService': 'DSL',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No'},
#  'account': {'Contract': 'Month-to-month',
#   'PaperlessBilling': 'No',
#   'PaymentMethod': 'Mailed check',
#   'Charges': {'Monthly': 45.1, 'Total': '45.1'}},
#  'gender': 'Female',
#  'InternetService': 'DSL',
#  'OnlineSecurity': 'No',
#  'OnlineBackup': 'No',
#  'DeviceProtection': 'No',
#  'TechSupport': 'No',
#  'StreamingTV': 'No',
#  'StreamingMovies': 'No',
#  'phone_service': 'Yes',
#  'contract': 'Month-to-month',
#  'paperless_billing': 'No',
#  'PaymentMethod': 'Mailed check',
#  'charges.monthly': 45.1,
#  'charges.total': 45.1,
#  'contract_in_numbers': 1,
#  'cuentas_diarias': 1.5033333333333334}

# %% [markdown]
# ######**El minimo cuentas diarias es de 0.6083333333333333**

# %%
df_telecom_X['cuentas_diarias'].min()
# Out:
# 0.6083333333333333

# %%
df_telecom_X.query('`cuentas_diarias`== 0.6083333333333333').index
# Out:
# Index([4988], dtype='int64')

# %%
df_telecom_X.iloc[4988].to_dict()
# Out:
# {'customerid': '0362-ZBZWJ',
#  'churn': 'Yes',
#  'customer': {'gender': 'Male',
#   'SeniorCitizen': 0,
#   'Partner': 'No',
#   'Dependents': 'No',
#   'tenure': 36},
#  'phone': {'PhoneService': 'Yes', 'MultipleLines': 'Yes'},
#  'internet': {'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'No',
#   'OnlineBackup': 'No',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'Yes'},
#  'account': {'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Electronic check',
#   'Charges': {'Monthly': 84.9, 'Total': '3067.2'}},
#  'gender': 'Male',
#  'InternetService': 'Fiber optic',
#  'OnlineSecurity': 'No',
#  'OnlineBackup': 'No',
#  'DeviceProtection': 'No',
#  'TechSupport': 'No',
#  'StreamingTV': 'No',
#  'StreamingMovies': 'Yes',
#  'phone_service': 'Yes',
#  'contract': 'Month-to-month',
#  'paperless_billing': 'Yes',
#  'PaymentMethod': 'Electronic check',
#  'charges.monthly': 84.9,
#  'charges.total': 3067.2,
#  'contract_in_numbers': 1,
#  'cuentas_diarias': 2.83}

# %% [markdown]
# #####**Resumen**
#
# *   El minimo cargo mensual es de 18.25
# *   El minimo cargo total es de 18.80
# *   El minimo cuentas diarias es de 0.6083333333333333

# %%
df_monthly_min = (df_telecom_X['charges.total']>0)
df_telecom_X[df_monthly_min].select_dtypes(include='number').min()
# Out:
# charges.monthly        18.250000
# charges.total          18.800000
# contract_in_numbers     1.000000
# cuentas_diarias         0.608333
# dtype: float64

# %% [markdown]
# #####**El maximo**

# %% [markdown]
# ######**El maximo cargo mensual es de 118.75**

# %%
df_telecom_X['charges.monthly'].max()
# Out:
# 118.75

# %%
df_telecom_X.iloc[df_telecom_X.query('`charges.monthly`== 118.75').index].to_dict()
# Out:
# {'customerid': {558: '0795-LAFGP'},
#  'churn': {558: 'No'},
#  'customer': {558: {'gender': 'Male',
#    'SeniorCitizen': 0,
#    'Partner': 'Yes',
#    'Dependents': 'Yes',
#    'tenure': 71}},
#  'phone': {558: {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}},
#  'internet': {558: {'InternetService': 'DSL',
#    'OnlineSecurity': 'Yes',
#    'OnlineBackup': 'Yes',
#    'DeviceProtection': 'Yes',
#    'TechSupport': 'Yes',
#    'StreamingTV': 'Yes',
#    'StreamingMovies': 'Yes'}},
#  'account': {558: {'Contract': 'Two year',
#    'PaperlessBilling': 'No',
#    'PaymentMethod': 'Electronic check',
#    'Charges': {'Monthly': 90.4, 'Total': '6668.05'}}},
#  'gender': {558: 'Male'},
#  'InternetService': {558: 'DSL'},
#  'OnlineSecurity': {558: 'Yes'},
#  'OnlineBackup': {558: 'Yes'},
#  'DeviceProtection': {558: 'Yes'},
#  'TechSupport': {558: 'Yes'},
#  'StreamingTV': {558: 'Yes'},
#  'StreamingMovies': {558: 'Yes'},
#  'phone_service': {558: 'Yes'},
#  'contract': {558: 'Two year'},
#  'paperless_billing': {558: 'No'},
#  'PaymentMethod': {558: 'Electronic check'},
#  'charges.monthly': {558: 90.4},
#  'charges.total': {558: 6668.05},
#  'contract_in_numbers': {558: 24},
#  'cuentas_diarias': {558: 3.0133333333333336}}

# %% [markdown]
# ######**El maximo cargo total es de 8684.8**

# %%
df_telecom_X['charges.total'].max()
# Out:
# 8684.8

# %%
df_telecom_X.iloc[df_telecom_X.query('`charges.total`== 8684.8').index].to_dict()
# Out:
# {'customerid': {6038: '8242-JSVBO'},
#  'churn': {6038: 'No'},
#  'customer': {6038: {'gender': 'Male',
#    'SeniorCitizen': 0,
#    'Partner': 'No',
#    'Dependents': 'No',
#    'tenure': 7}},
#  'phone': {6038: {'PhoneService': 'Yes', 'MultipleLines': 'No'}},
#  'internet': {6038: {'InternetService': 'DSL',
#    'OnlineSecurity': 'No',
#    'OnlineBackup': 'No',
#    'DeviceProtection': 'No',
#    'TechSupport': 'No',
#    'StreamingTV': 'No',
#    'StreamingMovies': 'No'}},
#  'account': {6038: {'Contract': 'Month-to-month',
#    'PaperlessBilling': 'Yes',
#    'PaymentMethod': 'Bank transfer (automatic)',
#    'Charges': {'Monthly': 44.65, 'Total': '322.5'}}},
#  'gender': {6038: 'Male'},
#  'InternetService': {6038: 'DSL'},
#  'OnlineSecurity': {6038: 'No'},
#  'OnlineBackup': {6038: 'No'},
#  'DeviceProtection': {6038: 'No'},
#  'TechSupport': {6038: 'No'},
#  'StreamingTV': {6038: 'No'},
#  'StreamingMovies': {6038: 'No'},
#  'phone_service': {6038: 'Yes'},
#  'contract': {6038: 'Month-to-month'},
#  'paperless_billing': {6038: 'Yes'},
#  'PaymentMethod': {6038: 'Bank transfer (automatic)'},
#  'charges.monthly': {6038: 44.65},
#  'charges.total': {6038: 322.5},
#  'contract_in_numbers': {6038: 1},
#  'cuentas_diarias': {6038: 1.4883333333333333}}

# %% [markdown]
# ######**El maximo cuentas_diarias es de 3.9583333333333335**

# %%
df_telecom_X['cuentas_diarias'].max()
# Out:
# 3.9583333333333335

# %%
df_telecom_X.iloc[df_telecom_X.query('`cuentas_diarias`== 3.9583333333333335').index].to_dict()
# Out:
# {'customerid': {558: '0795-LAFGP'},
#  'churn': {558: 'No'},
#  'customer': {558: {'gender': 'Male',
#    'SeniorCitizen': 0,
#    'Partner': 'Yes',
#    'Dependents': 'Yes',
#    'tenure': 71}},
#  'phone': {558: {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}},
#  'internet': {558: {'InternetService': 'DSL',
#    'OnlineSecurity': 'Yes',
#    'OnlineBackup': 'Yes',
#    'DeviceProtection': 'Yes',
#    'TechSupport': 'Yes',
#    'StreamingTV': 'Yes',
#    'StreamingMovies': 'Yes'}},
#  'account': {558: {'Contract': 'Two year',
#    'PaperlessBilling': 'No',
#    'PaymentMethod': 'Electronic check',
#    'Charges': {'Monthly': 90.4, 'Total': '6668.05'}}},
#  'gender': {558: 'Male'},
#  'InternetService': {558: 'DSL'},
#  'OnlineSecurity': {558: 'Yes'},
#  'OnlineBackup': {558: 'Yes'},
#  'DeviceProtection': {558: 'Yes'},
#  'TechSupport': {558: 'Yes'},
#  'StreamingTV': {558: 'Yes'},
#  'StreamingMovies': {558: 'Yes'},
#  'phone_service': {558: 'Yes'},
#  'contract': {558: 'Two year'},
#  'paperless_billing': {558: 'No'},
#  'PaymentMethod': {558: 'Electronic check'},
#  'charges.monthly': {558: 90.4},
#  'charges.total': {558: 6668.05},
#  'contract_in_numbers': {558: 24},
#  'cuentas_diarias': {558: 3.0133333333333336}}

# %% [markdown]
# ####**Resumen**
#
# *   charges.monthly	118.750000
# *   charges.total	8684.800000
# *   cuentas_diarias	3.958333

# %%
df_monthly_max = (df_telecom_X['charges.total']>0)
df_telecom_X[df_monthly_min].select_dtypes(include='number').max()
# Out:
# charges.monthly         118.750000
# charges.total          8684.800000
# contract_in_numbers      24.000000
# cuentas_diarias           3.958333
# dtype: float64

# %% [markdown]
# #####**Cuentas / Cantidad**

# %%
df_telecom_X['churn'].value_counts()
# Out:
# churn
# No     5174
# Yes    1869
#         224
# Name: count, dtype: int64

# %%
df_telecom_X['gender'].value_counts()
# Out:
# gender
# Male      3675
# Female    3592
# Name: count, dtype: int64

# %%
df_telecom_X['phone_service'].value_counts()
# Out:
# phone_service
# Yes    6560
# No      707
# Name: count, dtype: int64

# %% [markdown]
# ####**Aplicando Filtro Churn**

# %%
filtro_churn = df_telecom_X['churn'] == 'Yes'
df_telecom_X[filtro_churn]
# Out:
#       customerid churn                                           customer  \
# 6759  9318-NKNFC   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 6559  9025-ZRPVR   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 861   1218-VKFPE   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4463  6121-VZNQB   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4026  5510-BOIUJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# ...          ...   ...                                                ...
# 1027  1444-VVSGW   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 6581  9053-JZFKV   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 1620  2302-ANTDP   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 2053  2889-FPWRM   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 5998  8199-ZLLSA   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                 phone  \
# 6759   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 6559   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 861    {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4463   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4026   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                               ...
# 1027  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 6581  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 1620  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2053  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 5998  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                                internet  \
# 6759  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 6559  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 861   {'InternetService': 'No', 'OnlineSecurity': 'N...
# 4463  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 4026  {'InternetService': 'No', 'OnlineSecurity': 'N...
# ...                                                 ...
# 1027  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 6581  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 1620  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 2053  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 5998  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                                 account  gender  \
# 6759  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 6559  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 861   {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
# 4463  {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
# 4026  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# ...                                                 ...     ...
# 1027  {'Contract': 'One year', 'PaperlessBilling': '...    Male
# 6581  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 1620  {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
# 2053  {'Contract': 'One year', 'PaperlessBilling': '...    Male
# 5998  {'Contract': 'One year', 'PaperlessBilling': '...    Male
#
#      InternetService       OnlineSecurity         OnlineBackup  ...  \
# 6759              No  No internet service  No internet service  ...
# 6559              No  No internet service  No internet service  ...
# 861               No  No internet service  No internet service  ...
# 4463              No  No internet service  No internet service  ...
# 4026              No  No internet service  No internet service  ...
# ...              ...                  ...                  ...  ...
# 1027     Fiber optic                  Yes                  Yes  ...
# 6581     Fiber optic                  Yes                  Yes  ...
# 1620     Fiber optic                  Yes                  Yes  ...
# 2053     Fiber optic                  Yes                  Yes  ...
# 5998     Fiber optic                  Yes                  Yes  ...
#
#               StreamingTV      StreamingMovies phone_service        contract  \
# 6759  No internet service  No internet service           Yes  Month-to-month
# 6559  No internet service  No internet service           Yes  Month-to-month
# 861   No internet service  No internet service           Yes  Month-to-month
# 4463  No internet service  No internet service           Yes  Month-to-month
# 4026  No internet service  No internet service           Yes  Month-to-month
# ...                   ...                  ...           ...             ...
# 1027                  Yes                  Yes           Yes        One year
# 6581                  Yes                  Yes           Yes        Two year
# 1620                  Yes                  Yes           Yes  Month-to-month
# 2053                  Yes                  Yes           Yes        One year
# 5998                  Yes                  Yes           Yes        One year
#
#      paperless_billing              PaymentMethod charges.monthly  \
# 6759               Yes               Mailed check           18.85
# 6559               Yes               Mailed check           18.95
# 861                 No               Mailed check           19.00
# 4463               Yes               Mailed check           19.10
# 4026                No               Mailed check           19.25
# ...                ...                        ...             ...
# 1027                No    Credit card (automatic)          115.65
# 6581                No    Credit card (automatic)          116.20
# 1620                No           Electronic check          117.45
# 2053               Yes  Bank transfer (automatic)          117.80
# 5998               Yes  Bank transfer (automatic)          118.35
#
#      charges.total  contract_in_numbers  cuentas_diarias
# 6759         18.85                    1         0.628333
# 6559        185.60                    1         0.631667
# 861         233.55                    1         0.633333
# 4463         19.10                    1         0.636667
# 4026         19.25                    1         0.641667
# ...            ...                  ...              ...
# 1027       7968.85                   12         3.855000
# 6581       7752.30                   24         3.873333
# 1620       5438.90                    1         3.915000
# 2053       8684.80                   12         3.926667
# 5998       7804.15                   12         3.945000
#
# [1869 rows x 22 columns]

# %%
df_telecom_X[filtro_churn].count()
# Out:
# customerid             1869
# churn                  1869
# customer               1869
# phone                  1869
# internet               1869
# account                1869
# gender                 1869
# InternetService        1869
# OnlineSecurity         1869
# OnlineBackup           1869
# DeviceProtection       1869
# TechSupport            1869
# StreamingTV            1869
# StreamingMovies        1869
# phone_service          1869
# contract               1869
# paperless_billing      1869
# PaymentMethod          1869
# charges.monthly        1869
# charges.total          1869
# contract_in_numbers    1869
# cuentas_diarias        1869
# dtype: int64

# %%
filtro_churn_no = df_telecom_X['churn'] == 'No'
df_telecom_X[filtro_churn_no]
# Out:
#       customerid churn                                           customer  \
# 4988  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7090  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 579   0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 434   0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7233  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# ...          ...   ...                                                ...
# 7215  9924-JPRMC    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 4366  5989-AXPUC    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4182  5734-EJKXG    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6537  8984-HPEMB    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5523  7569-NMZYQ    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                 phone  \
# 4988   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7090   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 579    {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 434    {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7233   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                               ...
# 7215  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 4366  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 4182  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 6537  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 5523  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                                internet  \
# 4988  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 7090  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 579   {'InternetService': 'No', 'OnlineSecurity': 'N...
# 434   {'InternetService': 'No', 'OnlineSecurity': 'N...
# 7233  {'InternetService': 'No', 'OnlineSecurity': 'N...
# ...                                                 ...
# 7215  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4366  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4182  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 6537  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 5523  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                                 account  gender  \
# 4988  {'Contract': 'One year', 'PaperlessBilling': '...    Male
# 7090  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 579   {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 434   {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 7233  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# ...                                                 ...     ...
# 7215  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 4366  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 4182  {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 6537  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 5523  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
#
#      InternetService       OnlineSecurity         OnlineBackup  ...  \
# 4988              No  No internet service  No internet service  ...
# 7090              No  No internet service  No internet service  ...
# 579               No  No internet service  No internet service  ...
# 434               No  No internet service  No internet service  ...
# 7233              No  No internet service  No internet service  ...
# ...              ...                  ...                  ...  ...
# 7215     Fiber optic                  Yes                  Yes  ...
# 4366     Fiber optic                  Yes                  Yes  ...
# 4182     Fiber optic                  Yes                  Yes  ...
# 6537     Fiber optic                  Yes                  Yes  ...
# 5523     Fiber optic                  Yes                  Yes  ...
#
#               StreamingTV      StreamingMovies phone_service  contract  \
# 4988  No internet service  No internet service           Yes  One year
# 7090  No internet service  No internet service           Yes  Two year
# 579   No internet service  No internet service           Yes  Two year
# 434   No internet service  No internet service           Yes  Two year
# 7233  No internet service  No internet service           Yes  Two year
# ...                   ...                  ...           ...       ...
# 7215                  Yes                  Yes           Yes  Two year
# 4366                  Yes                  Yes           Yes  Two year
# 4182                  Yes                  Yes           Yes  One year
# 6537                  Yes                  Yes           Yes  Two year
# 5523                  Yes                  Yes           Yes  Two year
#
#      paperless_billing              PaymentMethod charges.monthly  \
# 4988                No    Credit card (automatic)           18.25
# 7090                No  Bank transfer (automatic)           18.40
# 579                Yes    Credit card (automatic)           18.55
# 434                 No               Mailed check           18.70
# 7233               Yes               Mailed check           18.70
# ...                ...                        ...             ...
# 7215               Yes           Electronic check          118.20
# 4366                No               Mailed check          118.60
# 4182               Yes           Electronic check          118.60
# 6537               Yes           Electronic check          118.65
# 5523               Yes  Bank transfer (automatic)          118.75
#
#      charges.total  contract_in_numbers  cuentas_diarias
# 4988        534.70                   12         0.608333
# 7090       1057.85                   24         0.613333
# 579         689.00                   24         0.618333
# 434        1005.70                   24         0.623333
# 7233        383.65                   24         0.623333
# ...            ...                  ...              ...
# 7215       8547.15                   24         3.940000
# 4366       7990.05                   24         3.953333
# 4182       7365.70                   12         3.953333
# 6537       8477.60                   24         3.955000
# 5523       8672.45                   24         3.958333
#
# [5174 rows x 22 columns]

# %%
df_telecom_X[filtro_churn_no].count()
# Out:
# customerid             5174
# churn                  5174
# customer               5174
# phone                  5174
# internet               5174
# account                5174
# gender                 5174
# InternetService        5174
# OnlineSecurity         5174
# OnlineBackup           5174
# DeviceProtection       5174
# TechSupport            5174
# StreamingTV            5174
# StreamingMovies        5174
# phone_service          5174
# contract               5174
# paperless_billing      5174
# PaymentMethod          5174
# charges.monthly        5174
# charges.total          5174
# contract_in_numbers    5174
# cuentas_diarias        5174
# dtype: int64

# %%
filtro_churn_vacio = df_telecom_X['churn'] == ''
df_telecom_X[filtro_churn_vacio]
# Out:
#       customerid churn                                           customer  \
# 3538  4878-SMQBX        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7058  9717-WXVSB        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3900  5332-UJJBL        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 1364  1972-RSMOV        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 3053  4250-QVQRU        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# ...          ...   ...                                                ...
# 640   0910-AJOHQ        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1517  2183-ZULVZ        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 3177  4438-GGYWL        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2576  3590-DWSLF        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4199  5766-RLNAM        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                 phone  \
# 3538   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7058   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3900   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1364   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3053   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                               ...
# 640   {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 1517  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 3177  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2576  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 4199  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                                internet  \
# 3538  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 7058  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 3900  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 1364  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 3053  {'InternetService': 'No', 'OnlineSecurity': 'N...
# ...                                                 ...
# 640   {'InternetService': 'Fiber optic', 'OnlineSecu...
# 1517  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3177  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 2576  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4199  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                                 account  gender  \
# 3538  {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
# 7058  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 3900  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 1364  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 3053  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# ...                                                 ...     ...
# 640   {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 1517  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 3177  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 2576  {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 4199  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
#
#      InternetService       OnlineSecurity         OnlineBackup  ...  \
# 3538              No  No internet service  No internet service  ...
# 7058              No  No internet service  No internet service  ...
# 3900              No  No internet service  No internet service  ...
# 1364              No  No internet service  No internet service  ...
# 3053              No  No internet service  No internet service  ...
# ...              ...                  ...                  ...  ...
# 640      Fiber optic                  Yes                  Yes  ...
# 1517     Fiber optic                  Yes                  Yes  ...
# 3177     Fiber optic                  Yes                  Yes  ...
# 2576     Fiber optic                  Yes                  Yes  ...
# 4199     Fiber optic                  Yes                  Yes  ...
#
#               StreamingTV      StreamingMovies phone_service        contract  \
# 3538  No internet service  No internet service           Yes  Month-to-month
# 7058  No internet service  No internet service           Yes  Month-to-month
# 3900  No internet service  No internet service           Yes  Month-to-month
# 1364  No internet service  No internet service           Yes        Two year
# 3053  No internet service  No internet service           Yes  Month-to-month
# ...                   ...                  ...           ...             ...
# 640                   Yes                  Yes           Yes        Two year
# 1517                  Yes                  Yes           Yes        Two year
# 3177                  Yes                  Yes           Yes        Two year
# 2576                  Yes                  Yes           Yes        One year
# 4199                  Yes                  Yes           Yes        Two year
#
#      paperless_billing              PaymentMethod charges.monthly  \
# 3538                No  Bank transfer (automatic)           18.75
# 7058                No               Mailed check           18.90
# 3900                No               Mailed check           19.00
# 1364                No               Mailed check           19.10
# 3053                No               Mailed check           19.25
# ...                ...                        ...             ...
# 640                Yes  Bank transfer (automatic)          115.10
# 1517               Yes    Credit card (automatic)          115.15
# 3177                No  Bank transfer (automatic)          115.55
# 2576                No    Credit card (automatic)          115.55
# 4199               Yes           Electronic check          115.55
#
#      charges.total  contract_in_numbers  cuentas_diarias
# 3538         53.15                    1         0.625000
# 7058         18.90                    1         0.630000
# 3900         73.45                    1         0.633333
# 1364        780.10                   24         0.636667
# 3053         48.35                    1         0.641667
# ...            ...                  ...              ...
# 640        7334.05                   24         3.836667
# 1517       8250.00                   24         3.838333
# 3177       7159.05                   24         3.851667
# 2576       8127.60                   12         3.851667
# 4199       8425.30                   24         3.851667
#
# [224 rows x 22 columns]

# %%
df_telecom_X[filtro_churn_vacio].count()
# Out:
# customerid             224
# churn                  224
# customer               224
# phone                  224
# internet               224
# account                224
# gender                 224
# InternetService        224
# OnlineSecurity         224
# OnlineBackup           224
# DeviceProtection       224
# TechSupport            224
# StreamingTV            224
# StreamingMovies        224
# phone_service          224
# contract               224
# paperless_billing      224
# PaymentMethod          224
# charges.monthly        224
# charges.total          224
# contract_in_numbers    224
# cuentas_diarias        224
# dtype: int64

# %% [markdown]
# ####**Conteo**

# %% [markdown]
# #####**Churn y customer Id  **
#
# *   vacio = 224
# *   churn No  = 5174
# *   churn Yes = 1869
#  total de 7267 usuarios de la empresa telecom X

# %%
df_churn_telecomX= df_telecom_X.groupby(['churn'])[['customerid']].count()
df_churn_telecomX
# Out:
#        customerid
# churn
#               224
# No           5174
# Yes          1869

# %%
df_churn_telecomX.plot(kind='pie', y='customerid', figsize=(10,8), color='purple', title='Churn en el TelecomX', xlabel='churn', ylabel='Cantidad de clientes', autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'Churn en el TelecomX'}, ylabel='Cantidad de clientes'>

# %%
df_churn_telecomX.plot(kind='bar', figsize=(12, 8), title='Churn Count by Contract Type', xlabel='Contract Type and Churn', ylabel='Count')
# Out:
# <Axes: title={'center': 'Churn Count by Contract Type'}, xlabel='Contract Type and Churn', ylabel='Count'>

# %% [markdown]
# #####**Churn, custumerid y gender   **

# %%
df_churn_telecomX_gender= df_telecom_X.groupby(['churn'])[['gender']].value_counts()
df_churn_telecomX_gender
# Out:
# churn  gender
#        Male       120
#        Female     104
# No     Male      2625
#        Female    2549
# Yes    Female     939
#        Male       930
# Name: count, dtype: int64

# %%
df_churn_telecomX_gender.plot(kind='bar', figsize=(10, 5), title='Churn Count by Contract Type', xlabel='Contract Type and Churn', ylabel='Count')
# Out:
# <Axes: title={'center': 'Churn Count by Contract Type'}, xlabel='Contract Type and Churn', ylabel='Count'>

# %% [markdown]
# #####**Churn y contract**

# %%
df_churn_telecomX_contract= df_telecom_X.groupby(['churn'])[['contract']].value_counts()
df_churn_telecomX_contract
# Out:
# churn  contract
#        Month-to-month     130
#        Two year            48
#        One year            46
# No     Month-to-month    2220
#        Two year          1647
#        One year          1307
# Yes    Month-to-month    1655
#        One year           166
#        Two year            48
# Name: count, dtype: int64

# %%
df_churn_telecomX_contract1= df_telecom_X.groupby(['churn','gender'])[['contract']].value_counts()
df_churn_telecomX_contract1
# Out:
# churn  gender  contract
#        Female  Month-to-month      57
#                Two year            25
#                One year            22
#        Male    Month-to-month      73
#                One year            24
#                Two year            23
# No     Female  Month-to-month    1083
#                Two year           823
#                One year           643
#        Male    Month-to-month    1137
#                Two year           824
#                One year           664
# Yes    Female  Month-to-month     842
#                One year            75
#                Two year            22
#        Male    Month-to-month     813
#                One year            91
#                Two year            26
# Name: count, dtype: int64

# %%
df_churn_telecomX_contract.plot(kind='bar', figsize=(10, 5), title='Churn Count by Contract Type', xlabel='Contract Type and Churn', ylabel='Count')
# Out:
# <Axes: title={'center': 'Churn Count by Contract Type'}, xlabel='Contract Type and Churn', ylabel='Count'>

# %% [markdown]
# ####**Churn,contract y PaymentMethod**

# %%
df_churn_telecomX_PaymentMethod= df_telecom_X.groupby(['churn'])[['PaymentMethod']].value_counts()
df_churn_telecomX_PaymentMethod
# Out:
# churn  PaymentMethod
#        Electronic check               80
#        Mailed check                   53
#        Credit card (automatic)        46
#        Bank transfer (automatic)      45
# No     Mailed check                 1304
#        Electronic check             1294
#        Credit card (automatic)      1290
#        Bank transfer (automatic)    1286
# Yes    Electronic check             1071
#        Mailed check                  308
#        Bank transfer (automatic)     258
#        Credit card (automatic)       232
# Name: count, dtype: int64

# %%
df_churn_telecomX_PaymentMethod.plot(kind='bar', figsize=(10, 5), title='Churn Count by PaymentMethod', xlabel='Contract Type and PaymentMethod', ylabel='Count')
# Out:
# <Axes: title={'center': 'Churn Count by PaymentMethod'}, xlabel='Contract Type and PaymentMethod', ylabel='Count'>

# %% [markdown]
# #####**Churn,contract y PaymentMethod**

# %%
df_churn_telecomX_PaymentMethod_contract= df_telecom_X.groupby(['churn','contract'])[['PaymentMethod']].value_counts()
df_churn_telecomX_PaymentMethod_contract
# Out:
# churn  contract        PaymentMethod
#        Month-to-month  Electronic check              65
#                        Mailed check                  32
#                        Bank transfer (automatic)     19
#                        Credit card (automatic)       14
#        One year        Credit card (automatic)       15
#                        Electronic check              12
#                        Bank transfer (automatic)     10
#                        Mailed check                   9
#        Two year        Credit card (automatic)       17
#                        Bank transfer (automatic)     16
#                        Mailed check                  12
#                        Electronic check               3
# No     Month-to-month  Electronic check             856
#                        Mailed check                 611
#                        Bank transfer (automatic)    388
#                        Credit card (automatic)      365
#        One year        Credit card (automatic)      357
#                        Bank transfer (automatic)    353
#                        Mailed check                 314
#                        Electronic check             283
#        Two year        Credit card (automatic)      568
#                        Bank transfer (automatic)    545
#                        Mailed check                 379
#                        Electronic check             155
# Yes    Month-to-month  Electronic check             994
#                        Mailed check                 282
#                        Bank transfer (automatic)    201
#                        Credit card (automatic)      178
#        One year        Electronic check              64
#                        Credit card (automatic)       41
#                        Bank transfer (automatic)     38
#                        Mailed check                  23
#        Two year        Bank transfer (automatic)     19
#                        Credit card (automatic)       13
#                        Electronic check              13
#                        Mailed check                   3
# Name: count, dtype: int64

# %% [markdown]
# #####**Churn,gender y PaymentMethod**

# %%
df_churn_telecomX_PaymentMethod_contract= df_telecom_X.groupby(['churn','gender'])[['PaymentMethod']].value_counts()
df_churn_telecomX_PaymentMethod_contract
# Out:
# churn  gender  PaymentMethod
#        Female  Electronic check              35
#                Bank transfer (automatic)     25
#                Credit card (automatic)       22
#                Mailed check                  22
#        Male    Electronic check              45
#                Mailed check                  31
#                Credit card (automatic)       24
#                Bank transfer (automatic)     20
# No     Female  Bank transfer (automatic)    652
#                Electronic check             648
#                Mailed check                 628
#                Credit card (automatic)      621
#        Male    Mailed check                 676
#                Credit card (automatic)      669
#                Electronic check             646
#                Bank transfer (automatic)    634
# Yes    Female  Electronic check             522
#                Mailed check                 150
#                Bank transfer (automatic)    136
#                Credit card (automatic)      131
#        Male    Electronic check             549
#                Mailed check                 158
#                Bank transfer (automatic)    122
#                Credit card (automatic)      101
# Name: count, dtype: int64

# %% [markdown]
# #####**Churn,contract,gender y PaymentMethod**

# %%
df_churn_telecomX_PaymentMethod_contract_gender= df_telecom_X.groupby(['churn','gender','contract'])[['PaymentMethod']].value_counts()
df_churn_telecomX_PaymentMethod_contract_gender
# Out:
# churn  gender  contract        PaymentMethod
#        Female  Month-to-month  Electronic check             28
#                                Mailed check                 13
#                                Bank transfer (automatic)    10
#                                Credit card (automatic)       6
#                One year        Credit card (automatic)       8
#                                                             ..
# Yes    Male    One year        Mailed check                 10
#                Two year        Bank transfer (automatic)    12
#                                Credit card (automatic)       7
#                                Electronic check              6
#                                Mailed check                  1
# Name: count, Length: 72, dtype: int64

# %%
df_churn_telecomX_PaymentMethod_contract_gender.plot(kind='bar', figsize=(10, 5), title='Churn Count,gender, contract by PaymentMethod', xlabel='Contract Type, gender, contract and PaymentMethod', ylabel='Count')
# Out:
# <Axes: title={'center': 'Churn Count,gender, contract by PaymentMethod'}, xlabel='Contract Type, gender, contract and PaymentMethod', ylabel='Count'>

# %% [markdown]
# ####**churn and (Internet data + phone_service)**

# %%
df_churn_telecomX_internet_data= df_telecom_X.groupby(['churn','InternetService', 'contract'])[['OnlineSecurity', 'OnlineBackup',
       'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies','phone_service']].count()
df_churn_telecomX_internet_data
# Out:
#                                       OnlineSecurity  OnlineBackup  \
# churn InternetService contract
#       DSL             Month-to-month              38            38
#                       One year                    16            16
#                       Two year                    13            13
#       Fiber optic     Month-to-month              71            71
#                       One year                    21            21
#                       Two year                    10            10
#       No              Month-to-month              21            21
#                       One year                     9             9
#                       Two year                    25            25
# No    DSL             Month-to-month             829           829
#                       One year                   517           517
#                       Two year                   616           616
#       Fiber optic     Month-to-month             966           966
#                       One year                   435           435
#                       Two year                   398           398
#       No              Month-to-month             425           425
#                       One year                   355           355
#                       Two year                   633           633
# Yes   DSL             Month-to-month             394           394
#                       One year                    53            53
#                       Two year                    12            12
#       Fiber optic     Month-to-month            1162          1162
#                       One year                   104           104
#                       Two year                    31            31
#       No              Month-to-month              99            99
#                       One year                     9             9
#                       Two year                     5             5
#
#                                       DeviceProtection  TechSupport  \
# churn InternetService contract
#       DSL             Month-to-month                38           38
#                       One year                      16           16
#                       Two year                      13           13
#       Fiber optic     Month-to-month                71           71
#                       One year                      21           21
#                       Two year                      10           10
#       No              Month-to-month                21           21
#                       One year                       9            9
#                       Two year                      25           25
# No    DSL             Month-to-month               829          829
#                       One year                     517          517
#                       Two year                     616          616
#       Fiber optic     Month-to-month               966          966
#                       One year                     435          435
#                       Two year                     398          398
#       No              Month-to-month               425          425
#                       One year                     355          355
#                       Two year                     633          633
# Yes   DSL             Month-to-month               394          394
#                       One year                      53           53
#                       Two year                      12           12
#       Fiber optic     Month-to-month              1162         1162
#                       One year                     104          104
#                       Two year                      31           31
#       No              Month-to-month                99           99
#                       One year                       9            9
#                       Two year                       5            5
#
#                                       StreamingTV  StreamingMovies  \
# churn InternetService contract
#       DSL             Month-to-month           38               38
#                       One year                 16               16
#                       Two year                 13               13
#       Fiber optic     Month-to-month           71               71
#                       One year                 21               21
#                       Two year                 10               10
#       No              Month-to-month           21               21
#                       One year                  9                9
#                       Two year                 25               25
# No    DSL             Month-to-month          829              829
#                       One year                517              517
#                       Two year                616              616
#       Fiber optic     Month-to-month          966              966
#                       One year                435              435
#                       Two year                398              398
#       No              Month-to-month          425              425
#                       One year                355              355
#                       Two year                633              633
# Yes   DSL             Month-to-month          394              394
#                       One year                 53               53
#                       Two year                 12               12
#       Fiber optic     Month-to-month         1162             1162
#                       One year                104              104
#                       Two year                 31               31
#       No              Month-to-month           99               99
#                       One year                  9                9
#                       Two year                  5                5
#
#                                       phone_service
# churn InternetService contract
#       DSL             Month-to-month             38
#                       One year                   16
#                       Two year                   13
#       Fiber optic     Month-to-month             71
#                       One year                   21
#                       Two year                   10
#       No              Month-to-month             21
#                       One year                    9
#                       Two year                   25
# No    DSL             Month-to-month            829
#                       One year                  517
#                       Two year                  616
#       Fiber optic     Month-to-month            966
#                       One year                  435
#                       Two year                  398
#       No              Month-to-month            425
#                       One year                  355
#                       Two year                  633
# Yes   DSL             Month-to-month            394
#                       One year                   53
#                       Two year                   12
#       Fiber optic     Month-to-month           1162
#                       One year                  104
#                       Two year                   31
#       No              Month-to-month             99
#                       One year                    9
#                       Two year                    5

# %%
df_churn_telecomX_internet_data1= df_telecom_X.groupby(['InternetService', 'contract','OnlineSecurity', 'OnlineBackup',
       'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies','phone_service','churn'])[['customerid']].count()
df_churn_telecomX_internet_data1
# Out:
#                                                                                                                                                                             customerid
# InternetService contract       OnlineSecurity      OnlineBackup        DeviceProtection    TechSupport         StreamingTV         StreamingMovies     phone_service churn
# DSL             Month-to-month No                  No                  No                  No                  No                  No                  No                            1
#                                                                                                                                                                      No             41
#                                                                                                                                                                      Yes            34
#                                                                                                                                                        Yes                           9
#                                                                                                                                                                      No            119
# ...                                                                                                                                                                                ...
# No              One year       No internet service No internet service No internet service No internet service No internet service No internet service Yes           No            355
#                                                                                                                                                                      Yes             9
#                 Two year       No internet service No internet service No internet service No internet service No internet service No internet service Yes                          25
#                                                                                                                                                                      No            633
#                                                                                                                                                                      Yes             5
#
# [857 rows x 1 columns]

# %%
# @title OnlineSecurity

from matplotlib import pyplot as plt
df_churn_telecomX_internet_data['OnlineSecurity'].plot(kind='hist', bins=20, title='OnlineSecurity')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df_telecom_X.columns
# Out:
# Index(['customerid', 'churn', 'customer', 'phone', 'internet', 'account',
#        'gender', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'phone_service', 'contract', 'paperless_billing', 'PaymentMethod',
#        'charges.monthly', 'charges.total', 'contract_in_numbers',
#        'cuentas_diarias'],
#       dtype='object')

# %% [markdown]
# ###**charges and churn**

# %%
df_analizer_0 = df_telecom_X[df_telecom_X['churn'] == 'No']
df_analizer_T = df_telecom_X[df_telecom_X['churn'] == 'Yes']
df_analizer_0
# Out:
#       customerid churn                                           customer  \
# 4988  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7090  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 579   0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 434   0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7233  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# ...          ...   ...                                                ...
# 7215  9924-JPRMC    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 4366  5989-AXPUC    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4182  5734-EJKXG    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6537  8984-HPEMB    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5523  7569-NMZYQ    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                 phone  \
# 4988   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7090   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 579    {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 434    {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7233   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                               ...
# 7215  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 4366  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 4182  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 6537  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 5523  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                                internet  \
# 4988  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 7090  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 579   {'InternetService': 'No', 'OnlineSecurity': 'N...
# 434   {'InternetService': 'No', 'OnlineSecurity': 'N...
# 7233  {'InternetService': 'No', 'OnlineSecurity': 'N...
# ...                                                 ...
# 7215  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4366  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4182  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 6537  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 5523  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                                 account  gender  \
# 4988  {'Contract': 'One year', 'PaperlessBilling': '...    Male
# 7090  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 579   {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 434   {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 7233  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# ...                                                 ...     ...
# 7215  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 4366  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 4182  {'Contract': 'One year', 'PaperlessBilling': '...  Female
# 6537  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 5523  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
#
#      InternetService       OnlineSecurity         OnlineBackup  ...  \
# 4988              No  No internet service  No internet service  ...
# 7090              No  No internet service  No internet service  ...
# 579               No  No internet service  No internet service  ...
# 434               No  No internet service  No internet service  ...
# 7233              No  No internet service  No internet service  ...
# ...              ...                  ...                  ...  ...
# 7215     Fiber optic                  Yes                  Yes  ...
# 4366     Fiber optic                  Yes                  Yes  ...
# 4182     Fiber optic                  Yes                  Yes  ...
# 6537     Fiber optic                  Yes                  Yes  ...
# 5523     Fiber optic                  Yes                  Yes  ...
#
#               StreamingTV      StreamingMovies phone_service  contract  \
# 4988  No internet service  No internet service           Yes  One year
# 7090  No internet service  No internet service           Yes  Two year
# 579   No internet service  No internet service           Yes  Two year
# 434   No internet service  No internet service           Yes  Two year
# 7233  No internet service  No internet service           Yes  Two year
# ...                   ...                  ...           ...       ...
# 7215                  Yes                  Yes           Yes  Two year
# 4366                  Yes                  Yes           Yes  Two year
# 4182                  Yes                  Yes           Yes  One year
# 6537                  Yes                  Yes           Yes  Two year
# 5523                  Yes                  Yes           Yes  Two year
#
#      paperless_billing              PaymentMethod charges.monthly  \
# 4988                No    Credit card (automatic)           18.25
# 7090                No  Bank transfer (automatic)           18.40
# 579                Yes    Credit card (automatic)           18.55
# 434                 No               Mailed check           18.70
# 7233               Yes               Mailed check           18.70
# ...                ...                        ...             ...
# 7215               Yes           Electronic check          118.20
# 4366                No               Mailed check          118.60
# 4182               Yes           Electronic check          118.60
# 6537               Yes           Electronic check          118.65
# 5523               Yes  Bank transfer (automatic)          118.75
#
#      charges.total  contract_in_numbers  cuentas_diarias
# 4988        534.70                   12         0.608333
# 7090       1057.85                   24         0.613333
# 579         689.00                   24         0.618333
# 434        1005.70                   24         0.623333
# 7233        383.65                   24         0.623333
# ...            ...                  ...              ...
# 7215       8547.15                   24         3.940000
# 4366       7990.05                   24         3.953333
# 4182       7365.70                   12         3.953333
# 6537       8477.60                   24         3.955000
# 5523       8672.45                   24         3.958333
#
# [5174 rows x 22 columns]

# %%
df_analizer_T
# Out:
#       customerid churn                                           customer  \
# 6759  9318-NKNFC   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 6559  9025-ZRPVR   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 861   1218-VKFPE   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4463  6121-VZNQB   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4026  5510-BOIUJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# ...          ...   ...                                                ...
# 1027  1444-VVSGW   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 6581  9053-JZFKV   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 1620  2302-ANTDP   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 2053  2889-FPWRM   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 5998  8199-ZLLSA   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                 phone  \
# 6759   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 6559   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 861    {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4463   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4026   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                               ...
# 1027  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 6581  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 1620  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2053  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 5998  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                                internet  \
# 6759  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 6559  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 861   {'InternetService': 'No', 'OnlineSecurity': 'N...
# 4463  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 4026  {'InternetService': 'No', 'OnlineSecurity': 'N...
# ...                                                 ...
# 1027  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 6581  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 1620  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 2053  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 5998  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                                 account  gender  \
# 6759  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 6559  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 861   {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
# 4463  {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
# 4026  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# ...                                                 ...     ...
# 1027  {'Contract': 'One year', 'PaperlessBilling': '...    Male
# 6581  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 1620  {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
# 2053  {'Contract': 'One year', 'PaperlessBilling': '...    Male
# 5998  {'Contract': 'One year', 'PaperlessBilling': '...    Male
#
#      InternetService       OnlineSecurity         OnlineBackup  ...  \
# 6759              No  No internet service  No internet service  ...
# 6559              No  No internet service  No internet service  ...
# 861               No  No internet service  No internet service  ...
# 4463              No  No internet service  No internet service  ...
# 4026              No  No internet service  No internet service  ...
# ...              ...                  ...                  ...  ...
# 1027     Fiber optic                  Yes                  Yes  ...
# 6581     Fiber optic                  Yes                  Yes  ...
# 1620     Fiber optic                  Yes                  Yes  ...
# 2053     Fiber optic                  Yes                  Yes  ...
# 5998     Fiber optic                  Yes                  Yes  ...
#
#               StreamingTV      StreamingMovies phone_service        contract  \
# 6759  No internet service  No internet service           Yes  Month-to-month
# 6559  No internet service  No internet service           Yes  Month-to-month
# 861   No internet service  No internet service           Yes  Month-to-month
# 4463  No internet service  No internet service           Yes  Month-to-month
# 4026  No internet service  No internet service           Yes  Month-to-month
# ...                   ...                  ...           ...             ...
# 1027                  Yes                  Yes           Yes        One year
# 6581                  Yes                  Yes           Yes        Two year
# 1620                  Yes                  Yes           Yes  Month-to-month
# 2053                  Yes                  Yes           Yes        One year
# 5998                  Yes                  Yes           Yes        One year
#
#      paperless_billing              PaymentMethod charges.monthly  \
# 6759               Yes               Mailed check           18.85
# 6559               Yes               Mailed check           18.95
# 861                 No               Mailed check           19.00
# 4463               Yes               Mailed check           19.10
# 4026                No               Mailed check           19.25
# ...                ...                        ...             ...
# 1027                No    Credit card (automatic)          115.65
# 6581                No    Credit card (automatic)          116.20
# 1620                No           Electronic check          117.45
# 2053               Yes  Bank transfer (automatic)          117.80
# 5998               Yes  Bank transfer (automatic)          118.35
#
#      charges.total  contract_in_numbers  cuentas_diarias
# 6759         18.85                    1         0.628333
# 6559        185.60                    1         0.631667
# 861         233.55                    1         0.633333
# 4463         19.10                    1         0.636667
# 4026         19.25                    1         0.641667
# ...            ...                  ...              ...
# 1027       7968.85                   12         3.855000
# 6581       7752.30                   24         3.873333
# 1620       5438.90                    1         3.915000
# 2053       8684.80                   12         3.926667
# 5998       7804.15                   12         3.945000
#
# [1869 rows x 22 columns]

# %% [markdown]
# #####**Churn, contract y charges.monthly  **

# %%
df_churn_telecomX_monthly= df_telecom_X.groupby(['churn' , 'contract'])[['charges.monthly']].count()
df_churn_telecomX_monthly
# Out:
#                       charges.monthly
# churn contract
#       Month-to-month              130
#       One year                     46
#       Two year                     48
# No    Month-to-month             2220
#       One year                   1307
#       Two year                   1647
# Yes   Month-to-month             1655
#       One year                    166
#       Two year                     48

# %% [markdown]
# ######**charges.monthly _ apply analize1**

# %%
df_analize1 = df_churn_telecomX_monthly.loc[('No', slice(None)), :]
df_analize1
# Out:
#                       charges.monthly
# churn contract
# No    Month-to-month             2220
#       One year                   1307
#       Two year                   1647

# %%
df_analize1.plot(kind='bar', figsize=(10, 5), title='Churn by montly.charges', xlabel='Contract Type and Churn', ylabel='charges.monthly')
# Out:
# <Axes: title={'center': 'Churn by montly.charges'}, xlabel='Contract Type and Churn', ylabel='charges.monthly'>

# %% [markdown]
# ######**charges.monthly _ apply analize2**

# %%
df_analize2 = df_churn_telecomX_monthly.loc[('Yes', slice(None)), :]
df_analize2
# Out:
#                       charges.monthly
# churn contract
# Yes   Month-to-month             1655
#       One year                    166
#       Two year                     48

# %%
df_analize1.plot(kind='bar', figsize=(10, 5), title='Churn by montly.charges', xlabel='Contract Type and Churn', ylabel='charges.monthly')
# Out:
# <Axes: title={'center': 'Churn by montly.charges'}, xlabel='Contract Type and Churn', ylabel='charges.monthly'>

# %%
from matplotlib import pyplot as plt
df_churn_telecomX_monthly['charges.monthly'].plot(kind='hist', bins=20, title='charges.monthly')
plt.gca().spines[['top', 'right',]].set_visible(True)

# %%
from matplotlib import pyplot as plt
df_churn_telecomX_monthly['charges.monthly'].plot(kind='line', figsize=(15, 4), title='charges.monthly')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df_churn_telecomX_monthly.plot(kind='bar', figsize=(10, 7), title='Churn Count by Churn Status', xlabel='Churn Status', ylabel='charges.monthly')
# Out:
# <Axes: title={'center': 'Churn Count by Churn Status'}, xlabel='Churn Status', ylabel='charges.monthly'>

# %% [markdown]
# #####**Churn, contract y charges.total  **

# %%
df_churn_telecomX_total= df_telecom_X.groupby(['churn' , 'contract'])[['charges.total']].count()
df_churn_telecomX_total
# Out:
#                       charges.total
# churn contract
#       Month-to-month            130
#       One year                   46
#       Two year                   48
# No    Month-to-month           2220
#       One year                 1307
#       Two year                 1647
# Yes   Month-to-month           1655
#       One year                  166
#       Two year                   48

# %%
df_churn_telecomX_total.plot(kind='bar', figsize=(12, 8), title='Churn Count by Contract Type and Churn Status charges.total', xlabel='Churn Status and Contract Type', ylabel='Charges.Total')
# Out:
# <Axes: title={'center': 'Churn Count by Contract Type and Churn Status charges.total'}, xlabel='Churn Status and Contract Type', ylabel='Charges.Total'>

# %% [markdown]
# ######**charges.total _ apply analize3**

# %%
df_analize3 = df_churn_telecomX_total.loc[('No', slice(None)), :]
df_analize3
# Out:
#                       charges.total
# churn contract
# No    Month-to-month           2220
#       One year                 1307
#       Two year                 1647

# %%
# @title charges.total

from matplotlib import pyplot as plt
df_analize3['charges.total'].plot(kind='line', figsize=(8, 4), title='charges.total')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ######**charges.total _ apply analize4**

# %%
df_analize4 = df_churn_telecomX_total.loc[('Yes', slice(None)), :]
df_analize4
# Out:
#                       charges.total
# churn contract
# Yes   Month-to-month           1655
#       One year                  166
#       Two year                   48

# %%
# @title charges.total

from matplotlib import pyplot as plt
df_analize4['charges.total'].plot(kind='line', figsize=(8, 4), title='charges.total')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# #####**Churn, contract y cuentas_diarias**

# %%
df_churn_telecomX_cuentas_diarias= df_telecom_X.groupby(['churn' , 'contract'])[['cuentas_diarias']].count()
df_churn_telecomX_cuentas_diarias
# Out:
#                       cuentas_diarias
# churn contract
#       Month-to-month              130
#       One year                     46
#       Two year                     48
# No    Month-to-month             2220
#       One year                   1307
#       Two year                   1647
# Yes   Month-to-month             1655
#       One year                    166
#       Two year                     48

# %%
# @title cuentas_diarias

from matplotlib import pyplot as plt
df_churn_telecomX_cuentas_diarias['cuentas_diarias'].plot(kind='line', figsize=(16, 4), title='cuentas_diarias')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ######**cuentas_diarias _ apply analize5**

# %%
df_analize5 = df_churn_telecomX_cuentas_diarias.loc[('No', slice(None)), :]
df_analize5
# Out:
#                       cuentas_diarias
# churn contract
# No    Month-to-month             2220
#       One year                   1307
#       Two year                   1647

# %%
# @title cuentas_diarias

from matplotlib import pyplot as plt
df_analize5['cuentas_diarias'].plot(kind='line', figsize=(8, 4), title='cuentas_diarias')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ######**cuentas_diarias_ apply analize6**

# %%
df_analize6 = df_churn_telecomX_cuentas_diarias.loc[('Yes', slice(None)), :]
df_analize6
# Out:
#                       cuentas_diarias
# churn contract
# Yes   Month-to-month             1655
#       One year                    166
#       Two year                     48

# %%
# @title charges.total

from matplotlib import pyplot as plt
df_analize6['cuentas_diarias'].plot(kind='line', figsize=(8, 4), title='cuentas_diarias / Yes')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# #####**Churn, contract y phone_service**

# %%
df_churn_telecomX_phone_service= df_telecom_X.groupby(['phone_service', 'contract'])[['churn']].count()
df_churn_telecomX_phone_service
# Out:
#                               churn
# phone_service contract
# No            Month-to-month    392
#               One year          149
#               Two year          166
# Yes           Month-to-month   3613
#               One year         1370
#               Two year         1577

# %% [markdown]
# ####**Resumido Churn  **

# %%
# @title Texto de título predeterminado
df_churn_telecomX_resumido= df_telecom_X.groupby(['contract'])[['churn','gender','charges.monthly','charges.total','cuentas_diarias','phone_service']].value_counts()
df_churn_telecomX_resumido
# Out:
# contract        churn  gender  charges.monthly  charges.total  cuentas_diarias  phone_service
# Month-to-month  No     Male    19.75            19.75          0.658333         Yes              5
#                                20.05            20.05          0.668333         Yes              5
#                        Female  19.55            19.55          0.651667         Yes              4
#                        Male    19.20            19.20          0.640000         Yes              4
#                                20.20            20.20          0.673333         Yes              4
#                                                                                                 ..
# Two year        Yes    Male    109.75           6110.20        3.658333         Yes              1
#                                110.00           7611.85        3.666667         Yes              1
#                                111.60           6876.05        3.720000         Yes              1
#                                113.15           7856.00        3.771667         Yes              1
#                                116.20           7752.30        3.873333         Yes              1
# Name: count, Length: 7159, dtype: int64

# %% [markdown]
# ###**Totales **

# %% [markdown]
# ####**count churn**

# %%
df_telecom_X_count=df_telecom_X.count()
df_telecom_X_count
# Out:
# customerid             7267
# churn                  7267
# customer               7267
# phone                  7267
# internet               7267
# account                7267
# gender                 7267
# InternetService        7267
# OnlineSecurity         7267
# OnlineBackup           7267
# DeviceProtection       7267
# TechSupport            7267
# StreamingTV            7267
# StreamingMovies        7267
# phone_service          7267
# contract               7267
# paperless_billing      7267
# PaymentMethod          7267
# charges.monthly        7267
# charges.total          7267
# contract_in_numbers    7267
# cuentas_diarias        7267
# dtype: int64

# %%
df_churn_X_count1=df_telecom_X['churn'].value_counts()
df_churn_X_count1
# Out:
# churn
# No     5174
# Yes    1869
#         224
# Name: count, dtype: int64

# %%
df_gender_X_count=df_telecom_X['gender'].value_counts()
df_gender_X_count
# Out:
# gender
# Male      3675
# Female    3592
# Name: count, dtype: int64

# %%
df_phone_X_count=df_telecom_X['phone_service'].value_counts()
df_phone_X_count
# Out:
# phone_service
# Yes    6560
# No      707
# Name: count, dtype: int64

# %%
df_contract_X_count=df_telecom_X['contract'].value_counts()
df_contract_X_count
# Out:
# contract
# Month-to-month    4005
# Two year          1743
# One year          1519
# Name: count, dtype: int64

# %%
df_paymentMethod_X_count=df_telecom_X['PaymentMethod'].value_counts()
df_paymentMethod_X_count
# Out:
# PaymentMethod
# Electronic check             2445
# Mailed check                 1665
# Bank transfer (automatic)    1589
# Credit card (automatic)      1568
# Name: count, dtype: int64

# %%
df_InternetService_X_count=df_telecom_X['InternetService'].value_counts()
df_InternetService_X_count
# Out:
# InternetService
# Fiber optic    3198
# DSL            2488
# No             1581
# Name: count, dtype: int64

# %% [markdown]
# #####**Creando Tabla**

# %%
summary_data1 = {'Metric': ['churn', 'gender', 'contract','phone_service','PaymentMethod','InternetService'],
                'Value': [df_churn_X_count1, df_gender_X_count, df_contract_X_count, df_phone_X_count, df_paymentMethod_X_count, df_InternetService_X_count]}
df_summary_no_numeric = pd.DataFrame(summary_data1)
display(df_summary_no_numeric)
# Out:
#             Metric                                              Value
# 0            churn  churn
# No     5174
# Yes    1869
#         224
# Name...
# 1           gender  gender
# Male      3675
# Female    3592
# Name: cou...
# 2         contract  contract
# Month-to-month    4005
# Two year      ...
# 3    phone_service  phone_service
# Yes    6560
# No      707
# Name: co...
# 4    PaymentMethod  PaymentMethod
# Electronic check             244...
# 5  InternetService  InternetService
# Fiber optic    3198
# DSL       ...
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['Value'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Metric').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_2.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Metric')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Metric', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_4['Metric'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_4, x='index', y='Metric', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_4['Metric'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_4, x='index', y='Metric', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# /tmp/ipython-input-1903320918.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(_df_4, x='index', y='Metric', inner='stick', palette='Dark2')

# %% [markdown]
# ####**Suma Valores Numericos**

# %%
df_churn_telecomX_resumido.to_json('telecom_X_resumido.json')

# %% [markdown]
# #####**sumas de valores numericos **

# %%
df_sum_monthly= df_telecom_X['charges.monthly'].sum()
df_sum_monthly
# Out:
# np.float64(470320.94999999995)

# %%
# Ensure 'charges.total' is numeric after filling nulls
df_telecom_X['charges.total'] = pd.to_numeric(df_telecom_X['charges.total'], errors='coerce').fillna(0).astype(float)

df_sum = df_telecom_X['charges.total']
df_sum_total= df_sum.sum()
df_sum_total
# Out:
# np.float64(16548281.85)

# %%
df_sum_cuentas_diarias= df_telecom_X['cuentas_diarias'].sum()
df_sum_cuentas_diarias
# Out:
# np.float64(15677.364999999998)

# %%
df_sum_total_contrato= df_telecom_X['total_contracto'].sum()
df_sum_total_contrato
# Out:
# np.float64(215654844.9)

# %%
summary_data = {'Metric': ['Sum Monthly Charges', 'Sum Total Charges', 'Sum Daily Accounts', 'total_contracto'],
                'Value': [df_sum_monthly, df_sum_total, df_sum_cuentas_diarias, df_sum_total_contrato]}
df_summary = pd.DataFrame(summary_data)
display(df_summary)
# Out:
#                 Metric         Value
# 0  Sum Monthly Charges  4.703209e+05
# 1    Sum Total Charges  1.654828e+07
# 2   Sum Daily Accounts  1.567736e+04
# 3      total_contracto  2.156548e+08

# %%
# @title Metric

from matplotlib import pyplot as plt
import seaborn as sns
df_summary.groupby(['Metric','Value']).size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(True)

# %% [markdown]
# #**Guardar _ Telecom_X**

# %%
df_telecom_X.to_json('telecom_X_final_1.json')

# %%
pd.read_json('telecom_X_final_1.json').head()
# Out:
#       customerid churn                                           customer  \
# 4988  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7090  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 579   0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 434   0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7233  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                phone  \
# 4988  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7090  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 579   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 434   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7233  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                                internet  \
# 4988  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 7090  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 579   {'InternetService': 'No', 'OnlineSecurity': 'N...
# 434   {'InternetService': 'No', 'OnlineSecurity': 'N...
# 7233  {'InternetService': 'No', 'OnlineSecurity': 'N...
#
#                                                 account  gender  \
# 4988  {'Contract': 'One year', 'PaperlessBilling': '...    Male
# 7090  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 579   {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 434   {'Contract': 'Two year', 'PaperlessBilling': '...  Female
# 7233  {'Contract': 'Two year', 'PaperlessBilling': '...  Female
#
#      InternetService       OnlineSecurity         OnlineBackup  ...  \
# 4988              No  No internet service  No internet service  ...
# 7090              No  No internet service  No internet service  ...
# 579               No  No internet service  No internet service  ...
# 434               No  No internet service  No internet service  ...
# 7233              No  No internet service  No internet service  ...
#
#           StreamingMovies phone_service  contract paperless_billing  \
# 4988  No internet service           Yes  One year                No
# 7090  No internet service           Yes  Two year                No
# 579   No internet service           Yes  Two year               Yes
# 434   No internet service           Yes  Two year                No
# 7233  No internet service           Yes  Two year               Yes
#
#                   PaymentMethod charges.monthly charges.total cuentas_diarias  \
# 4988    Credit card (automatic)           18.25        534.70        0.608333
# 7090  Bank transfer (automatic)           18.40       1057.85        0.613333
# 579     Credit card (automatic)           18.55        689.00        0.618333
# 434                Mailed check           18.70       1005.70        0.623333
# 7233               Mailed check           18.70        383.65        0.623333
#
#       Tiempo_de_Contrato  total_contracto
# 4988                  12           6416.4
# 7090                  24          25388.4
# 579                   24          16536.0
# 434                   24          24136.8
# 7233                  24           9207.6
#
# [5 rows x 23 columns]

# %% [markdown]
# #📄Informe final

# %% [markdown]
# 🔹 Introducción: Explica el objetivo del análisis y el problema de evasión de clientes (Churn).
#
# **Mision**:
# proyecto "Churn de Clientes". La empresa enfrenta una alta tasa de cancelaciones y necesita comprender los factores que llevan a la pérdida de clientes.
#
# Tu desafío será recopilar, procesar y analizar los datos, utilizando Python y sus principales bibliotecas para extraer información valiosa. A partir de tu análisis, el equipo de Data Science podrá avanzar en modelos predictivos y desarrollar estrategias para reducir la evasión.
#
# Tu eres el **asistente de análisis de datos en Telecom X**
#
# > Telecom_X
#
#
#
# # Telecom X - Análisis de Evasión de Clientes

# %% [markdown]
# # **Limpieza y Tratamiento de Datos**: Describe los pasos realizados para importar, limpiar y procesar los datos.
#
# 1. se determina que tipo de archivo son los dos archivos que proporcionan, el del cuaderno de colab, y el de la base de datos, que es .json.
# 2.se carga al cuaderno en colab o a un drive.
# 3. se importa pandas y se lee el archivo json con su instruccion correspondiente.
# 4. luego se guarda en una variable tipo dataframe, llamada: df_telecom_X.
# 5. se accede al dataframe de la base de datos df_telecom_X.
# 6. se determina si hay listas o diccionarios.
# 7. se normaliza las columnas tipo diccionarios.
# 8. se escribe este nuevo dataframe, 'columna normalizada ', en un nuevo archivo .json.

# %% [markdown]
# instrucciones utilizadas:
#
# *   Elemento de la lista
#
# *   Elemento de la lista
#
# *   Elemento de la lista
#
# *   Elemento de la lista
#
# *   Elemento de la lista
# *   Elemento de la lista
#
#
# *   Elemento de la lista
#
#
# *   Elemento de la lista
#
#
# *   Elemento de la lista
#
#
# *   Elemento de la lista
