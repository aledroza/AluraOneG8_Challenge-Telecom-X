# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# %%
url='https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json'
df_telecom_X=pd.read_json(url)
df_telecom_X
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
df_telecom_X.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df_telecom_X.tail()
# Out:
#       customerID Churn                                           customer  \
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df_telecom_X.head(10)
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 5  0013-MHZWF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6  0013-SMEOE    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 7  0014-BMAQU    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 8  0015-UOCOJ    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 9  0016-QLJIS    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# ...

# %%
df_telecom_X.sample(10)
# Out:
#       customerID Churn                                           customer  \
# 2150  3007-FDPEA    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4371  5995-LFTLE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3864  5294-DMSFH    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6914  9526-BIHHD   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2001  2830-LEWOA    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7037  9693-XMUOB    No  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 755   1084-MNSMJ    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4435  6078-VESFR    No  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 2014  2845-AFFTX   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4532  6211-WWLTF    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 2150     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...

# %%
type(df_telecom_X)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Normalizando los dicionarios en Json

# %%
df_normalized_customer = pd.json_normalize(df_telecom_X['customer'])
df_normalized_customer
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
df_normalized_phone = pd.json_normalize(df_telecom_X['phone'])
df_normalized_phone
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
df_normalized_internet = pd.json_normalize(df_telecom_X['internet'])
df_normalized_internet
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# ...

# %%
df_normalized_account = pd.json_normalize(df_telecom_X['account'])
df_normalized_account
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# ...

# %% [markdown]
# #### ESCRIBIENDO JSON NORMALIZADO

# %%
df_normalized_customer.to_json('telecom_X_customer_normalizado.json')
df_normalized_phone.to_json('telecom_X_phone_normalizado.json')
df_normalized_internet.to_json('telecom_X_internet_normalizado.json')
df_normalized_account.to_json('telecom_X_account_normalizado.json')

# %%
pd.read_json('telecom_X_customer_normalizado.json')
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
pd.read_json('telecom_X_phone_normalizado.json')
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
pd.read_json('telecom_X_internet_normalizado.json')
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# ...

# %%
pd.read_json('telecom_X_account_normalizado.json')
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# ...

# %%
df_telecom_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# ###**Conociendo los Datos**

# %% [markdown]
# ####**Tipo Dataframe**

# %%
df_telecom_X.dtypes
# Out:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %%
df_normalized_customer.dtypes
# Out:
# gender           object
# SeniorCitizen     int64
# Partner          object
# Dependents       object
# tenure            int64
# dtype: object

# %%
df_normalized_phone.dtypes
# Out:
# PhoneService     object
# MultipleLines    object
# dtype: object

# %%
df_normalized_internet.dtypes
# Out:
# InternetService     object
# OnlineSecurity      object
# OnlineBackup        object
# DeviceProtection    object
# TechSupport         object
# StreamingTV         object
# StreamingMovies     object
# dtype: object

# %%
df_normalized_account.dtypes
# Out:
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Charges.Monthly     float64
# Charges.Total        object
# dtype: object

# %% [markdown]
# ####**Info de los dataframe**

# %%
df_telecom_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
df_normalized_account.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contract          7267 non-null   object
#  1   PaperlessBilling  7267 non-null   object
#  2   PaymentMethod     7267 non-null   object
#  3   Charges.Monthly   7267 non-null   float64
#  4   Charges.Total     7267 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 284.0+ KB

# %%
df_normalized_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         7267 non-null   object
#  1   SeniorCitizen  7267 non-null   int64
#  2   Partner        7267 non-null   object
#  3   Dependents     7267 non-null   object
#  4   tenure         7267 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 284.0+ KB

# %%
df_normalized_internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   InternetService   7267 non-null   object
#  1   OnlineSecurity    7267 non-null   object
#  2   OnlineBackup      7267 non-null   object
#  3   DeviceProtection  7267 non-null   object
#  4   TechSupport       7267 non-null   object
#  5   StreamingTV       7267 non-null   object
#  6   StreamingMovies   7267 non-null   object
# dtypes: object(7)
# memory usage: 397.5+ KB

# %%
df_normalized_phone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PhoneService   7267 non-null   object
#  1   MultipleLines  7267 non-null   object
# dtypes: object(2)
# memory usage: 113.7+ KB

# %%
df_telecom_X.describe()
# Out:
#         customerID Churn                                           customer  \
# count         7267  7267                                               7267
# unique        7267     3                                                891
# top     9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# freq             1  5174                                                223
#
#                                                  phone  \
# count                                             7267
# unique                                               3
# top     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# freq                                              3495
#
#                                                  internet  \
# count                                                7267
# unique                                                129
# top     {'InternetService': 'No', 'OnlineSecurity': 'N...
# freq                                                 1581
#
# ...

# %% [markdown]
# ####**Filas y columnas en los dataframe**

# %%
df_telecom_X.shape
# Out:
# (7267, 23)

# %%
df_normalized_customer.shape
# Out:
# (7267, 5)

# %%
df_normalized_phone.shape
# Out:
# (7267, 2)

# %%
df_normalized_internet.shape
# Out:
# (7267, 7)

# %%
df_normalized_account.shape
# Out:
# (7267, 5)

# %% [markdown]
# ####**cuales son las columnas en los dataframe**
#
#
# ---

# %%
df1= df_telecom_X.columns
df1
# Out:
# Index(['customerid', 'churn', 'customer', 'phone', 'internet', 'account',
#        'gender', 'internetservice', 'onlinesecurity', 'onlinebackup',
#        'deviceprotection', 'techsupport', 'streamingtv', 'streamingmovies',
#        'phone_service', 'contract', 'paperless_billing', 'paymentmethod',
#        'charges.monthly', 'charges.total', 'Tiempo_de_Contrato',
#        'cuentas_diarias', 'total_contracto'],
#       dtype='object')

# %%
df2=df_normalized_customer.columns
df2
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure'], dtype='object')

# %%
df3= df_normalized_phone.columns
df3
# Out:
# Index(['PhoneService', 'MultipleLines'], dtype='object')

# %%
df4= df_normalized_internet.columns
df4
# Out:
# Index(['InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies'],
#       dtype='object')

# %%
df5= df_normalized_account.columns
df5
# Out:
# Index(['Contract', 'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ####**Que hay en cada columna**

# %%
df_telecom_X['customerID']
# Out:
# 0       0002-ORFBO
# 1       0003-MKNFE
# 2       0004-TLHLJ
# 3       0011-IGKFF
# 4       0013-EXCHZ
#            ...
# 7262    9987-LUTYD
# 7263    9992-RRAMN
# 7264    9992-UJOEL
# 7265    9993-LHIEB
# 7266    9995-HOTOH
# Name: customerID, Length: 7267, dtype: object

# %%
df_telecom_X['Churn']
# Out:
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7262     No
# 7263    Yes
# 7264     No
# 7265     No
# 7266     No
# Name: Churn, Length: 7267, dtype: object

# %%
df_telecom_X['customer']
# Out:
# 0       {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1       {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2       {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3       {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4       {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#                               ...
# 7262    {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# Name: customer, Length: 7267, dtype: object

# %%
df_telecom_X['phone']
# Out:
# 0          {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1         {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2          {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3          {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4          {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#                               ...
# 7262       {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263      {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264       {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265       {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266    {'PhoneService': 'No', 'MultipleLines': 'No ph...
# Name: phone, Length: 7267, dtype: object

# %%
df_telecom_X['internet']
# Out:
# 0       {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1       {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2       {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3       {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4       {'InternetService': 'Fiber optic', 'OnlineSecu...
#                               ...
# 7262    {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263    {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264    {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265    {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266    {'InternetService': 'DSL', 'OnlineSecurity': '...
# Name: internet, Length: 7267, dtype: object

# %%
df_telecom_X['account']
# Out:
# 0       {'Contract': 'One year', 'PaperlessBilling': '...
# 1       {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2       {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3       {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4       {'Contract': 'Month-to-month', 'PaperlessBilli...
#                               ...
# 7262    {'Contract': 'One year', 'PaperlessBilling': '...
# 7263    {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264    {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265    {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266    {'Contract': 'Two year', 'PaperlessBilling': '...
# Name: account, Length: 7267, dtype: object

# %%
df_telecom_X[['customerID','Churn']]
# Out:
#       customerID Churn
# 0     0002-ORFBO    No
# 1     0003-MKNFE    No
# 2     0004-TLHLJ   Yes
# 3     0011-IGKFF   Yes
# 4     0013-EXCHZ   Yes
# ...          ...   ...
# 7262  9987-LUTYD    No
# 7263  9992-RRAMN   Yes
# 7264  9992-UJOEL    No
# 7265  9993-LHIEB    No
# 7266  9995-HOTOH    No
#
# [7267 rows x 2 columns]

# %% [markdown]
# ####**Valores no Repetidos**

# %%
customerID_unique=df_telecom_X['customerID'].unique()
customerID_unique
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'customerID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1560843352.py in <cell line: 0>()
# ----> 1 customerID_unique=df_telecom_X['customerID'].unique()
# ...

# %% [markdown]
# ####**Buscando Valores no Repetidos en la columna CustomerID, analizada**

# %%
df_telecom_X.query('@customerID_unique in customerID')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     230             if self.has_resolvers:
# --> 231                 return self.resolvers[key]
#     232
#
# /usr/lib/python3.11/collections/__init__.py in __getitem__(self, key)
#    1005                 pass
# -> 1006         return self.__missing__(key)            # support subclasses that define __missing__
#    1007
#
# /usr/lib/python3.11/collections/__init__.py in __missing__(self, key)
#     997     def __missing__(self, key):
# --> 998         raise KeyError(key)
#     999
#
# KeyError: 'customerID'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ####**Valores nulos**

# %%
df_telecom_X.isnull()
# Out:
#       customerid  churn  customer  phone  internet  account  gender  \
# 4988       False  False     False  False     False    False   False
# 7090       False  False     False  False     False    False   False
# 579        False  False     False  False     False    False   False
# 434        False  False     False  False     False    False   False
# 7233       False  False     False  False     False    False   False
# ...          ...    ...       ...    ...       ...      ...     ...
# 5998       False  False     False  False     False    False   False
# 4366       False  False     False  False     False    False   False
# 4182       False  False     False  False     False    False   False
# 6537       False  False     False  False     False    False   False
# 5523       False  False     False  False     False    False   False
#
#       internetservice  onlinesecurity  onlinebackup  ...  streamingmovies  \
# 4988            False           False         False  ...            False
# ...

# %%
df_telecom_X.isnull().sum()
# Out:
# customerid            0
# churn                 0
# customer              0
# phone                 0
# internet              0
# account               0
# gender                0
# internetservice       0
# onlinesecurity        0
# onlinebackup          0
# deviceprotection      0
# techsupport           0
# streamingtv           0
# streamingmovies       0
# phone_service         0
# contract              0
# paperless_billing     0
# paymentmethod         0
# charges.monthly       0
# charges.total         0
# Tiempo_de_Contrato    0
# cuentas_diarias       0
# total_contracto       0
# dtype: int64

# %%
df_normalized_customer.isnull().sum()
# Out:
# gender           0
# SeniorCitizen    0
# Partner          0
# Dependents       0
# tenure           0
# dtype: int64

# %%
df_normalized_account.isnull().sum()
# Out:
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# dtype: int64

# %%
df_normalized_internet.isnull().sum()
# Out:
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# dtype: int64

# %%
df_normalized_phone.isnull().sum()
# Out:
# PhoneService     0
# MultipleLines    0
# dtype: int64

# %%
df_normalized_internet.isnull().sum()
# Out:
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# dtype: int64

# %% [markdown]
# ####**Manejo de incosistencias, letra minuscula, rellenando espacios en blanco**

# %%
telecomx_coloumnslow= df_telecom_X.columns.str.lower()
telecomx_coloumnslow
# Out:
# Index(['customerid', 'churn', 'customer', 'phone', 'internet', 'account',
#        'gender', 'internetservice', 'onlinesecurity', 'onlinebackup',
#        'deviceprotection', 'techsupport', 'streamingtv', 'streamingmovies',
#        'phone_service', 'contract', 'paperless_billing', 'paymentmethod',
#        'charges.monthly', 'charges.total', 'tiempo_de_contrato',
#        'cuentas_diarias', 'total_contracto'],
#       dtype='object')

# %%
df_telecom_X.columns = df_telecom_X.columns.str.lower().str.replace(' ', '_')
df_telecom_X.columns
# Out:
# Index(['customerid', 'churn', 'customer', 'phone', 'internet', 'account',
#        'gender', 'internetservice', 'onlinesecurity', 'onlinebackup',
#        'deviceprotection', 'techsupport', 'streamingtv', 'streamingmovies',
#        'phone_service', 'contract', 'paperless_billing', 'paymentmethod',
#        'charges.monthly', 'charges.total', 'tiempo_de_contrato',
#        'cuentas_diarias', 'total_contracto'],
#       dtype='object')

# %%
df_telecom_X.columns
# Out:
# Index(['customerid', 'churn', 'customer', 'phone', 'internet', 'account',
#        'gender', 'internetservice', 'onlinesecurity', 'onlinebackup',
#        'deviceprotection', 'techsupport', 'streamingtv', 'streamingmovies',
#        'phone_service', 'contract', 'paperless_billing', 'paymentmethod',
#        'charges.monthly', 'charges.total', 'tiempo_de_contrato',
#        'cuentas_diarias', 'total_contracto'],
#       dtype='object')

# %%
df_telecom_X.head()
# Out:
#       customerid churn                                           customer  \
# 4988  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7090  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 579   0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 434   0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7233  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                phone  \
# 4988  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7090  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 579   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 434   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7233  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                                internet  \
# 4988  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 7090  {'InternetService': 'No', 'OnlineSecurity': 'N...
# ...

# %% [markdown]
# ###**Añadiendo Columnas**

# %%
df_telecom_X['gender']= df_normalized_customer['gender']
df_telecom_X
# Out:
#       customerid churn                                           customer  \
# 4988  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7090  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 579   0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 434   0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7233  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# ...          ...   ...                                                ...
# 5998  8199-ZLLSA   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 4366  5989-AXPUC    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4182  5734-EJKXG    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6537  8984-HPEMB    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5523  7569-NMZYQ    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                 phone  \
# ...

# %%
df_telecom_X[['InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
       'TechSupport', 'StreamingTV', 'StreamingMovies']]= df_normalized_internet[['InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
       'TechSupport', 'StreamingTV', 'StreamingMovies']]
df_telecom_X.columns= df_telecom_X.columns.str.lower().str.replace(' ', '_')
df_telecom_X
# Out:
#       customerid churn                                           customer  \
# 4988  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7090  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 579   0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 434   0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7233  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# ...          ...   ...                                                ...
# 5998  8199-ZLLSA   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 4366  5989-AXPUC    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4182  5734-EJKXG    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6537  8984-HPEMB    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5523  7569-NMZYQ    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                 phone  \
# ...

# %%
df_telecom_X['phone_service']= df_normalized_phone['PhoneService']
df_telecom_X
# Out:
#       customerid churn                                           customer  \
# 4988  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7090  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 579   0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 434   0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7233  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# ...          ...   ...                                                ...
# 5998  8199-ZLLSA   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 4366  5989-AXPUC    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4182  5734-EJKXG    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6537  8984-HPEMB    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5523  7569-NMZYQ    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                 phone  \
# ...

# %%
df_telecom_X['contract']= df_normalized_account['Contract']
df_telecom_X
# Out:
#       customerid churn                                           customer  \
# 4988  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7090  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 579   0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 434   0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7233  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# ...          ...   ...                                                ...
# 5998  8199-ZLLSA   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 4366  5989-AXPUC    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4182  5734-EJKXG    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6537  8984-HPEMB    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5523  7569-NMZYQ    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                 phone  \
# ...

# %%
df_telecom_X[['paperless_billing','PaymentMethod']]= df_normalized_account[['PaperlessBilling','PaymentMethod']]
df_telecom_X.columns= df_telecom_X.columns.str.lower().str.replace(' ', '_')
df_telecom_X.head()
# Out:
#       customerid churn                                           customer  \
# 4988  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7090  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 579   0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 434   0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7233  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                phone  \
# 4988  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7090  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 579   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 434   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7233  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                                internet  \
# 4988  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 7090  {'InternetService': 'No', 'OnlineSecurity': 'N...
# ...

# %%
df_telecom_X['charges.monthly']= df_normalized_account['Charges.Monthly']
df_telecom_X
# Out:
#       customerid churn                                           customer  \
# 4988  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7090  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 579   0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 434   0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7233  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# ...          ...   ...                                                ...
# 5998  8199-ZLLSA   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 4366  5989-AXPUC    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4182  5734-EJKXG    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6537  8984-HPEMB    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5523  7569-NMZYQ    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                 phone  \
# ...

# %%
df_telecom_X['charges.total']= df_normalized_account['Charges.Total']
df_telecom_X
# Out:
#       customerid churn                                           customer  \
# 4988  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7090  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 579   0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 434   0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7233  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# ...          ...   ...                                                ...
# 5998  8199-ZLLSA   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 4366  5989-AXPUC    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4182  5734-EJKXG    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6537  8984-HPEMB    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5523  7569-NMZYQ    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                 phone  \
# ...

# %%
df_telecom_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7267 entries, 4988 to 5523
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customerid          7267 non-null   object
#  1   churn               7267 non-null   object
#  2   customer            7267 non-null   object
#  3   phone               7267 non-null   object
#  4   internet            7267 non-null   object
#  5   account             7267 non-null   object
#  6   gender              7267 non-null   object
#  7   internetservice     7267 non-null   object
#  8   onlinesecurity      7267 non-null   object
#  9   onlinebackup        7267 non-null   object
#  10  deviceprotection    7267 non-null   object
#  11  techsupport         7267 non-null   object
#  12  streamingtv         7267 non-null   object
#  13  streamingmovies     7267 non-null   object
#  14  phone_service       7267 non-null   object
# ...

# %% [markdown]
# ####**Creando Columna Contract in Numbers / Tiempo de Contrato**

# %%
import numpy as np

df_telecom_X['Tiempo_de_Contrato']= df_normalized_account['Contract'].map({'Month-to-month':1, 'One year':12, 'Two year':24}).astype(np.float64)
df_telecom_X
# Out:
#       customerid churn                                           customer  \
# 4988  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7090  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 579   0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 434   0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7233  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# ...          ...   ...                                                ...
# 5998  8199-ZLLSA   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 4366  5989-AXPUC    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4182  5734-EJKXG    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6537  8984-HPEMB    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5523  7569-NMZYQ    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                 phone  \
# ...

# %%
df_telecom_X['Tiempo_de_Contrato'].unique()
# Out:
# array([12., 24.,  1.])

# %% [markdown]
# ####**Creando Columna cuentas Diarias**

# %%
df_telecom_X['cuentas_diarias']= df_normalized_account['Charges.Monthly']/30
df_telecom_X
# Out:
#       customerid churn                                           customer  \
# 4988  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7090  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 579   0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 434   0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7233  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# ...          ...   ...                                                ...
# 5998  8199-ZLLSA   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 4366  5989-AXPUC    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4182  5734-EJKXG    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6537  8984-HPEMB    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5523  7569-NMZYQ    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                 phone  \
# ...

# %% [markdown]
# ####**Total_a_Pagar/Contracto**

# %%
df_telecom_X['charges.total'] = pd.to_numeric(df_telecom_X['charges.total'], errors='coerce').fillna(0).astype(float)
df_telecom_X['total_contracto']= df_telecom_X['charges.total']*df_telecom_X['Tiempo_de_Contrato']
df_telecom_X.head()
# Out:
#       customerid churn                                           customer  \
# 4988  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7090  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 579   0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 434   0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7233  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                phone  \
# 4988  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7090  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 579   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 434   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7233  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                                internet  \
# 4988  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 7090  {'InternetService': 'No', 'OnlineSecurity': 'N...
# ...

# %%
## df_telecom_X.drop(columns=['contract_in_numbers'], inplace=True)

# %%
df_telecom_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7267 entries, 4988 to 5523
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customerid          7267 non-null   object
#  1   churn               7267 non-null   object
#  2   customer            7267 non-null   object
#  3   phone               7267 non-null   object
#  4   internet            7267 non-null   object
#  5   account             7267 non-null   object
#  6   gender              7267 non-null   object
#  7   internetservice     7267 non-null   object
#  8   onlinesecurity      7267 non-null   object
#  9   onlinebackup        7267 non-null   object
#  10  deviceprotection    7267 non-null   object
#  11  techsupport         7267 non-null   object
#  12  streamingtv         7267 non-null   object
#  13  streamingmovies     7267 non-null   object
#  14  phone_service       7267 non-null   object
# ...

# %% [markdown]
# ###**reseteando index**

# %%
df_telecom_X.reset_index(inplace=True, drop=True)
df_telecom_X.head()
# Out:
#    customerid churn                                           customer  \
# 0  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 1  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 2  0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                             phone  \
# 0  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 2  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 1  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 2  {'InternetService': 'No', 'OnlineSecurity': 'N...
# ...

# %% [markdown]
# ###**Organizando el dataframe df_telecom_X, en orden ascendente de menor a mayor, para la columna '***charges.monthly***'**

# %%
df_telecom_X = df_telecom_X.sort_values('charges.monthly', ascending=True)
df_telecom_X.head()
# Out:
#    customerid churn                                           customer  \
# 0  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 1  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 2  0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                             phone  \
# 0  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 2  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 1  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 2  {'InternetService': 'No', 'OnlineSecurity': 'N...
# ...

# %% [markdown]
# ###**definiendo tipo de dato por columna**

# %%
df_telecom_X.dtypes
# Out:
# customerid             object
# churn                  object
# customer               object
# phone                  object
# internet               object
# account                object
# gender                 object
# internetservice        object
# onlinesecurity         object
# onlinebackup           object
# deviceprotection       object
# techsupport            object
# streamingtv            object
# streamingmovies        object
# phone_service          object
# contract               object
# paperless_billing      object
# paymentmethod          object
# charges.monthly       float64
# charges.total         float64
# Tiempo_de_Contrato    float64
# cuentas_diarias       float64
# total_contracto       float64
# dtype: object

# %%
col_numericas=['charges.monthly','charges.total','Tiempo_de_Contrato','cuentas_diarias','total_contracto']

# Convert 'charges.total' and 'total_contracto' to numeric, coercing errors and filling NaN
df_telecom_X['charges.total'] = pd.to_numeric(df_telecom_X['charges.total'], errors='coerce').fillna(0)
df_telecom_X['total_contracto'] = pd.to_numeric(df_telecom_X['total_contracto'], errors='coerce').fillna(0)


df_telecom_X[col_numericas]=df_telecom_X[col_numericas].astype(np.float64)
df_telecom_X.dtypes
# Out:
# customerid             object
# churn                  object
# customer               object
# phone                  object
# internet               object
# account                object
# gender                 object
# internetservice        object
# onlinesecurity         object
# onlinebackup           object
# deviceprotection       object
# techsupport            object
# streamingtv            object
# streamingmovies        object
# phone_service          object
# contract               object
# paperless_billing      object
# paymentmethod          object
# charges.monthly       float64
# charges.total         float64
# Tiempo_de_Contrato    float64
# cuentas_diarias       float64
# total_contracto       float64
# dtype: object

# %%
df_telecom_X['internetservice'].value_counts()
# Out:
# internetservice
# Fiber optic    3198
# DSL            2488
# No             1581
# Name: count, dtype: int64

# %%
df_telecom_X['churn'].value_counts()
# Out:
# churn
# No     5174
# Yes    1869
#         224
# Name: count, dtype: int64

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# ####**Describing all columns of a DataFrame regardless of data type.**

# %%
df_telecom_X.describe(include='all')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1935032712.py in <cell line: 0>()
# ----> 1 df_telecom_X.describe(include='all')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in describe(self, percentiles, include, exclude)
#   11974         max            NaN      3.0
#   11975         """
# > 11976         return describe_ndframe(
#   11977             obj=self,
#   11978             include=include,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/methods/describe.py in describe_ndframe(obj, include, exclude, percentiles)
#      95         )
#      96
# ---> 97     result = describer.describe(percentiles=percentiles)
#      98     return cast(NDFrameT, result)
#      99
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/methods/describe.py in describe(self, percentiles)
#     170         for _, series in data.items():
# ...

# %% [markdown]
# ####**Including only numeric columns in a DataFrame description.**

# %%
import numpy as np

df_telecom_X.describe(include=[np.number])
# Out:
#        charges.monthly  charges.total  tiempo_de_contrato  cuentas_diarias  \
# count      7267.000000    7267.000000         7267.000000      7267.000000
# mean         64.720098    2277.182035            8.815880         2.157337
# std          30.129572    2268.648587            9.544539         1.004319
# min          18.250000       0.000000            1.000000         0.608333
# 25%          35.425000     396.200000            1.000000         1.180833
# 50%          70.300000    1389.200000            1.000000         2.343333
# 75%          89.875000    3778.525000           12.000000         2.995833
# max         118.750000    8684.800000           24.000000         3.958333
#
#        total_contracto  Tiempo_de_Contrato
# count      7267.000000         7267.000000
# mean      29675.910954            8.815880
# std       48587.597295            9.544539
# min           0.000000            1.000000
# 25%         524.750000            1.000000
# ...

# %% [markdown]
# ####**Including only string columns in a DataFrame description.**

# %%
df_telecom_X.describe(include=[object])
# Out:
#         customerid churn                                           customer  \
# count         7267  7267                                               7267
# unique        7267     3                                                891
# top     7569-NMZYQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# freq             1  5174                                                223
#
#                                                  phone  \
# count                                             7267
# unique                                               3
# top     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# freq                                              3495
#
#                                                  internet  \
# count                                                7267
# unique                                                129
# top     {'InternetService': 'No', 'OnlineSecurity': 'N...
# freq                                                 1581
#
# ...

# %% [markdown]
# ####**Including only categorical columns from a DataFrame description.**

# %%
df_telecom_X.describe(include=['object'])
# Out:
#         customerid churn                                           customer  \
# count         7267  7267                                               7267
# unique        7267     3                                                891
# top     7569-NMZYQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# freq             1  5174                                                223
#
#                                                  phone  \
# count                                             7267
# unique                                               3
# top     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# freq                                              3495
#
#                                                  internet  \
# count                                                7267
# unique                                                129
# top     {'InternetService': 'No', 'OnlineSecurity': 'N...
# freq                                                 1581
#
# ...

# %% [markdown]
# #####**Calculando la Media**

# %% [markdown]
# ######**La mediana en estadística es el valor medio en un conjunto de datos ordenados. Representa el punto medio, donde la mitad de los datos son menores y la otra mitad son mayores.
# ¿Cómo se calcula la mediana?
# Ordena los datos: Organiza el conjunto de datos de menor a mayor.
# Encuentra el valor medio:
# Si el número de datos es impar, la mediana es el valor central.
# Si el número de datos es par, la mediana es el promedio de los dos valores centrales, según Khan Academy.
# Ejemplo:
# Para los datos: 2, 3, 3, 5, 7, 10, la mediana es 4 (el promedio de 3 y 5). **

# %% [markdown]
# ####**Cargo Mensual, la mediana 64.72009770194028**

# %%
df_telecom_X['charges.monthly'].mean()
# Out:
# np.float64(64.72009770194028)

# %%
df_telecom_X.groupby('customerid')[['charges.monthly']].mean().sort_values('charges.monthly', ascending=True)
# Out:
#             charges.monthly
# customerid
# 6823-SIDFQ            18.25
# 9764-REAFF            18.40
# 0827-ITJPH            18.55
# 0621-CXBKL            18.70
# 9945-PSVIP            18.70
# ...                     ...
# 8199-ZLLSA           118.35
# 5989-AXPUC           118.60
# 5734-EJKXG           118.60
# 8984-HPEMB           118.65
# 7569-NMZYQ           118.75
#
# [7267 rows x 1 columns]

# %% [markdown]
# ####**Cargo Total, la mediana 2280.6342130650496**

# %%
# Convert 'charges.total' to numeric, coercing errors to NaN
df_telecom_X['charges.total'] = pd.to_numeric(df_telecom_X['charges.total'], errors='coerce')

# Calculate the mean of the numeric column, skipping NaN values
df_telecom_X['charges.total'].mean()
# Out:
# np.float64(2277.182035227742)

# %%
df_telecom_X['charges.total'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_telecom_X['charges.total'].fillna(0, inplace=True)
# Out:
# /tmp/ipython-input-107880294.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_telecom_X['charges.total'].fillna(0, inplace=True)

# %%
df_telecom_X.groupby(['customerid','contract'])[['charges.total']].mean().sort_values('charges.total', ascending=False)
# Out:
#                      charges.total
# customerid contract
# 2889-FPWRM One year        8684.80
# 7569-NMZYQ Two year        8672.45
# 9739-JLPQJ Two year        8670.10
# 9788-HNGUT Two year        8594.40
# 8879-XUAHX Two year        8564.75
# ...                            ...
# 5709-LVOEQ Two year           0.00
# 3213-VVOLG Two year           0.00
# 2775-SEFEE Two year           0.00
# 3115-CZMZD Two year           0.00
# 7644-OMVMY Two year           0.00
#
# [7267 rows x 1 columns]

# %% [markdown]
# ####**Cuentas Diarias, la mediana 2.1573365900646757**

# %%
df_telecom_X['cuentas_diarias'].mean()
# Out:
# np.float64(2.1573365900646757)

# %%
df_telecom_X.groupby(['customerid','charges.monthly'])[['cuentas_diarias']].mean().sort_values('cuentas_diarias', ascending=True)
# Out:
#                             cuentas_diarias
# customerid charges.monthly
# 6823-SIDFQ 18.25                   0.608333
# 9764-REAFF 18.40                   0.613333
# 0827-ITJPH 18.55                   0.618333
# 0621-CXBKL 18.70                   0.623333
# 9945-PSVIP 18.70                   0.623333
# ...                                     ...
# 8199-ZLLSA 118.35                  3.945000
# 5989-AXPUC 118.60                  3.953333
# 5734-EJKXG 118.60                  3.953333
# 8984-HPEMB 118.65                  3.955000
# 7569-NMZYQ 118.75                  3.958333
#
# [7267 rows x 1 columns]

# %% [markdown]
# ###**Resumen**
#
#
# *   charges.monthly	64.755423
# *   charges.total	2280.634213
# *   cuentas_diarias	2.158514

# %%
df_median = (df_telecom_X['charges.total']>0)
df_telecom_X[df_median].select_dtypes(include='number').mean()
# Out:
# charges.monthly          64.755423
# charges.total          2280.634213
# tiempo_de_contrato        8.794515
# cuentas_diarias           2.158514
# total_contracto       29720.899242
# Tiempo_de_Contrato        8.794515
# dtype: float64

# %% [markdown]
# #####**El minimo**

# %% [markdown]
# ######**El minimo cargo mensual es de 18.25**

# %%
df_telecom_X['charges.monthly'].min()
# Out:
# 18.25

# %%
df_telecom_X.query('`charges.monthly`== 18.25').index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3984971671.py in <cell line: 0>()
# ----> 1 df_telecom_X.query('`charges.monthly`== 18.25').index
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    4821         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822         kwargs["target"] = None
# -> 4823         res = self.eval(expr, **kwargs)
#    4824
#    4825         try:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    4941         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4942         index_resolvers = self._get_index_resolvers()
# -> 4943         column_resolvers = self._get_cleaned_column_resolvers()
#    4944         resolvers = column_resolvers, index_resolvers
#    4945         if "target" not in kwargs:
#
# ...

# %%
df_telecom_X.iloc[4988].to_dict()

# %% [markdown]
# ######**El minimo cargo total es de 18.80**

# %%
df_monthly_min = (df_telecom_X['charges.total']>0)

# %%
df_telecom_X[df_monthly_min].select_dtypes(include='number').min()
# Out:
# charges.monthly       18.250000
# charges.total         18.800000
# tiempo_de_contrato     1.000000
# cuentas_diarias        0.608333
# total_contracto       18.850000
# Tiempo_de_Contrato     1.000000
# dtype: float64

# %%
df_telecom_X.query('`charges.total`== 18.80').index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-713741580.py in <cell line: 0>()
# ----> 1 df_telecom_X.query('`charges.total`== 18.80').index
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    4821         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822         kwargs["target"] = None
# -> 4823         res = self.eval(expr, **kwargs)
#    4824
#    4825         try:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    4941         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4942         index_resolvers = self._get_index_resolvers()
# -> 4943         column_resolvers = self._get_cleaned_column_resolvers()
#    4944         resolvers = column_resolvers, index_resolvers
#    4945         if "target" not in kwargs:
#
# ...

# %%
df_telecom_X.iloc[2111].to_dict()

# %% [markdown]
# ######**El minimo cuentas diarias es de 0.6083333333333333**

# %%
df_telecom_X['cuentas_diarias'].min()

# %%
df_telecom_X.query('`cuentas_diarias`== 0.6083333333333333').index

# %%
df_telecom_X.iloc[4988].to_dict()
# Out:
# {'customerid': '3865-ZYKAD',
#  'churn': 'No',
#  'customer': {'gender': 'Male',
#   'SeniorCitizen': 1,
#   'Partner': 'Yes',
#   'Dependents': 'No',
#   'tenure': 69},
#  'phone': {'PhoneService': 'Yes', 'MultipleLines': 'Yes'},
#  'internet': {'InternetService': 'Fiber optic',
#   'OnlineSecurity': 'Yes',
#   'OnlineBackup': 'Yes',
#   'DeviceProtection': 'No',
#   'TechSupport': 'No',
#   'StreamingTV': 'No',
#   'StreamingMovies': 'No'},
#  'account': {'Contract': 'Month-to-month',
#   'PaperlessBilling': 'Yes',
#   'PaymentMethod': 'Credit card (automatic)',
#   'Charges': {'Monthly': 84.9, 'Total': '5785.65'}},
#  'gender': 'Male',
#  'internetservice': 'Fiber optic',
#  'onlinesecurity': 'Yes',
#  'onlinebackup': 'Yes',
#  'deviceprotection': 'No',
#  'techsupport': 'No',
#  'streamingtv': 'No',
#  'streamingmovies': 'No',
#  'phone_service': 'Yes',
#  'contract': 'Month-to-month',
#  'paperless_billing': 'Yes',
#  'paymentmethod': 'Credit card (automatic)',
# ...

# %% [markdown]
# #####**Resumen**
#
# *   El minimo cargo mensual es de 18.25
# *   El minimo cargo total es de 18.80
# *   El minimo cuentas diarias es de 0.6083333333333333

# %%
df_monthly_min = (df_telecom_X['charges.total']>0)
df_telecom_X[df_monthly_min].select_dtypes(include='number').min()
# Out:
# charges.monthly       18.250000
# charges.total         18.800000
# tiempo_de_contrato     1.000000
# cuentas_diarias        0.608333
# total_contracto       18.850000
# Tiempo_de_Contrato     1.000000
# dtype: float64

# %% [markdown]
# #####**El maximo**

# %% [markdown]
# ######**El maximo cargo mensual es de 118.75**

# %%
df_telecom_X['charges.monthly'].max()

# %%
df_telecom_X.iloc[df_telecom_X.query('`charges.monthly`== 118.75').index].to_dict()

# %% [markdown]
# ######**El maximo cargo total es de 8684.8**

# %%
df_telecom_X['charges.total'].max()

# %%
df_telecom_X.iloc[df_telecom_X.query('`charges.total`== 8684.8').index].to_dict()

# %% [markdown]
# ######**El maximo cuentas_diarias es de 3.9583333333333335**

# %%
df_telecom_X['cuentas_diarias'].max()

# %%
df_telecom_X.iloc[df_telecom_X.query('`cuentas_diarias`== 3.9583333333333335').index].to_dict()

# %% [markdown]
# ####**Resumen**
#
# *   charges.monthly	118.750000
# *   charges.total	8684.800000
# *   cuentas_diarias	3.958333

# %%
df_monthly_max = (df_telecom_X['charges.total']>0)
df_telecom_X[df_monthly_min].select_dtypes(include='number').max()

# %% [markdown]
# #####**Cuentas / Cantidad**

# %%
df_telecom_X['churn'].value_counts()

# %%
df_telecom_X['gender'].value_counts()

# %%
df_telecom_X['phone_service'].value_counts()

# %%
df_telecom_X['internetservice'].value_counts()

# %%
df_telecom_X['paymentmethod'].value_counts()

# %%
df_telecom_X['contract'].value_counts()

# %% [markdown]
# ####**Aplicando Filtro Churn**

# %%
filtro_churn = df_telecom_X['churn'] == 'Yes'
df_telecom_X[filtro_churn]

# %%
df_telecom_X[filtro_churn].count()

# %%
filtro_churn_no = df_telecom_X['churn'] == 'No'
df_telecom_X[filtro_churn_no]

# %%
df_telecom_X[filtro_churn_no].count()

# %%
filtro_churn_vacio = df_telecom_X['churn'] == ''
df_telecom_X[filtro_churn_vacio]

# %%
df_telecom_X[filtro_churn_vacio].count()

# %% [markdown]
# ####**Conteo**

# %% [markdown]
# #####**Churn y customer Id  **
#
# *   vacio = 224
# *   churn No  = 5174
# *   churn Yes = 1869
#  total de 7267 usuarios de la empresa telecom X

# %%
df_churn_telecomX= df_telecom_X.groupby(['churn'])[['customerid']].count()
df_churn_telecomX

# %%
df_churn_telecomX.plot(kind='pie', y='customerid', figsize=(10,8), color='purple', title='Churn en el TelecomX', xlabel='churn', ylabel='Cantidad de clientes', autopct='%1.1f%%')

# %%
df_churn_telecomX.plot(kind='bar', figsize=(12, 8), title='Churn Count by Contract Type', xlabel='Contract Type and Churn', ylabel='Count')

# %% [markdown]
# #####**Churn, custumerid y gender   **

# %%
df_churn_telecomX_gender= df_telecom_X.groupby(['churn'])[['gender']].value_counts()
df_churn_telecomX_gender

# %%
df_churn_telecomX_gender_percentage = df_churn_telecomX_gender / df_churn_telecomX_gender.sum() * 100
df_churn_telecomX_gender_percentage

# %%
df_churn_telecomX_gender_percentage.plot(kind='pie', y='count', figsize=(10, 8), autopct='%1.1f%%', title='Churn Percentage Distribution by Gender', ylabel='Percentage')

# %% [markdown]
# #####**Churn y contract**

# %%
df_churn_telecomX_contract= df_telecom_X.groupby(['churn'])[['contract']].value_counts()
df_churn_telecomX_contract

# %%
df_churn_telecomX_contract1= df_telecom_X.groupby(['churn','gender'])[['contract']].value_counts()
df_churn_telecomX_contract1

# %%
df_churn_telecomX_contract.plot(kind='bar', figsize=(10, 5), title='Churn Count by Contract Type', xlabel='Contract Type and Churn', ylabel='Count')

# %% [markdown]
# ####**Churn,contract y PaymentMethod**

# %%
df_churn_telecomX_PaymentMethod= df_telecom_X.groupby(['churn'])[['paymentmethod']].value_counts()
df_churn_telecomX_PaymentMethod

# %%
df_churn_telecomX_PaymentMethod.plot(kind='bar', figsize=(10, 5), title='Churn Count by PaymentMethod', xlabel='Contract Type and PaymentMethod', ylabel='Count')

# %% [markdown]
# #####**Churn,contract y PaymentMethod**

# %%
df_churn_telecomX_PaymentMethod_contract= df_telecom_X.groupby(['churn','contract'])[['paymentmethod']].value_counts()
df_churn_telecomX_PaymentMethod_contract

# %% [markdown]
# #####**Churn,gender y PaymentMethod**

# %%
df_churn_telecomX_PaymentMethod_contract= df_telecom_X.groupby(['churn','gender'])[['paymentmethod']].value_counts()
df_churn_telecomX_PaymentMethod_contract

# %% [markdown]
# #####**Churn,contract,gender y PaymentMethod**

# %%
df_churn_telecomX_PaymentMethod_contract_gender= df_telecom_X.groupby(['churn','gender','contract'])[['paymentmethod']].value_counts()
df_churn_telecomX_PaymentMethod_contract_gender

# %%
df_churn_telecomX_PaymentMethod_contract_gender.plot(kind='bar', figsize=(10, 5), title='Churn Count,gender, contract by PaymentMethod', xlabel='Contract Type, gender, contract and PaymentMethod', ylabel='Count')

# %% [markdown]
# ####**churn and (Internet data + phone_service)**

# %%
df_churn_telecomX_internet_data= df_telecom_X.groupby(['churn','internetservice', 'contract'])[['onlinesecurity', 'onlinebackup',
       'deviceprotection', 'techsupport', 'streamingtv', 'streamingmovies','phone_service']].count()
df_churn_telecomX_internet_data

# %%
df_churn_telecomX_internet_data1= df_telecom_X.groupby(['internetservice', 'contract','onlinesecurity', 'onlinebackup',
       'deviceprotection', 'techsupport', 'streamingtv', 'streamingmovies','phone_service','churn'])[['customerid']].count()
df_churn_telecomX_internet_data1

# %%
# @title OnlineSecurity

from matplotlib import pyplot as plt
df_churn_telecomX_internet_data['onlinesecurity'].plot(kind='hist', bins=20, title='OnlineSecurity')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df_telecom_X.columns

# %% [markdown]
# ###**charges and churn**

# %%
df_analizer_0 = df_telecom_X[df_telecom_X['churn'] == 'No']
df_analizer_T = df_telecom_X[df_telecom_X['churn'] == 'Yes']
df_analizer_0

# %%
df_analizer_T

# %% [markdown]
# #####**Churn, contract y charges.monthly  **

# %%
df_churn_telecomX_monthly= df_telecom_X.groupby(['churn' , 'contract'])[['charges.monthly']].count()
df_churn_telecomX_monthly

# %%
df_churn_telecomX_monthly_sum= df_telecom_X.groupby(['churn' , 'contract'])[['charges.monthly']].sum()
df_churn_telecomX_monthly_sum

# %%
df_churn_telecomX_monthly_sum1= df_telecom_X.groupby(['churn' , 'gender','contract'])[['charges.monthly']].sum()
df_churn_telecomX_monthly_sum1

# %% [markdown]
# ######**charges.monthly _ apply analize1**

# %%
df_analize1 = df_churn_telecomX_monthly.loc[('No', slice(None)), :]
df_analize1

# %%
df_analize1.plot(kind='bar', figsize=(10, 5), title='Churn by montly.charges', xlabel='Contract Type and Churn', ylabel='charges.monthly')

# %% [markdown]
# ######**charges.monthly _ apply analize2**

# %%
df_analize2 = df_churn_telecomX_monthly.loc[('Yes', slice(None)), :]
df_analize2

# %%
df_analize1.plot(kind='bar', figsize=(10, 5), title='Churn by montly.charges', xlabel='Contract Type and Churn', ylabel='charges.monthly')

# %%
from matplotlib import pyplot as plt
df_churn_telecomX_monthly['charges.monthly'].plot(kind='hist', bins=20, title='charges.monthly')
plt.gca().spines[['top', 'right',]].set_visible(True)

# %%
from matplotlib import pyplot as plt
df_churn_telecomX_monthly['charges.monthly'].plot(kind='line', figsize=(15, 4), title='charges.monthly')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df_churn_telecomX_monthly.plot(kind='bar', figsize=(10, 7), title='Churn Count by Churn Status', xlabel='Churn Status', ylabel='charges.monthly')

# %% [markdown]
# #####**Churn, contract y charges.total  **

# %%
df_churn_telecomX_total= df_telecom_X.groupby(['churn' , 'contract'])[['charges.total']].count()
df_churn_telecomX_total

# %%
df_churn_telecomX_total_sum= df_telecom_X.groupby(['churn' , 'contract'])[['charges.total']].sum()
df_churn_telecomX_total_sum
# Out:
#                       charges.total
# churn contract
#       Month-to-month      167928.00
#       One year            166843.25
#       Two year            157341.90
# No    Month-to-month     3378679.25
#       One year           3792062.30
#       Two year           6022500.25
# Yes   Month-to-month     1927182.25
#       One year            674991.20
#       Two year            260753.45

# %%
df_churn_telecomX_total_sum1= df_telecom_X.groupby(['churn' ,'gender', 'contract'])[['charges.total']].sum()
df_churn_telecomX_total_sum1

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df_churn_telecomX_total_sum1)

# %%
df_churn_telecomX_total.plot(kind='bar', figsize=(12, 8), title='Churn Count by Contract Type and Churn Status charges.total', xlabel='Churn Status and Contract Type', ylabel='Charges.Total')

# %% [markdown]
# ######**charges.total _ apply analize3**

# %%
df_analize3 = df_churn_telecomX_total.loc[('No', slice(None)), :]
df_analize3

# %%
# @title charges.total

from matplotlib import pyplot as plt
df_analize3['charges.total'].plot(kind='line', figsize=(8, 4), title='charges.total')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ######**charges.total _ apply analize4**

# %%
df_analize4 = df_churn_telecomX_total.loc[('Yes', slice(None)), :]
df_analize4

# %%
# @title charges.total

from matplotlib import pyplot as plt
df_analize4['charges.total'].plot(kind='line', figsize=(8, 4), title='charges.total')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# #####**Churn, contract y cuentas_diarias**

# %%
df_churn_telecomX_cuentas_diarias= df_telecom_X.groupby(['churn' , 'contract'])[['cuentas_diarias']].count()
df_churn_telecomX_cuentas_diarias

# %%
df_churn_telecomX_cuentas_diarias_sum= df_telecom_X.groupby(['churn' , 'contract'])[['cuentas_diarias']].sum()
df_churn_telecomX_cuentas_diarias_sum
# Out:
#                       cuentas_diarias
# churn contract
#       Month-to-month       280.531667
#       One year             109.095000
#       Two year              83.851667
# No    Month-to-month      4548.235000
#       One year            2723.271667
#       Two year            3294.685000
# Yes   Month-to-month      4028.236667
#       One year             470.615000
#       Two year             138.843333

# %%
df_churn_telecomX_cuentas_diarias_sum1= df_telecom_X.groupby(['churn' ,'gender', 'contract'])[['cuentas_diarias']].sum()
df_churn_telecomX_cuentas_diarias_sum1

# %%
# @title cuentas_diarias

from matplotlib import pyplot as plt
df_churn_telecomX_cuentas_diarias['cuentas_diarias'].plot(kind='line', figsize=(16, 4), title='cuentas_diarias')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ######**cuentas_diarias _ apply analize5**

# %%
df_analize5 = df_churn_telecomX_cuentas_diarias.loc[('No', slice(None)), :]
df_analize5

# %%
# @title cuentas_diarias

from matplotlib import pyplot as plt
df_analize5['cuentas_diarias'].plot(kind='line', figsize=(8, 4), title='cuentas_diarias')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ######**cuentas_diarias_ apply analize6**

# %%
df_analize6 = df_churn_telecomX_cuentas_diarias.loc[('Yes', slice(None)), :]
df_analize6

# %%
# @title charges.total

from matplotlib import pyplot as plt
df_analize6['cuentas_diarias'].plot(kind='line', figsize=(8, 4), title='cuentas_diarias / Yes')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# #####**Churn, contract y total_contracto **

# %%
df_churn_telecomX_total= df_telecom_X.groupby(['churn' , 'contract'])[['total_contracto']].count()
df_churn_telecomX_total

# %%
df_churn_telecomX_total_sum= df_telecom_X.groupby(['churn' , 'contract'])[['total_contracto']].sum()
df_churn_telecomX_total_sum

# %%
df_churn_telecomX_total_sum1= df_telecom_X.groupby(['churn','gender', 'contract'])[['total_contracto']].sum()
df_churn_telecomX_total_sum1

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df_churn_telecomX_total_sum1)

# %%
df_telecom_X.columns

# %% [markdown]
# #####**Churn, contract y phone_service**

# %%
df_churn_telecomX_phone_service= df_telecom_X.groupby(['phone_service', 'contract'])[['churn']].count()
df_churn_telecomX_phone_service

# %% [markdown]
# ####**Resumido Churn  **

# %%
# @title Texto de título predeterminado
df_churn_telecomX_resumido= df_telecom_X.groupby(['contract'])[['churn','gender','charges.monthly','charges.total','cuentas_diarias','phone_service']].value_counts()
df_churn_telecomX_resumido

# %% [markdown]
# ###**Totales **

# %% [markdown]
# ####**count churn**

# %%
df_telecom_X_count=df_telecom_X.count()
df_telecom_X_count

# %%
df_churn_X_count1=df_telecom_X['churn'].value_counts()
df_churn_X_count1

# %%
df_gender_X_count=df_telecom_X['gender'].value_counts()
df_gender_X_count

# %%
df_phone_X_count=df_telecom_X['phone_service'].value_counts()
df_phone_X_count

# %%
df_contract_X_count=df_telecom_X['contract'].value_counts()
df_contract_X_count

# %%
df_paymentMethod_X_count=df_telecom_X['paymentmethod'].value_counts()
df_paymentMethod_X_count

# %%
df_InternetService_X_count=df_telecom_X['internetservice'].value_counts()
df_InternetService_X_count

# %% [markdown]
# #####**Creando Tabla**

# %%
summary_data1 = {'Metric': ['churn', 'gender', 'contract','phone_service','PaymentMethod','InternetService'],
                'Value': [df_churn_X_count1, df_gender_X_count, df_contract_X_count, df_phone_X_count, df_paymentMethod_X_count, df_InternetService_X_count]}
df_summary_no_numeric = pd.DataFrame(summary_data1)
display(df_summary_no_numeric)

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df_summary_no_numeric)

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# Extract the count data from the 'Value' column
plot_data = df_summary_no_numeric.set_index('Metric')['Value'].apply(pd.Series).stack().reset_index(name='Count')

plt.figure(figsize=(12, 6))
sns.barplot(data=plot_data, x='Metric', y='Count', hue='level_1', palette='Dark2')
plt.title('Counts of Categorical Variables')
plt.xlabel('Metric')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ####**Suma Valores Numericos**

# %%
df_churn_telecomX_resumido.to_json('telecom_X_resumido.json')

# %% [markdown]
# #####**sumas de valores numericos **

# %%
df_sum_monthly= df_telecom_X['charges.monthly'].sum()
df_sum_monthly

# %%
# Ensure 'charges.total' is numeric after filling nulls
df_telecom_X['charges.total'] = pd.to_numeric(df_telecom_X['charges.total'], errors='coerce').fillna(0).astype(float)

df_sum = df_telecom_X['charges.total']
df_sum_total= df_sum.sum()
df_sum_total

# %%
df_sum_cuentas_diarias= df_telecom_X['cuentas_diarias'].sum()
df_sum_cuentas_diarias

# %%
df_sum_total_contrato= df_telecom_X['total_contracto'].sum()
df_sum_total_contrato

# %%
summary_data = {'Metric': ['Sum Monthly Charges', 'Sum Total Charges', 'Sum Daily Accounts', 'total_contracto'],
                'Value': [df_sum_monthly, df_sum_total, df_sum_cuentas_diarias, df_sum_total_contrato]}
df_summary = pd.DataFrame(summary_data)
display(df_summary)

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df_summary)

# %%
# @title Metric

from matplotlib import pyplot as plt
import seaborn as sns
df_summary.groupby(['Metric','Value']).size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(True)

# %% [markdown]
# #**Guardar _ Telecom_X**

# %%
df_telecom_X.to_json('telecom_X_final_1.json')

# %%
pd.read_json('telecom_X_final_1.json').head()
# Out:
#       customerid churn                                           customer  \
# 4988  6823-SIDFQ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7090  9764-REAFF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 579   0827-ITJPH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 434   0621-CXBKL    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7233  9945-PSVIP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                phone  \
# 4988  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7090  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 579   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 434   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7233  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                                internet  \
# 4988  {'InternetService': 'No', 'OnlineSecurity': 'N...
# 7090  {'InternetService': 'No', 'OnlineSecurity': 'N...
# ...

# %% [markdown]
# #📄Informe final

# %% [markdown]
# El "churn" de clientes, también conocido como rotación de clientes o pérdida de clientes, se refiere al porcentaje de clientes que dejan de utilizar un servicio o producto de una empresa en un período de tiempo determinado. Es una métrica crucial para evaluar la fidelidad del cliente y la salud general de un negocio, especialmente en industrias con suscripciones o contratos.

# %% [markdown]
# 🔹 Introducción: Explica el objetivo del análisis y el problema de evasión de clientes (Churn).
#
# **Mision**:
# proyecto "Churn de Clientes". La empresa enfrenta una alta tasa de cancelaciones y necesita comprender los factores que llevan a la pérdida de clientes.
#
# Tu desafío será recopilar, procesar y analizar los datos, utilizando Python y sus principales bibliotecas para extraer información valiosa. A partir de tu análisis, el equipo de Data Science podrá avanzar en modelos predictivos y desarrollar estrategias para reducir la evasión.
#
# Tu eres el **asistente de análisis de datos en Telecom X**
#
# > Telecom_X
#
#
#
# # Telecom X - Análisis de Evasión de Clientes

# %% [markdown]
# *texto en cursiva*##**Limpieza_ Extraccion:**

# %% [markdown]
# ### **Extraccion**: Describe los pasos realizados para importar, limpiar y procesar los datos.
#
# 1. se determina que tipo de archivo son los dos archivos que proporcionan, el del cuaderno de colab, y el de la base de datos, que es .json.
# 2.se carga al cuaderno en colab o a un drive.
# 3. se importa pandas y se lee el archivo json con su instruccion correspondiente.
# 4. luego se guarda en una variable tipo dataframe, llamada: df_telecom_X.
# 5. se accede al dataframe de la base de datos df_telecom_X.
# 6. se determina si hay listas o diccionarios.
# 7. se normaliza las columnas tipo diccionarios.
# 8. se escribe este nuevo dataframe, 'columna normalizada ', en un nuevo archivo .json.

# %% [markdown]
# instrucciones utilizadas:
#
# *   url='https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json'
#
#
# *   df_telecom_X=pd.read_json(url)
#
# *   df_telecom_X.head()
#
# *   df_telecom_X.tail()
#
# *   df_telecom_X.head(10)
# *   df_telecom_X.sample(10)
#
#
# *   type(df_telecom_X)
#
#
# *   df_normalized_customer = pd.json_normalize(df_telecom_X['customer'])
# df_normalized_customer
#
#
# *   df_normalized_customer.to_json('telecom_X_customer_normalizado.json')
#
#
# *   pd.read_json('telecom_X_customer_normalizado.json')
#
#
# *   df_normalized_customer.dtypes
# *   df_normalized_customer.info()

# %%
df_telecom_X.info()

# %% [markdown]
# ### **Conociendo los Datos**: Describe los pasos realizados para importar, limpiar y procesar los datos.
# 1. se conoce los tipos de datos en cada columna de los dataframe
# 2. se conoce la informacion de los dataframe.
# 3. se solicita una descripcion del dataframe, que incluye, conteo_total, valores unicos, valor top y frecuencia.
# 4. se conoce cuantas filas y colunas hay en los dataframe.
# 5. se pregunta porlas columnas, que hay en cada dataframe.
# 6. se pregunta que hay en cada columna.
#
# Instrucciones utilizadas:
# 1. df_telecom_X.dtypes
# 2. df_telecom_X.info()
# 3. df_telecom_X.describe()
# 4. df_telecom_X.shape
# 5. df1= df_telecom_X.columns
#    df1
# 6. df_telecom_X['customerID']

# %%
df_telecom_X.describe(include='all')

# %% [markdown]
# ## **limpiar los Datos: Describe los pasos realizados para importar, limpiar y procesar los datos.**
#
# 1. buscar valores no repetidos (unicos).
# 2. bucar valores no repitodos en columna.
# 3. buscar valores nulos.
# 4. manejo de inconsistencia.
# 5. letra minuscula.
# 6. rellenando espacios en blanco.
#
# instrucciones utilizadas:
# 1. customerID_unique=df_telecom_X['customerID'].unique()
# customerID_unique
# 2. df_telecom_X.query('@customerID_unique in customerID')
# 3. df_telecom_X.isnull().sum()
# 4. telecomx_coloumnslow= df_telecom_X.columns.str.lower()
# telecomx_coloumnslow
# 5. str.lower()

# %%
df_telecom_X.columns

# %%
df_telecom_X.head()

# %%
df_telecom_X.info()

# %% [markdown]
# ## **Transformando los Datos: Describe los pasos realizados para importar, limpiar y procesar los datos.**
# 1. añadiendo columnas.
# 2. eliminando columnas.
# 3. reseteando index.
# 4. organizando el dataframe en orden ascendente.
# 5. definiendo el tipo de datos por columna.
#
# instrucciones utilizadas:
# 1. df_telecom_X['gender']= df_normalized_customer['gender']
# df_telecom_X
# 2. df_telecom_X.drop(columns=['contract_in_numbers'], inplace=True)
# 3. df_telecom_X.reset_index(inplace=True, drop=True)
# df_telecom_X.head()
# 4. df_telecom_X = df_telecom_X.sort_values('charges.monthly', ascending=True)
# df_telecom_X.head()
# 5. astype(np.float64)

# %% [markdown]
# ## **Procesar los Datos: Describe los pasos realizados para importar, limpiar y procesar los datos.**
#
# 1. describiendo todas la columnas del dataframe, Telecom_x y el tipo de dato.
# 2. incluye columnas de siertos tipos.
# 3. calculando
#   a). la mediana.
#     1). cargo mensual.
#     2). cargo total.
#     3). cuentas diarias.
#     4). Resumen
#       a). el valor minimo.
#       b). el valor maximo.
#       c). cantidad.
#     5). aplicando filtros _ churn:
#       a). churn y customer id.
#       b). churn, customerid y gender.
#       c). churn y contract.
#       d). churn, contract y paymentMethod:
#         1). churn, contract y paymentMethod.
#         2). churn, gender y paymentMethod.
#         3). churn, contract, gender y PaymentMethod.
#       6). churn and (Internet data + phone_service).
#         a). onlineSecurity.
#       7). charges and churn:
#         a). churn, contract y charges.monthly.
#           1).charges.monthly_apply analize2.
#             a). grafica.
#           2). charges.monthly_apply analize2.
#             a). grafica.
#         b). churn, contract y charges.total.
#           1).charges.total_apply analize3.
#             a). grafica.
#           2). charges.total_apply analize4.
#             a). grafica.
#       8). churn, contract y cuentas_diarias:
#         a). grafica.
#         b). cuentas_diarias_apply analize5.
#           a). grafica.
#         c). cuentas_diarias_apply analize6.
#           a). grafica.
#       9). churn, contract y phone_service
#           a). grafica.
#       10). Resumido churn.
#       11). Totales:
#         a).count churn
#           1). creando tabla.
#         b). suma valores numericos:
#           1). metric.
#       12). Guardar_ Telecom_X
#
#
#
#
#
#
#
#
# Instruccion utilizada:
#
# 1. df_telecom_X.describe(include='all')
# 2.
#   a). import numpy as np
#
# df_telecom_X.describe(include=[np.number])
#   b). df_telecom_X.describe(include=[object])
#
# 3.
# 3.a.) df_telecom_X.groupby('customerid')[['charges.monthly']].mean().sort_values('charges.monthly', ascending=True)
#
# 3.1) df_telecom_X['charges.monthly'].mean()
# 3.2) df_telecom_X.groupby(['customerid','contract'])[['charges.total']].mean().sort_values('charges.total', ascending=False)
# 3.3) df_telecom_X.groupby(['customerid','charges.monthly'])[['cuentas_diarias']].mean().sort_values('cuentas_diarias', ascending=True)
#
# 3.4) df_median = (df_telecom_X['charges.total']>0)
# df_telecom_X[df_median].select_dtypes(include='number').mean()
# 3.4.a) df_telecom_X['charges.monthly'].min()
# 3.4.b) df_telecom_X['charges.monthly'].max()
# 3.4.c) df_telecom_X['churn'].value_counts()
#
# 3.5) filtro_churn = df_telecom_X['churn'] == 'Yes'
# df_telecom_X[filtro_churn]
# 3.5.a) df_churn_telecomX= df_telecom_X.groupby(['churn'])[['customerid']].count()
# df_churn_telecomX
# 3.5.b) df_churn_telecomX_gender= df_telecom_X.groupby(['churn'])[['gender']].value_counts()
# df_churn_telecomX_gender
# 3.5.c) df_churn_telecomX_contract= df_telecom_X.groupby(['churn'])[['contract']].value_counts()
# df_churn_telecomX_contract
#
# 3.5.d) df_churn_telecomX_PaymentMethod= df_telecom_X.groupby(['churn'])[['PaymentMethod']].value_counts()
# df_churn_telecomX_PaymentMethod
# 3.5.d.1) df_churn_telecomX_PaymentMethod_contract= df_telecom_X.groupby(['churn','contract'])[['PaymentMethod']].value_counts()
# df_churn_telecomX_PaymentMethod_contract
# 3.5.d.2) df_churn_telecomX_PaymentMethod_contract= df_telecom_X.groupby(['churn','gender'])[['PaymentMethod']].value_counts()
# df_churn_telecomX_PaymentMethod_contract
# 3.5.d.3) df_churn_telecomX_PaymentMethod_contract_gender= df_telecom_X.groupby(['churn','gender','contract'])[['PaymentMethod']].value_counts()
# df_churn_telecomX_PaymentMethod_contract_gender
#
# 3.6) df_churn_telecomX_internet_data= df_telecom_X.groupby(['churn','InternetService', 'contract'])[['OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies','phone_service']].count()
# df_churn_telecomX_internet_data
# 3.6.a) # @title OnlineSecurity
#
# from matplotlib import pyplot as plt
# df_churn_telecomX_internet_data['OnlineSecurity'].plot(kind='hist', bins=20, title='OnlineSecurity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
#
# 3.7) df_analizer_0 = df_telecom_X[df_telecom_X['churn'] == 'No']
# df_analizer_T = df_telecom_X[df_telecom_X['churn'] == 'Yes']
# df_analizer_0
# 3.7.a) df_churn_telecomX_monthly= df_telecom_X.groupby(['churn' , 'contract'])[['charges.monthly']].count()
# df_churn_telecomX_monthly
# 3.7.a.1) df_analize1 = df_churn_telecomX_monthly.loc[('No', slice(None)), :]
# df_analize1
# 3.7.a.1.a) df_analize1.plot(kind='bar', figsize=(10, 5), title='Churn by montly.charges', xlabel='Contract Type and Churn', ylabel='charges.monthly')
#
# 3.7.a.2) df_analize2 = df_churn_telecomX_monthly.loc[('Yes', slice(None)), :]
# df_analize2
# 3.7.a.2.a) df_analize1.plot(kind='bar', figsize=(10, 5), title='Churn by montly.charges', xlabel='Contract Type and Churn', ylabel='charges.monthly')
#
# 3.7.b) df_churn_telecomX_total= df_telecom_X.groupby(['churn' , 'contract'])[['charges.total']].count()
# df_churn_telecomX_total
# 3.7.b.1) df_analize3 = df_churn_telecomX_total.loc[('No', slice(None)), :]
# df_analize3
# 3.7.b.1.a) # @title charges.total
#
# from matplotlib import pyplot as plt
# df_analize3['charges.total'].plot(kind='line', figsize=(8, 4), title='charges.total')
# plt.gca().spines[['top', 'right']].set_visible(False)
#
# 3.7.b.2) df_analize4 = df_churn_telecomX_total.loc[('Yes', slice(None)), :]
# df_analize4
# 3.7.b.2.a) df_analize4 = df_churn_telecomX_total.loc[('Yes', slice(None)), :]
# df_analize4
#
#
#
# 3.8. df_churn_telecomX_cuentas_diarias= df_telecom_X.groupby(['churn' , 'contract'])[['cuentas_diarias']].count()
# df_churn_telecomX_cuentas_diarias
#
# 3.8.a) # @title cuentas_diarias
#
# from matplotlib import pyplot as plt
# df_churn_telecomX_cuentas_diarias['cuentas_diarias'].plot(kind='line', figsize=(16, 4), title='cuentas_diarias')
# plt.gca().spines[['top', 'right']].set_visible(False)
#
# 3.8.b) df_analize5 = df_churn_telecomX_cuentas_diarias.loc[('No', slice(None)), :]
# df_analize5
#
# 3.8.b.a) # @title cuentas_diarias
#
# from matplotlib import pyplot as plt
# df_analize5['cuentas_diarias'].plot(kind='line', figsize=(8, 4), title='cuentas_diarias')
# plt.gca().spines[['top', 'right']].set_visible(False)
#
# 3.8.c) df_analize6 = df_churn_telecomX_cuentas_diarias.loc[('Yes', slice(None)), :]
# df_analize6
#
# 3.8.c.a) # @title charges.total
#
# from matplotlib import pyplot as plt
# df_analize6['cuentas_diarias'].plot(kind='line', figsize=(8, 4), title='cuentas_diarias / Yes')
# plt.gca().spines[['top', 'right']].set_visible(False)
#
#
# 3.9.  df_churn_telecomX_phone_service= df_telecom_X.groupby(['phone_service', 'contract'])[['churn']].count()
# df_churn_telecomX_phone_service
#
# 3.9.a) # @title Texto de título predeterminado
# df_churn_telecomX_resumido= df_telecom_X.groupby(['contract'])[['churn','gender','charges.monthly','charges.total','cuentas_diarias','phone_service']].value_counts()
# df_churn_telecomX_resumido
#
# 3.10. df_churn_telecomX_resumido= df_telecom_X.groupby(['contract'])[['churn','gender','charges.monthly','charges.total','cuentas_diarias','phone_service']].value_counts()
# df_churn_telecomX_resumido
#
# 3.11.
# 3.11.a) df_telecom_X_count=df_telecom_X.count()
#
# 3.11.a.1) summary_data1 = {'Metric': ['churn', 'gender', 'contract','phone_service','PaymentMethod','InternetService'],
#                 'Value': [df_churn_X_count1, df_gender_X_count, df_contract_X_count, df_phone_X_count, df_paymentMethod_X_count, df_InternetService_X_count]}
# df_summary_no_numeric = pd.DataFrame(summary_data1)
# display(df_summary_no_numeric)
#
# 3.11.b) # Ensure 'charges.total' is numeric after filling nulls
# df_telecom_X['charges.total'] = pd.to_numeric(df_telecom_X['charges.total'], errors='coerce').fillna(0).astype(float)
#
# df_sum = df_telecom_X['charges.total']
# df_sum_total= df_sum.sum()
# df_sum_total
#
# 3.11.b.1) # @title Metric
#
# from matplotlib import pyplot as plt
# import seaborn as sns
# df_summary.groupby(['Metric','Value']).size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(True)
#
#
# 3.12. df_telecom_X.to_json('telecom_X_final_1.json')
#
# pd.read_json('telecom_X_final_1.json').head()

# %% [markdown]
# ##**Analisis_ Exploratorio 'presentacion-resumen':**

# %% [markdown]
# ###**Análisis Exploratorio de Datos: Presenta los análisis realizados, incluyendo gráficos y visualizaciones para identificar patrones.**

# %% [markdown]
# ####**Cantidad de Usuario**
#
# *   El archivo df_telecom_X tiene 7267 registros de usuarios con sus servicios contractados para la empresa TelecomX.

# %%
df_telecom_X.info()

# %% [markdown]
# ####**El dataframe df telecom X ** tiene, despues de la modificacion:
#
#
# *   Filas =     7267
# *   Columnas =    23

# %%
df_telecom_X.shape

# %% [markdown]
# ####**Las columnas del dataframe TelecomX** son:
#
# > 'customerid', 'churn', 'customer', 'phone', 'internet', 'account',
#        'gender', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'phone_service', 'contract', 'paperless_billing', 'PaymentMethod',
#        'charges.monthly', 'charges.total', 'Tiempo_de_Contrato',
#        'cuentas_diarias', 'total_contracto'

# %%
df_telecom_X.columns

# %% [markdown]
# ####**Las columnas del dataframe TelecomX y sus tipos de datos** son:

# %%
df_telecom_X.dtypes

# %% [markdown]
# ####** La Media, minimos, maximos  de los Cargos Mensual, Total y Diarios**
#
# Media:
# charges.monthly 64.755423
# charges.total 2280.634213
# cuentas_diarias 2.158514
#
# los Minimos:
# El minimo cargo mensual es de 18.25
# El minimo cargo total es de 18.80
# El minimo cuentas diarias es de 0.6083333333333333
#
# los Maximos:
# charges.monthly 118.750000
# charges.total 8684.800000
# cuentas_diarias 3.958333

# %%
import numpy as np

df_telecom_X.describe(include=[np.number])

# %% [markdown]
# ####**Cantidades relevantes**
#
#
#
# *   Churn (evasion) : yes/no No= 5174 Yes= 1869 vacio= 224
# *   Gender: Male /Hombre=	3675  Female /Mujer=	3592
# *   servicio telefonico: Yes=	6560  No=	707
# *   servicio de internet: Fiber optic=	3198 DSL=	2488 No=	1581
# *   metodo de pago: Electronic check=	2445 Mailed check=	1665 Bank transfer (automatic)=	1589  Credit card (automatic)=	1568
# *   tipo de contracto: Month-to-month=	4005 Two year=	1743 One year=	1519

# %%
summary_data1 = {'Metric': ['churn', 'gender', 'contract','phone_service','PaymentMethod','InternetService'],
                'Value': [df_churn_X_count1, df_gender_X_count, df_contract_X_count, df_phone_X_count, df_paymentMethod_X_count, df_InternetService_X_count]}
df_summary_no_numeric = pd.DataFrame(summary_data1)
display(df_summary_no_numeric)

# %%
from google.colab import sheets

# Convert the Series in the 'Value' column to strings
df_summary_no_numeric['Value'] = df_summary_no_numeric['Value'].astype(str)

sheet = sheets.InteractiveSheet(df=df_summary_no_numeric)
# Out:
# https://docs.google.com/spreadsheets/d/1b-Uga_Z7BuVKnc9FJ4y_z6_RmNCNwFBkTMxWfhvbAPg/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1b-Uga_Z7BuVKnc9FJ4y_z6_RmNCNwFBkTMxWfhvbAPg/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ##**Analisis_ Comparativo 'La Evacion / Churn y el cliente':**
#
#
#
# "**Churn de Clientes**". La empresa enfrenta una alta tasa de cancelaciones y necesita comprender los factores que llevan a la pérdida de clientes

# %% [markdown]
# ###**Churn en los usuarios  / cuantos se retiraron**
#
# *Churn y customer Id *
# vacio = 224
# churn No = 5174
# churn Yes = 1869 total de 7267 usuarios de la empresa telecom X
#
# analisis: de los 7267 registros (clientes) de la base de datos del archivo telecomX, 1869 se retiran (churn= Yes), 5174 no se retiran (churn= No) y 224 registros (clientes) no se ha definido si se retiron o no se retiron.
#
# La empresa telecomX de los 7267 clientes, no se retiraron el 71.2%, continuaron utilizando los servicios contratados de la compañia y se retiron el 25.7 %, no continuaron utilizando mas sus servicios, generando que de los 7267 usuarios, cancelaron la cuarta parte los servicios y un 3.1 % no se ha definido si se retiro y dejo de utilizar los servicios o continuo con los servicios contratados con la compañia Telecom X.
#
# **RECOMENDACIONES**
# se recomienda, definir este 3.1%, que representa 224 registros, para poder clasificarlos en el churn, poder generar las acciones necesarias para poder frenar la evacion. / se recomienda actualizar el archivo base de registro de telecomX, de sus usuarios y servicios contractados. Para una mejor clasificacion  y Analisis.

# %%
df_churn_telecomX= df_telecom_X.groupby(['churn'])[['customerid']].count()
df_churn_telecomX
# Out:
#        customerid
# churn
#               224
# No           5174
# Yes          1869

# %%
df_churn_telecomX.plot(kind='pie', y='customerid', figsize=(10,8), color='purple', title='Churn en el TelecomX', xlabel='churn', ylabel='Cantidad de clientes', autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'Churn en el TelecomX'}, ylabel='Cantidad de clientes'>

# %%
filtro_churn_ = df_telecom_X['churn'] == ''
df_telecom_X[filtro_churn_].index
# Out:
# Index([3538, 7058, 3900, 1364, 3053, 2690, 7239, 1160, 2913, 2584,
#        ...
#        3438, 5871, 4769, 4938, 6913,  640, 1517, 3177, 2576, 4199],
#       dtype='int64', length=224)

# %%
df_telecom_X.loc[7062]
# Out:
# customerid                                                   9724-BFUOP
# churn
# customer              {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# phone                   {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# internet              {'InternetService': 'Fiber optic', 'OnlineSecu...
# account               {'Contract': 'Month-to-month', 'PaperlessBilli...
# gender                                                           Female
# internetservice                                             Fiber optic
# onlinesecurity                                                       No
# onlinebackup                                                         No
# deviceprotection                                                     No
# techsupport                                                          No
# streamingtv                                                          No
# streamingmovies                                                      No
# ...

# %%
df_telecom_X[filtro_churn_]
# Out:
#       customerid churn                                           customer  \
# 3538  4878-SMQBX        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7058  9717-WXVSB        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3900  5332-UJJBL        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 1364  1972-RSMOV        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 3053  4250-QVQRU        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# ...          ...   ...                                                ...
# 640   0910-AJOHQ        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1517  2183-ZULVZ        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 3177  4438-GGYWL        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2576  3590-DWSLF        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4199  5766-RLNAM        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                 phone  \
# ...

# %% [markdown]
# ###**Churn en los usuarios  / cuantos se retiraron / Analisis por Genero\**
#
# se puede observa unos datos muy cercanos y casi iguales entre los clientes que continuaron utilizando los servicios de telecomX, los que no y los que no se han definido, la cantidad tanto para hombres como para mujeres.
#
# tenemo:
#
# *   Continuaron Churn: **No**= Male=	2625 Female=	2549 para un **50.734 % / 49.265 %**
#
# *   NO continuaron Churn: **YES**=  Female=	939 Male=	930 para un **50.24 % / 49.76 %**
# *   NO se han definido:  Male=	120  Female=	104 para un **53.571 % / 46.428 %**
#
# valores sobre el total de churn no, churn yes y churn ''.
#
# segun los datos analizados y arrojados, que son muy cercanos su diferencia es poca solo en los casos que el churn no esta definido, podemos afirmar que el genero sea hombre o mujer no influye en la condicion de continuar o no continuar con los servicios contratados de la empresa telecomX. / tenemos en muchos casos un 50 / 49 % para mujer y hombre o viceversa en terminos son iguales y casos muy pequeños marcarian un diferencia, pero podemos estar hablando de un 50 /50, ** el genero no marco tendencia sobre el churn.**

# %%
df_churn_telecomX_gender= df_telecom_X.groupby(['churn'])[['gender']].value_counts()
df_churn_telecomX_gender
# Out:
# churn  gender
#        Male       120
#        Female     104
# No     Male      2625
#        Female    2549
# Yes    Female     939
#        Male       930
# Name: count, dtype: int64

# %%
##no_churn_gender_porcentil_male= 5174*100
##yes_churn_gender_porcentil= 1869
##_churn_gener_porcentil= 224

# %% [markdown]
# ** no churn / gender /// male / female// ** // continuaron con el servicio

# %%
no_churn_gender_porcentil_male= (2625/5174)*100
no_churn_gender_porcentil_male
# Out:
# 50.73444143795902

# %%
no_churn_gender_porcentil_female= (2549/5174)*100
no_churn_gender_porcentil_female
# Out:
# 49.26555856204097

# %% [markdown]
# ** yes churn / gender /// male / female// ** // se retiron del servicio.

# %%
yes_churn_gender_porcentil_male= (930/1869)*100
yes_churn_gender_porcentil_male
# Out:
# 49.75922953451043

# %%
yes_churn_gender_porcentil_female= (939/1869)*100
yes_churn_gender_porcentil_female
# Out:
# 50.24077046548957

# %%
_churn_gener_porcentil_male= (120/224)*100
_churn_gener_porcentil_male
# Out:
# 53.57142857142857

# %%
_churn_gener_porcentil_female = (104/224)*100
_churn_gener_porcentil_female
# Out:
# 46.42857142857143

# %%
###df_churn_telecomX_gender[(df_churn_telecomX_gender.index.get_level_values('churn') == 'No') & (df_churn_telecomX_gender.index.get_level_values('gender') == 'Male')]

# %%
df_churn_telecomX_gender_percentage.plot(kind='pie', y='count', figsize=(10, 8), autopct='%1.1f%%', title='Churn Percentage Distribution by Gender', ylabel='Percentage')
# Out:
# <Axes: title={'center': 'Churn Percentage Distribution by Gender'}, ylabel='Percentage'>

# %% [markdown]
# ###**Churn ****en los usuarios  / cuantos se retiraron / Analisis por  Contrato/Genero\** ****
#
#
#
# *   **de los clientes que no se retiron** el contrato que tanto hombre como mujeres continuaron fue el contrato contratado mes a mes; luego siguio el contrato a 2 años y por ultimo el contrato a 1 año.
#
# *   **de los clientes que se retiron **el contrato que tanto hombres como mujeres tuvo mayores retiros, fue el contrato mes a mes, luego siguio el contrato a 1 año y por ultimo el contrato a 2 años.
#
# *   **El contrato con menos retiros es el contrato 2 dos años**, contratados por mujeres. con una cantidad de 22 usuarios que se retiron. representa una proporsion en mujeres o hombres que se retiron de los servicios contratados por la empresa telecomX, del 1% al rededor del valor total de los usuarios que se retiron de los servicios de la empresa telecomX.
#
# **RECOMENDACION**
# recomendacion: revisar las clausulas y beneficios del contrato por un año, determinando y comprarando con los contrato mes a mes y el contrato por dos años.
# ademas revisar el contrato por dos años, para determinar que ventajas se pueden implementar en proporcion al servicio contratado sea en tarifa o beneficios, para poder mantener mas tiempo al usuario final en estos contratos contratados.

# %% [markdown]
# 	count
# contract
# Month-to-month	4005
# Two year	1743
# One year	1519

# %%
df_churn_telecomX_contract1= df_telecom_X.groupby(['churn','gender'])[['contract']].value_counts()
df_churn_telecomX_contract1
# Out:
# churn  gender  contract
#        Female  Month-to-month      57
#                Two year            25
#                One year            22
#        Male    Month-to-month      73
#                One year            24
#                Two year            23
# No     Female  Month-to-month    1083
#                Two year           823
#                One year           643
#        Male    Month-to-month    1137
#                Two year           824
#                One year           664
# Yes    Female  Month-to-month     842
#                One year            75
#                Two year            22
#        Male    Month-to-month     813
#                One year            91
#                Two year            26
# Name: count, dtype: int64

# %% [markdown]
# **no_churn_gender_porcentil_male= 5174*100
# **yes_churn_gender_porcentil= 1869
# **_churn_gener_porcentil= 224

# %%
yes_churn_gender_porcentil_male_m = (813/1869)*100

# %%
yes_churn_gender_porcentil_male_1= (91/1869)*100

# %%
yes_churn_gender_porcentil_male_2= (26/1869)*100

# %%
yes_churn_gender_porcentil_female_m= (842/1869)*100

# %%
yes_churn_gender_porcentil_female_1= (75/1869)*100

# %%
yes_churn_gender_porcentil_female_2= (22/1869)*100

# %% [markdown]
# **Tabla Metrica**

# %%
summary_data2 = {'Metric': ['mounth_male', 'one_male', 'two_male','mounth_female','one_female','two_female'],
                'Value': [yes_churn_gender_porcentil_male_m, yes_churn_gender_porcentil_male_1, yes_churn_gender_porcentil_male_2, yes_churn_gender_porcentil_female_m, yes_churn_gender_porcentil_female_1, yes_churn_gender_porcentil_female_2]}
df_summary_no_numeric = pd.DataFrame(summary_data2)
display(df_summary_no_numeric)
# Out:
#           Metric      Value
# 0    mounth_male  43.499197
# 1       one_male   4.868914
# 2       two_male   1.391118
# 3  mounth_female  45.050829
# 4     one_female   4.012841
# 5     two_female   1.177100

# %%
df_churn_telecomX_contract1.plot(kind='pie', y='count', figsize=(15, 10), autopct='%1.1f%%', title='Churn Percentage Distribution by Contract / Gender', ylabel='Percentage')
# Out:
# <Axes: title={'center': 'Churn Percentage Distribution by Contract / Gender'}, ylabel='Percentage'>

# %% [markdown]
# ###**Churn ****en los usuarios  / cuantos se retiraron / Analisis por/Genero\metodo de pago** ****
#
#
#
# *   El metodo de pago mas utilizado para los clientes hombres y mujeres,que no se retiron y utilizan los servicios de telecom x es:
#   * **hombres: mailed check.** (con un **40.6%**, sobre el total de usuarios que utilizan el metodo de pago)
#   * **mujeres: bank transfer(automatic). (con un **41%**, sobre el total de usuarios que utilizan el metodo de pago)
#
# aunque los otros metodos de pago, como Electronic check, Credit card, (automatic), son utilizados con la misma frecuencia que el mailed check y el bank transfer(automatic); pudiendo afirmar que los clientes que no se retiron, utilizan todos los 4 metodos de pago, con la misma frecuencia, segun sea su posiblidad.
#
# * para los clientes, que se retiron, el metodo de pago mas utilizado es el:
#   * **Electronic check. (con un **43.45%**, sobre el total de usuarios que utilizan el metodo de pago)
#
# luego en menor frecuencia sigue el mailed check, bank transfer(automatic) y credit card (automatic).
#
# **Recomendaciones**, revisar por que los clientes que todavia se conservan (no )utilizando los servicios de telecomX, no se retiron, utilizan los 4 medios de pago con la misma frecuencia, como buscando alternativas de pago, cuando algun medio o muchos fallan y por que los clientes que se retiron el metodo de pago mas utilizado era electronic check, y los otros metodos, casi no eran utilizados.
#   * revisar que inconvenientes han tenido con estos metodos de pago, en el momento de hacer sus pagos, para determinar si, el metodo de pago pudo determinar la desicion del retiro de los clientes al utilizar los servicios de telecomX.
#
#
#
# **OBSERVACIONES**
# se observa una descongestion para el metodo de pago **ElectronicCheck**,
#
# ya que los clientes de la **compañia TelecomX**; ya que se retiron, la gran mayoria tanto hombres como mujeres, los que utilizaban el metodo de pago **electronicCheck**  siendo un total de ** 1.071 usuarios ** que dejaron de utilizar este metodo de pago, por que se retiron de la compañia; Lo cual representa ** un total de 43.45% **, sobre el total de usuarios que seleccionaron este metodo, que representa un total 2445 usuarios, representando un **1.374* usuarios, que no se retiron y utilizan este metodo de pago, representando un total de ** 56.2% ** que lo siguen utilizando. quedando un 43.45% descongestionado, ya que era el metodo de pago con mas clientes que lo utilizaban.
#
#  paymentmethod / total de usuarios que lo usan sobre el total de clientes (**7267 registros_clientes**) de la compañia telecomX
#
# Electronic check	2445
# Mailed check	1665
# Bank transfer (automatic)	1589
# Credit card (automatic)	1568
#
# Permitiendo asi que, despues del analisis los metodos de pago por usuario queden de la siguiente manera: (analisis y modificacion al mas usado /ElectronicCheck)
#
# Electronic check	** 1374 **
# Mailed check	1665
# Bank transfer (automatic)	1589
# Credit card (automatic)	1568
#
# Generando que los metodos de pago utilizados tengan en proporcion de uso, la misma cantidad de usuarios y no exista un metodo mas congestionado que otros.
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# para **los clientes que no se retiron:**
#
# **HOMBRES -/- uso metodos de pago** / porcentaje calculado sobre total de usuarios que utiliza este metodo de pago.
#
# Electronic check	26,4%
# Mailed check	    40.6%
# Bank transfer (automatic)	39.9%
# Credit card (automatic)	  42.66%
#
#
# **MUJERES -/- uso metodos de pago** / porcentaje calculado sobre total de usuarios que utiliza este metodo de pago.
#
# Electronic check	26,5%
# Mailed check	    37.72%
# Bank transfer (automatic)	41%
# Credit card (automatic)	  39.60%
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# 	count
# paymentmethod
# Electronic check	2445
# Mailed check	1665
# Bank transfer (automatic)	1589
# Credit card (automatic)	1568

# %%
df_churn_telecomX_PaymentMethod_contract= df_telecom_X.groupby(['churn','gender'])[['paymentmethod']].value_counts()
df_churn_telecomX_PaymentMethod_contract
# Out:
# churn  gender  paymentmethod
#        Female  Electronic check              35
#                Bank transfer (automatic)     25
#                Credit card (automatic)       22
#                Mailed check                  22
#        Male    Electronic check              45
#                Mailed check                  31
#                Credit card (automatic)       24
#                Bank transfer (automatic)     20
# No     Female  Bank transfer (automatic)    652
#                Electronic check             648
#                Mailed check                 628
#                Credit card (automatic)      621
#        Male    Mailed check                 676
#                Credit card (automatic)      669
#                Electronic check             646
#                Bank transfer (automatic)    634
# Yes    Female  Electronic check             522
#                Mailed check                 150
#                Bank transfer (automatic)    136
# ...

# %% [markdown]
# **Porcentaje**

# %% [markdown]
# **Churn= Yes Genero= Mujer**

# %%
yes_churn_gender_porcentil_Female_EC = (522/2445)*100

# %%
yes_churn_gender_porcentil_Female_MC = (150/1665)*100

# %%
yes_churn_gender_porcentil_Female_BT = (136/1589)*100

# %%
yes_churn_gender_porcentil_Female_CC = (131/1568)*100

# %% [markdown]
# **Metrica**

# %%
summary_data_PM = {'Metric': ['Churn_Y_ElectronicCheck', 'Churn_Y_MailCheck', 'Churn_Y_BankTransfer','Churn_Y_CreditCard'],
                'Value': [yes_churn_gender_porcentil_Female_EC, yes_churn_gender_porcentil_Female_MC, yes_churn_gender_porcentil_Female_BT, yes_churn_gender_porcentil_Female_CC]}
df_summary_no_numeric_PM = pd.DataFrame(summary_data_PM)
display(df_summary_no_numeric_PM)
# Out:
#                     Metric      Value
# 0  Churn_Y_ElectronicCheck  21.349693
# 1        Churn_Y_MailCheck   9.009009
# 2     Churn_Y_BankTransfer   8.558842
# 3       Churn_Y_CreditCard   8.354592

# %% [markdown]
# **Churn= Yes Genero= Hombre**

# %%
yes_churn_gender_porcentil_Male_EC = (549/2445)*100

# %%
yes_churn_gender_porcentil_Male_MC = (158/1665)*100

# %%
yes_churn_gender_porcentil_Male_BT = (122/1589)*100

# %%
yes_churn_gender_porcentil_Male_CC = (101/1568)*100

# %% [markdown]
# **Metrica**

# %%
summary_data_PM1 = {'Metric': ['M_Churn_Y_ElectronicCheck', 'M_Churn_Y_MailCheck', 'M_Churn_Y_BankTransfer','M_Churn_Y_CreditCard'],
                'Value': [yes_churn_gender_porcentil_Male_EC, yes_churn_gender_porcentil_Male_MC, yes_churn_gender_porcentil_Male_BT, yes_churn_gender_porcentil_Male_CC]}
df_summary_no_numeric_PM1 = pd.DataFrame(summary_data_PM1)
display(df_summary_no_numeric_PM1)
# Out:
#                       Metric      Value
# 0  M_Churn_Y_ElectronicCheck  22.453988
# 1        M_Churn_Y_MailCheck   9.489489
# 2     M_Churn_Y_BankTransfer   7.677785
# 3       M_Churn_Y_CreditCard   6.441327

# %% [markdown]
# ****

# %% [markdown]
# **Churn= NO Genero= Hombre**

# %%
no_churn_gender_porcentil_Male_MC = (676/1665)*100

# %%
no_churn_gender_porcentil_Male_CC = (669/1568)*100

# %%
no_churn_gender_porcentil_Male_EC = (646/2445)*100

# %%
no_churn_gender_porcentil_Male_BT = (634/1589)*100

# %% [markdown]
# **Metrica**

# %%
summary_data_PM2 = {'Metric': ['M_Churn_N_ElectronicCheck', 'M_Churn_N_MailCheck', 'M_Churn_N_BankTransfer','M_Churn_N_CreditCard'],
                'Value': [no_churn_gender_porcentil_Male_EC, no_churn_gender_porcentil_Male_MC, no_churn_gender_porcentil_Male_BT, no_churn_gender_porcentil_Male_CC]}
df_summary_no_numeric_PM2 = pd.DataFrame(summary_data_PM2)
display(df_summary_no_numeric_PM2)
# Out:
#                       Metric      Value
# 0  M_Churn_N_ElectronicCheck  26.421268
# 1        M_Churn_N_MailCheck  40.600601
# 2     M_Churn_N_BankTransfer  39.899308
# 3       M_Churn_N_CreditCard  42.665816

# %% [markdown]
# **Churn= NO Genero= Mujer**

# %%
no_churn_gender_porcentil_Female_BT = (652/1589)*100

# %%
no_churn_gender_porcentil_Female_EC = (648/2445)*100

# %%
no_churn_gender_porcentil_Female_MC = (628/1665)*100

# %%
no_churn_gender_porcentil_Female_CC = (621/1568)*100

# %% [markdown]
# **Metrica**

# %%
summary_data_PM3 = {'Metric': ['_Churn_N_ElectronicCheck', '_Churn_N_MailCheck', '_Churn_N_BankTransfer','_Churn_N_CreditCard'],
                'Value': [no_churn_gender_porcentil_Female_EC, no_churn_gender_porcentil_Female_MC, no_churn_gender_porcentil_Female_BT, no_churn_gender_porcentil_Female_CC ]}
df_summary_no_numeric_PM3 = pd.DataFrame(summary_data_PM3)
display(df_summary_no_numeric_PM3)
# Out:
#                      Metric      Value
# 0  _Churn_N_ElectronicCheck  26.503067
# 1        _Churn_N_MailCheck  37.717718
# 2     _Churn_N_BankTransfer  41.032096
# 3       _Churn_N_CreditCard  39.604592

# %%
df_churn_telecomX_PaymentMethod_contract.plot(kind='pie', y='count', figsize=(15, 10), autopct='%1.1f%%', title='Churn Percentage Distribution by paymethod / Gender', ylabel='Percentage')
# Out:
# <Axes: title={'center': 'Churn Percentage Distribution by paymethod / Gender'}, ylabel='Percentage'>

# %% [markdown]
# ###**Churn ****en los usuarios  / cuantos se retiraron / Analisis por/Genero\ servicios de telefonia e internet** ****

# %% [markdown]
# **count
# internetservice
# Fiber optic	3198
# DSL	2488
# No	1581
# **
#
# **	count
# phone_service
# Yes	6560
# No	707
# **
#
# **
# *Churn y customer Id * vacio = 224 churn No = 5174 churn Yes = 1869 total de 7267 usuarios de la empresa telecom X
# **
#
# **OBSERVACIONES**
#
# la empresa TelecomX, tiene el % de clientes con servicio telefonico contratado y el % restante, con servicio telefonico no contratado, de esos 7267 clientes en total se observa lo siguiente:
#
#
# *   **1.699 clientes se han retirado** y tenian servicio telefonico, representando el **23.38%** y **170 clientes se retiron, pero no tenian servicio telefonico**, representando el **2.34%**.
#
# *   **4.662 clientes no se han retirado, continuan con el servicio contratado** y tienen el servico de telefonia contratado, representado **el 64.15%**
#
# * **512 clientes no se han retirado**, pero no tienen el servicio telefonico, contratado, representando el 7.04%
#
# Segun las observaciones de estos datos, podemos afirmar que, la mayor cantidad de **clientes que no cancelaron, tienen servicio telefonico, contratado**. y la cantidad de hombres y mujeres que tienen servicio telefonico contratado y no se retiron es muy similar, para no igual de **32.53% a 31.62%.**
#
# tambien se observa que la mayor cantidad de clientes que se retiraron, tienen servicio telefonico contratado, en una relacion de 23.38%; mientras que 2.34%, que son los clientes que se retiron y no tenian servicio telefonico contratado, siendo una de 170 clientes.
#
# Pudiendo afirmar que el genero, no determina la contratacion del servicio telefonico, pero la gran mayoria de clientes que se retiron tenian servicio telefonico contratado siendo 1699, que se retiron y tenian contratado servicio telefonico.
#
# Por lo anterior se puede afirmar que:_ tener servicio telefonico contratado, marca tendencia en los clientes que se retiran de la compañia, de una relacion de 23.38% a 2.34%, entres los clientes que se retiron.
#
# **RECOMENDACIONES:**
#
# Revisar el servicio telefonico, tarifa, precio, calidad y funcionalidad, para evitar que este servicio contratado, marque mas la pauta en el retiro de los clientes de **la empresa TelecomX**, y se convierta en una tendencia.

# %% [markdown]
# *count internetservice Fiber optic 3198 DSL 2488 No 1581 *
# **RETIROS DE CLIENTES / SERVICIO DE INTERNET**
#
# de los 7267 clientes registrados, tenemos que los servicios de internet utilizados son:
#
# internetservice
# * Fiber optic 3198 clientes  **44.01%**
# * DSL 2488 clientes          **34.24%**
# * No 1581 clientes           **21.75**
# Total de 7267 clientes      =100%
#
# el genero no determina la eleccion de los servicios de internet, sino la continuidad en el servicio y la tendencia.
#
# * **los clientes que se retiron**, tanto hombres como mujeres, tenian el servicio de internet **FiberOptic** / contratado: 1.297 clientes, **el 17.85%**
#
# **Para los clientes que continuaron**, se observan dos servicios de internet como los mas seleccionados:
#
# ***los clientes que continuaron**, tanto hombres como mujeres, tenien el servicio de internet **DSL** / contratado: 1.962 clientes, **el 27%**
# ***los clientes que continuaron**, tanto hombres como mujeres, tenien el servicio de internet **FiberOptic** / contratado: 1.799 clientes,**el 24.75%****
#
# Para los clientes, **que se retiron**, las **mujeres** son las que tienen la mayor cantidad de servicios de **Fiber Optica contratados = 664 **, mientras los **hombres** son los que tenian la mayor cantidad de servicios **DSL = 240** contratados; para **aquellos que no tienen servicios de internet contratados**, las **cantidades son muy cercanas / similares 56/57**.
#
# Para los clientes, **que continuaron**, los **hombres** son los que tienen la mayor cantidad de servicios de internet contratados **DSL = 993**, **fiberOptic =910**, y **no tienen servicio de internet = 722.**
#
# **RECOMENDACIONES**
# revisar el servicio de FiberOptica, calidad, conectividad, tarifa, velocidad, ya que marca la tendencia en los clientes y sus servicios que fueron cancelados. / clientes que se retiraron.
#
# Tambien revisar el servicio DSL, pues es el servicio mas elegido, en los clientes que no se retiron, que continuaron con sus servicios.
#
# Revisar urgentemente estos dos servicios de internet, ya que la menor cantidad de clientes que se retiron, se registra, en aquellos clientes, que no tienen servicios de internet contratados.
#
# **CONCLUSION**
# Por lo anterior se concluye, que el servicio de internet, esta marcando la pauta, en el retiro de los clientes, de la compañia, TelecomX. / COLOCAR ESPECIAL ATENCION EN LOS CLIENTES QUE TIENEN CONTRATADOS LOS **SERVICIOS DSL /FIBER_OPTIC**

# %%
df_churn_telecomX_internet_data_anar= df_telecom_X.groupby(['churn','internetservice','gender'])[['phone_service']].value_counts()
df_churn_telecomX_internet_data_anar
# Out:
# churn  internetservice  gender  phone_service
#        DSL              Female  Yes               21
#                                 No                13
#                         Male    Yes               21
#                                 No                12
#        Fiber optic      Female  Yes               45
#                         Male    Yes               57
#        No               Female  Yes               25
#                         Male    Yes               30
# No     DSL              Female  Yes              718
#                                 No               251
#                         Male    Yes              732
#                                 No               261
#        Fiber optic      Female  Yes              889
#                         Male    Yes              910
#        No               Female  Yes              691
#                         Male    Yes              722
# Yes    DSL              Female  Yes              139
# ...

# %% [markdown]
# **analisis 2**

# %%
df_churn_telecomX_internet_data_anar2= df_telecom_X.groupby(['churn','gender'])[['internetservice']].value_counts()
df_churn_telecomX_internet_data_anar2
# Out:
# churn  gender  internetservice
#        Female  Fiber optic         45
#                DSL                 34
#                No                  25
#        Male    Fiber optic         57
#                DSL                 33
#                No                  30
# No     Female  DSL                969
#                Fiber optic        889
#                No                 691
#        Male    DSL                993
#                Fiber optic        910
#                No                 722
# Yes    Female  Fiber optic        664
#                DSL                219
#                No                  56
#        Male    Fiber optic        633
#                DSL                240
#                No                  57
# Name: count, dtype: int64

# %% [markdown]
# **analisis 3**

# %%
df_churn_telecomX_internet_data_anar3= df_telecom_X.groupby(['churn','gender'])[['phone_service']].value_counts()
df_churn_telecomX_internet_data_anar3
# Out:
# churn  gender  phone_service
#        Female  Yes                91
#                No                 13
#        Male    Yes               108
#                No                 12
# No     Female  Yes              2298
#                No                251
#        Male    Yes              2364
#                No                261
# Yes    Female  Yes               859
#                No                 80
#        Male    Yes               840
#                No                 90
# Name: count, dtype: int64

# %% [markdown]
# **porcentaje / global **

# %% [markdown]
# ** Churn= no ............ PhoneService= yes **

# %%
analisis_phone_yes_churn_no_ = (4662/7267 )*100
analisis_phone_yes_churn_no_
# Out:
# 64.15302050364662

# %%
analisis_phone_yes_churn_no_Female = (2298/7267 )*100
analisis_phone_yes_churn_no_Female
# Out:
# 31.622402642080637

# %%
analisis_phone_yes_churn_no_Male = (2364/7267 )*100
analisis_phone_yes_churn_no_Male
# Out:
# 32.530617861565986

# %% [markdown]
# ** Churn= no ............ PhoneService= no **

# %%
analisis_phone_no_churn_no_ = (512/7267 )*100
analisis_phone_no_churn_no_
# Out:
# 7.045548369340857

# %%
analisis_phone_no_churn_no_Female = (251/7267 )*100
analisis_phone_no_churn_no_Female
# Out:
# 3.453970001376084

# %%
analisis_phone_no_churn_no_Male = (261/7267 )*100
analisis_phone_no_churn_no_Male
# Out:
# 3.591578367964772

# %% [markdown]
# ** Churn= yes ............ PhoneService= yes **

# %%
analisis_phone_yes_churn_yes_ = (1699/7267 )*100
analisis_phone_yes_churn_yes_
# Out:
# 23.379661483418193

# %%
analisis_phone_yes_churn_yes_Female = (859/7267 )*100
analisis_phone_yes_churn_yes_Female
# Out:
# 11.82055868996835

# %%
analisis_phone_yes_churn_yes_Male = (840/7267 )*100
analisis_phone_yes_churn_yes_Male
# Out:
# 11.559102793449842

# %% [markdown]
# ** Churn= no ............ PhoneService= yes **

# %%
analisis_phone_yes_churn_no_ = (170/7267 )*100
analisis_phone_yes_churn_no_
# Out:
# 2.3393422320077057

# %%
analisis_phone_yes_churn_no_Female = (80/7267 )*100
analisis_phone_yes_churn_no_Female
# Out:
# 1.1008669327095089

# %%
analisis_phone_yes_churn_no_Male = (90/7267 )*100
analisis_phone_yes_churn_no_Male
# Out:
# 1.2384752992981973

# %%
df_churn_telecomX_internet_data_anar3_percentage = df_churn_telecomX_internet_data_anar3 / df_churn_telecomX_internet_data_anar3.sum() * 100
df_churn_telecomX_internet_data_anar3_percentage
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2223161923.py in <cell line: 0>()
# ----> 1 df_churn_telecomX_internet_data_anar3_percentage = df_churn_telecomX_internet_data_anar3 / df_churn_telecomX_internet_data_anar3.sum() * 100
#       2 df_churn_telecomX_internet_data_anar3_percentage
#
# NameError: name 'df_churn_telecomX_internet_data_anar3' is not defined

# %% [markdown]
# ###Churn **en los usuarios / cuantos se retiraron / Analisis por/Genero\ Cargo mensual, total, cuentas diarias y total de contrato** ****
#
# LOS CARGOS, PARA LOS 7267 CLIENTES, SEGUN SUS SERVICIOS CONTRATADOS Y TIPOS DE CONTRATOS, SUMAN: **moneda / pesos colombianos**
# ```
# Sum Monthly Charges,"$470.320,95"
# Sum Total Charges,"$16.548.281,85"
# Sum Daily Accounts,"$15.677,37"
# total_contracto,"$215.654.844,90"
# ,
# TOTALES,"$232.689.125,07"
# ```
#
# Para los cargos mensuales segun churn y contracto, tenemos:
#
# ´-------resumen---- analitico con churn-----´-
# ```
# charges.monthly
# ,,
# churn,contract,values
# ,Month-to-month,"$8.415,95"
# No,Month-to-month,"$136.447,05"
# Yes,Month-to-month,"$120.847,10"
# ,
# TOTALES, "$ 265710,1"
# ```
#
# ```
# charges.monthly,,,,,CARGO TOTAL / MENSUAL
# ,,,,,,,"$470.320,95"
# churn,contract,values,TOTAL,PORCENTAJE / Total Cargo Mensual / Month-to-month,PORCENTAJE / Total Cargo Mensual,,
# ,Month-to-month,"$8.415,95",,"3,17%","1,79%",,
# No,Month-to-month,"$136.447,05",,"51,35%","29,01%",,
# Yes,Month-to-month,"$120.847,10",,"45,48%","25,69%",,
# ```
# **Cargo Mensual / contracto month_to_Month**
# **Conclusion: de los cargos mensuales, para los contratos mes a mes** que representan **_($ 265710,1)_ el 56.50% del cargo mensual total($470.320,95)**, hubo un retiro (contratos cancelados); perdida de **$120.847,10**, representando una cancelacion de estos contratos del **45.48%**; para un   ** 51,35%**_**($136.447,05)**_ de clientes que todavia tienen sus contratos vigentes con la compañia **telecomX.**
#
# **Recomendacion:**
# hacer enfasis y mayor analisis, **en los contratos mes a mes de los cargos mensuales**, ya que hay una perdida significativa en facturacion mensual, pues el **45.48%** _($120.847,10)_ de los contratos cancelados en los cargos mensuales, eran los contratos mes a mes, que representan la mayor facturacion del cargo mensual, dando un representativo total del **56.50%. _($ 265710,1)_**
# ```
#
#
# -----´Tablas _ Cargo Mensual´------
# ,,,,,,,,,
# ,,,,CHURN
# TOTALES,Values,%Porcentaje / CARGO TOTAL MENSUAL,,,NO,YES,%,%nO,%YES
# Month-to-month,"$265.710,10","56,50%",,"$8.415,95","$136.447,05","$120.847,10","3,17%","51,35%","45,48%"
# One year,"$99.089,45","21,07%",,"$3.272,85","$81.698,15","$14.118,45","3,30%","82,45%","14,25%"
# Two year,"$105.521,40","22,44%",,"$2.515,55","$98.840,55","$4.165,30","2,38%","93,67%","3,95%"
# CARGO TOTAL / MENSUAL,"$470.320,95","100,00%","0,00%","$14.204,35","$316.985,75","$139.130,85","8,85%","227,47%","63,68%"
# ,,,,,,,,,
# ```
#
#
#
# ---------------------------´Cargos_Totales´-----------------------------------
#
# Para los cargos totales segun churn y contracto, tenemos:
#
# ```
# TOTALES,Values,%Porcentaje / Cargo Total
# Month-to-month,"$5.473.789,50","33,08%"
# One year,"$4.633.896,75","28,00%"
# Two year,"$6.440.595,60","38,92%"
# CARGO TOTAL / MENSUAL,"$16.548.281,85","100,00%"
# ```
#
# ```
# ,,,,CHURN
# TOTALES,Values,%Porcentaje / Cargo Total,,,NO,YES,%,%nO,%YES
# Month-to-month,"$5.473.789,50","33,08%",,"$167.928,00","$3.378.679,25","$1.927.182,25","3,07%","61,72%","35,21%"
# One year,"$4.633.896,75","28,00%",,"$166.843,25","$3.792.062,30","$674.991,20","3,60%","81,83%","14,57%"
# Two year,"$6.440.595,60","38,92%",,"$157.341,90","$6.022.500,25","$260.753,45","2,44%","93,51%","4,05%"
# CARGO TOTAL / MENSUAL,"$16.548.281,85","100,00%","0,00%","$492.113,15","$13.193.241,80","$2.862.926,90","9,11%","237,07%","53,82%"
# ```
#
#
#
# ----------------------------´´-------------------------------------------------
#
# ´-------resumen---- analitico con churn-----´-
# -----´Tablas _ Cargo Total´------
#
# ```
# CARGO TOTAL / TOTAL,,,,,,,,,
# "$16.548.281,85",,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,CHURN
# TOTALES,Values,%Porcentaje / Cargo Total,,,NO,YES,%,%nO,%YES
# Month-to-month,"$5.473.789,50","33,08%",,"$167.928,00","$3.378.679,25","$1.927.182,25","3,07%","61,72%","35,21%"
# One year,"$4.633.896,75","28,00%",,"$166.843,25","$3.792.062,30","$674.991,20","3,60%","81,83%","14,57%"
# Two year,"$6.440.595,60","38,92%",,"$157.341,90","$6.022.500,25","$260.753,45","2,44%","93,51%","4,05%"
# CARGO TOTAL / MENSUAL,"$16.548.281,85","100,00%","0,00%","$492.113,15","$13.193.241,80","$2.862.926,90","9,11%","237,07%","53,82%"
# ```
#
# --------------------------------------´Cargo Total´---------------------------
# Observaciones:
# para el cargo total, tenemos la mayor facturacion (valor), por el contrato a dos años (6.440.595,60), representando el 38.92%, pero en condicion de retiros el contrato que mas retiros registra en los cargos totales, es el contrato mes a mes ($1.927.182,25), representando el 35.21%; mientras que el contrato a dos años, registra una cantidad de retiros que representan valor a ($260.753,45), representado en el 4.05%
#
# mientras que para los clientes que permanecieron, el contrato a dos años es el que mayor porcentaje y valor representa, en el cargo total con ($6.022.500,25), representando el 93,51%.
#
# Conclusion:
# En los cargos totales, el contrato a dos años, representa la mayor cantidad de facturacion y la mayor cantidad de clientes, ya que de los clientes que cancelaron sus contratos solo el 4.05% que habian contratado este tipo de contrato, cancelaron sus contratos, de los 1.743 clientes que eligieron este tipo de contrato, solo 48 clientes cancelaron.
#
# para el contrato mes a mes tenemos la gran mayoria de los clientes, para un registro de 4005 clientes y 1.655 clientes que cancelaron + 130 clientes, que no se han definido.
#
# por lo anterior podemos afirmar que el contrato mes a mes, marco tendencia, en el cargo total y en el retiro de los clientes.
#
# **Recomendaciones:**
# revisar el contrato mes a mes, para los clientes, que tienen uno o mas de un servicio contratado.
#
#
# -------------------------´Cuentas Diarias y Total contrato´------------------------------
#
# para las cuentas Diarias y Total contrato, la correspondencia es equivalente, con los cargos mensuales y el cargo total, la tendencia se conserva, lo unico que cambia son los valores, que en el caso de cuentas diarias, es un cargo dia a dia( cuentas_diarias = cargo_mensual /30 dias) mientras para total contrato es un cargo total anual (total_contrato= cargo_total * (cantidad_tiempo_contrato)).
#
#
# **cuentas_diarias**
# para las cuentas diarias el contrato:
# - Month-to-month,"$8.857,00","56,50%", el mas representativo.
#
# y de los retiros el contrato:
# - ```
# Month-to-month,"$8.857,00","56,50%",,"$280,53","$4.548,24","$4.028,24","3,17%","51,35%","45,48%" **con retiros de el 45,48% con cargos diarios que suman un total de ($4.028,24)**
# ```
#
# y de los clientes que permanecieron el contrato:
# - ```
# -Two year,"$3.517,38","22,44%",,"$83,85","$3.294,69","$138,84","2,38%","93,67%","3,95%" ** con clientes que no cancelaron el 93,67% con cargos diarios que suman un total de ($3.294,69)**
# ```
#
#
# -----------------------------------´Tabla cuentas_Diarias´-------------------------------------------
#
#
#
#
#
# ```
# CUENTAS_DIARIAS / TOTAL,,
# "$15.677,37",,
# ,,
# ,,
# ,,
# ,,
# ,,
# ,,
# ,,
# TOTALES,Values,%Porcentaje / Cuenta_Diaria_ Total
# Month-to-month,"$8.857,00","56,50%"
# One year,"$3.302,98","21,07%"
# Two year,"$3.517,38","22,44%"
# CUENTAS_DIARIAS / MENSUAL,"$15.677,37","100,00%"
# ```
#
#
#
# -------------------´cuentas_diarias /churn´----------------------
#
#
# ```
# ,,,,,,,,,
# CUENTAS_DIARIAS / TOTAL,,,,,,,,,
# "$15.677,37",,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,CHURN
# TOTALES,Values,%Porcentaje / Cuenta_Diaria_ Total,,,NO,YES,%,%nO,%YES
# Month-to-month,"$8.857,00","56,50%",,"$280,53","$4.548,24","$4.028,24","3,17%","51,35%","45,48%"
# One year,"$3.302,98","21,07%",,"$109,10","$2.723,27","$470,62","3,30%","82,45%","14,25%"
# Two year,"$3.517,38","22,44%",,"$83,85","$3.294,69","$138,84","2,38%","93,67%","3,95%"
# CUENTAS_DIARIAS / MENSUAL,"$15.677,37","100,00%","0,00%","$473,48","$10.566,19","$4.637,70","8,85%","227,47%","63,68%"
# ,,,,,,,,,
# ```
#
# -----------------------------------´Tabla Total_Contrato´-------------------------------------------
#
# **total_contrato**
# para el total_contrato,  el contrato:
# -```
# - Two year, con un **valor total (sum)"$154.574.294,40", y representa el "71,68%"**
# ```
# para el total_contrato, los clientes que se retiron, el contrato:
#
# ```
# - **Month-to-month**,"$5.473.789,50","2,54%",,"$167.928,00","$3.378.679,25",**valor total de "$1.927.182,25"**,"3,07%","61,72%",** y representa el "35,21%"**
# ```
#
# para el total_contrato, los clientes que no se retiron, el contrato:
#
# ```
# - **Two year**,"$154.574.294,40","71,68%",,"$3.776.205,60",** valor_total de = "$144.540.006,00"**,"$6.258.082,80","2,44%",** representa el "93,51%"**,"4,05%"
# ```
#
#
# -------------------------------------´´-----------------------------------------
#
# ```
# TOTAL_CONTRATO/ TOTAL,,
# "$215.654.844,90",,
# ,,
# ,,
# ,,
# ,,
# ,,
# ,,
# ,,
# TOTALES,Values,%Porcentaje / Cuenta_Diaria_ Total
# Month-to-month,"$5.473.789,50","2,54%"
# One year,"$55.606.761,00","25,79%"
# Two year,"$154.574.294,40","71,68%"
# Total_Contrato / MENSUAL,"$215.654.844,90","100,00%"
# ```
#
# -------------------´Tabla Total_Contrato /churn´----------------------
#
#
# ```
# TOTAL_CONTRATO/ TOTAL,,,,,,,,,
# "$215.654.844,90",,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,CHURN
# TOTALES,Values,%Porcentaje / Cuenta_Diaria_ Total,,,NO,YES,%,%nO,%YES
# Month-to-month,"$5.473.789,50","2,54%",,"$167.928,00","$3.378.679,25","$1.927.182,25","3,07%","61,72%","35,21%"
# One year,"$55.606.761,00","25,79%",,"$2.002.119,00","$45.504.747,60","$8.099.894,40","3,60%","81,83%","14,57%"
# Two year,"$154.574.294,40","71,68%",,"$3.776.205,60","$144.540.006,00","$6.258.082,80","2,44%","93,51%","4,05%"
# Total_Contrato / MENSUAL,"$215.654.844,90","100,00%","0,00%","$5.946.252,60","$193.423.432,85","$16.285.159,45","9,11%","237,07%","53,82%"
# ```
#
# ```
# Month-to-month,"$8.857,00","56,50%"
# ```

# %% [markdown]
# **TOTALES/ CARGO MENSUAL / CARGO TOTAL / CUENTAS DIARIAS / TOTAL CONTRATO**

# %%
summary_data = {'Metric': ['Sum Monthly Charges', 'Sum Total Charges', 'Sum Daily Accounts', 'total_contracto'],
                'Value': [df_sum_monthly, df_sum_total, df_sum_cuentas_diarias, df_sum_total_contrato]}
df_summary = pd.DataFrame(summary_data)
display(df_summary)
# Out:
#                 Metric         Value
# 0  Sum Monthly Charges  4.703209e+05
# 1    Sum Total Charges  1.654828e+07
# 2   Sum Daily Accounts  1.567736e+04
# 3      total_contracto  2.156548e+08
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df_summary)
# Out:
# https://docs.google.com/spreadsheets/d/1er0Fk-a73fpskZZIqMr0RvE8HK08cI7QuNjrHSl0mBY/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1er0Fk-a73fpskZZIqMr0RvE8HK08cI7QuNjrHSl0mBY/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# **Cargos _ Mensuales**

# %%
df_churn_telecomX_monthly_sum= df_telecom_X.groupby(['churn' , 'contract'])[['charges.monthly']].sum()
df_churn_telecomX_monthly_sum
# Out:
#                       charges.monthly
# churn contract
#       Month-to-month          8415.95
#       One year                3272.85
#       Two year                2515.55
# No    Month-to-month        136447.05
#       One year               81698.15
#       Two year               98840.55
# Yes   Month-to-month        120847.10
#       One year               14118.45
#       Two year                4165.30

# %% [markdown]
# **Cargos_Totales**

# %%
df_churn_telecomX_total_sum= df_telecom_X.groupby(['churn' , 'contract'])[['charges.total']].sum()
df_churn_telecomX_total_sum
# Out:
#                       charges.total
# churn contract
#       Month-to-month      167928.00
#       One year            166843.25
#       Two year            157341.90
# No    Month-to-month     3378679.25
#       One year           3792062.30
#       Two year           6022500.25
# Yes   Month-to-month     1927182.25
#       One year            674991.20
#       Two year            260753.45

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df_churn_telecomX_total_sum)
# Out:
# https://docs.google.com/spreadsheets/d/1EQM-pAMs5Z1ghzYvpKqTg8zG-FvKaVQ1WstJe_lFhkI/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1EQM-pAMs5Z1ghzYvpKqTg8zG-FvKaVQ1WstJe_lFhkI/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df_churn_telecomX_monthly_sum)
# Out:
# https://docs.google.com/spreadsheets/d/1c2uTFVwzFvbA_frU55YCQNsOIQfnuSQ_yU7d_VKtX4A/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1c2uTFVwzFvbA_frU55YCQNsOIQfnuSQ_yU7d_VKtX4A/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# **cuentas Diarias**

# %%
df_churn_telecomX_cuentas_diarias_sum= df_telecom_X.groupby(['churn' , 'contract'])[['cuentas_diarias']].sum()
df_churn_telecomX_cuentas_diarias_sum
# Out:
#                       cuentas_diarias
# churn contract
#       Month-to-month       280.531667
#       One year             109.095000
#       Two year              83.851667
# No    Month-to-month      4548.235000
#       One year            2723.271667
#       Two year            3294.685000
# Yes   Month-to-month      4028.236667
#       One year             470.615000
#       Two year             138.843333

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df_churn_telecomX_cuentas_diarias_sum)
# Out:
# https://docs.google.com/spreadsheets/d/1V8mKKag8MSxE3Kq52qfGVjbN8GIY3BQ20q4xdjTVTeA/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1V8mKKag8MSxE3Kq52qfGVjbN8GIY3BQ20q4xdjTVTeA/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# **Cargos_Totales**

# %%
df_churn_telecomX_total_sum= df_telecom_X.groupby(['churn' , 'contract'])[['total_contracto']].sum()
df_churn_telecomX_total_sum
# Out:
#                       total_contracto
# churn contract
#       Month-to-month     1.679280e+05
#       One year           2.002119e+06
#       Two year           3.776206e+06
# No    Month-to-month     3.378679e+06
#       One year           4.550475e+07
#       Two year           1.445400e+08
# Yes   Month-to-month     1.927182e+06
#       One year           8.099894e+06
#       Two year           6.258083e+06

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df_churn_telecomX_total_sum)
# Out:
# https://docs.google.com/spreadsheets/d/1hP13GZMKFQfWQYEQRakjI0jfZpfnu8LnfuPRN7pgWic/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1hP13GZMKFQfWQYEQRakjI0jfZpfnu8LnfuPRN7pgWic/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# **Metrica _ resumen**

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df_summary)
# Out:
# https://docs.google.com/spreadsheets/d/1P5x63JnIvvam7lhIxSdUUD6vs-GdJfGtTw_uNuN6Jb4/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1P5x63JnIvvam7lhIxSdUUD6vs-GdJfGtTw_uNuN6Jb4/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Conclusiones e Insights: Resume los principales hallazgos y cómo estos datos pueden ayudar a reducir la evasión.
#
#
#
# *   --------------------------------------------------------------------------------
# **Churn en los usuarios / cuantos se retiraron**
# *Churn y customer Id * vacio = 224 churn No = 5174 churn Yes = 1869 total de 7267 usuarios de la empresa telecom X
#
# analisis: de los 7267 registros (clientes) de la base de datos del archivo telecomX, 1869 se retiran (churn= Yes), 5174 no se retiran (churn= No) y 224 registros (clientes) no se ha definido si se retiron o no se retiron.
#
# La empresa telecomX de los 7267 clientes, no se retiraron el 71.2%, continuaron utilizando los servicios contratados de la compañia y se retiron el 25.7 %, no continuaron utilizando mas sus servicios, generando que de los 7267 usuarios, cancelaron la cuarta parte los servicios y un 3.1 % no se ha definido si se retiro y dejo de utilizar los servicios o continuo con los servicios contratados con la compañia Telecom X.
#
# --------------------------------------------------------------------------------
# *
# --------------------------------------------------------------------------------
# se puede observa unos datos muy cercanos y casi iguales entre los clientes que continuaron utilizando los servicios de telecomX, los que no y los que no se han definido, la cantidad tanto para hombres como para mujeres.
#
# tenemo:
#
# *   Continuaron Churn: **No**= Male=	2625 Female=	2549 para un **50.734 % / 49.265 %**
#
# *   NO continuaron Churn: **YES**=  Female=	939 Male=	930 para un **50.24 % / 49.76 %**
# *   NO se han definido:  Male=	120  Female=	104 para un **53.571 % / 46.428 %**
#
# valores sobre el total de churn no, churn yes y churn ''.
#
# segun los datos analizados y arrojados, que son muy cercanos su diferencia es poca solo en los casos que el churn no esta definido, podemos afirmar que el genero sea hombre o mujer no influye en la condicion de continuar o no continuar con los servicios contratados de la empresa telecomX. / tenemos en muchos casos un 50 / 49 % para mujer y hombre o viceversa en terminos son iguales y casos muy pequeños marcarian un diferencia, pero podemos estar hablando de un 50 /50, ** el GENERO no marco tendencia sobre el churn.**
# --------------------------------------------------------------------------------
# *
# --------------------------------------------------------------------------------
# Churn **en los usuarios / cuantos se retiraron / Analisis por Contrato/Genero** ****
# de los clientes que no se retiron el contrato que tanto hombre como mujeres continuaron fue el contrato contratado mes a mes; luego siguio el contrato a 2 años y por ultimo el contrato a 1 año.
#
# *de los clientes que se retiron *el contrato que tanto hombres como mujeres tuvo mayores retiros, fue el contrato mes a mes, luego siguio el contrato a 1 año y por ultimo el contrato a 2 años.
#
# El contrato con menos retiros es el contrato 2 dos años, contratados por mujeres. con una cantidad de 22 usuarios que se retiron. representa una proporsion en mujeres o hombres que se retiron de los servicios contratados por la empresa telecomX, del 1% al rededor del valor total de los usuarios que se retiron de los servicios de la empresa telecomX.
# --------------------------------------------------------------------------------
#
# *
# --------------------------------------------------------------------------------
# Churn **en los usuarios / cuantos se retiraron / Analisis por/Genero\metodo de pago** ****
# **El metodo de pago** mas utilizado para los clientes hombres y mujeres,que no se retiron y utilizan los servicios de telecom x es:
# hombres: mailed check. (con un 40.6%, sobre el total de usuarios que utilizan el metodo de pago)
# mujeres: bank transfer(automatic). (con un **41%, sobre el total de usuarios que utilizan el metodo de pago)
# aunque los otros metodos de pago, como Electronic check, Credit card, (automatic), son utilizados con la misma frecuencia que el mailed check y el bank transfer(automatic); pudiendo afirmar que los clientes que no se retiron, utilizan todos los 4 metodos de pago, con la misma frecuencia, segun sea su posiblidad.
#
# para los clientes, que se retiron, el metodo de pago mas utilizado es el:
# Electronic check. (con un **43.45%, sobre el total de usuarios que utilizan el metodo de pago)
# luego en menor frecuencia sigue el mailed check, bank transfer(automatic) y credit card (automatic).
#
# Recomendaciones, revisar por que los clientes que todavia se conservan (no )utilizando los servicios de telecomX, no se retiron, utilizan los 4 medios de pago con la misma frecuencia, como buscando alternativas de pago, cuando algun medio o muchos fallan y por que los clientes que se retiron el metodo de pago mas utilizado era electronic check, y los otros metodos, casi no eran utilizados.
#
# revisar que inconvenientes han tenido con estos metodos de pago, en el momento de hacer sus pagos, para determinar si, el metodo de pago pudo determinar la desicion del retiro de los clientes al utilizar los servicios de telecomX.
# --------------------------------------------------------------------------------
# *
# --------------------------------------------------------------------------------
# OBSERVACIONES se observa una descongestion para el metodo de pago ElectronicCheck,
#
# ya que los clientes de la compañia TelecomX; ya que se retiron, la gran mayoria tanto hombres como mujeres, los que utilizaban el metodo de pago electronicCheck siendo un total de * 1.071 usuarios ** que dejaron de utilizar este metodo de pago, por que se retiron de la compañia; Lo cual representa ** un total de 43.45% *, sobre el total de usuarios que seleccionaron este metodo, que representa un total 2445 usuarios, representando un *1.374 usuarios, que no se retiron y utilizan este metodo de pago, representando un total de ** 56.2% ** que lo siguen utilizando. quedando un 43.45% descongestionado, ya que era el metodo de pago con mas clientes que lo utilizaban.
#
# paymentmethod / total de usuarios que lo usan sobre el total de clientes (7267 registros_clientes) de la compañia telecomX
#
# Electronic check 2445 Mailed check 1665 Bank transfer (automatic) 1589 Credit card (automatic) 1568
#
# Permitiendo asi que, despues del analisis los metodos de pago por usuario queden de la siguiente manera: (analisis y modificacion al mas usado /ElectronicCheck)
#
# Electronic check ** 1374 ** Mailed check 1665 Bank transfer (automatic) 1589 Credit card (automatic) 1568
#
# Generando que los metodos de pago utilizados tengan en proporcion de uso, la misma cantidad de usuarios y no exista un metodo mas congestionado que otros.
# para los clientes que no se retiron:
#
# HOMBRES -/- uso metodos de pago / porcentaje calculado sobre total de usuarios que utiliza este metodo de pago.
#
# Electronic check 26,4% Mailed check 40.6% Bank transfer (automatic) 39.9% Credit card (automatic) 42.66%
#
# MUJERES -/- uso metodos de pago / porcentaje calculado sobre total de usuarios que utiliza este metodo de pago.
#
# Electronic check 26,5% Mailed check 37.72% Bank transfer (automatic) 41% Credit card (automatic) 39.60%
# --------------------------------------------------------------------------------
# *
# --------------------------------------------------------------------------------
# *
# --------------------------------------------------------------------------------
# *count internetservice Fiber optic 3198 DSL 2488 No 1581 *
# **RETIROS DE CLIENTES / SERVICIO DE INTERNET**
#
# de los 7267 clientes registrados, tenemos que los servicios de internet utilizados son:
#
# internetservice
# * Fiber optic 3198 clientes  **44.01%**
# * DSL 2488 clientes          **34.24%**
# * No 1581 clientes           **21.75**
# Total de 7267 clientes      =100%
#
# el genero no determina la eleccion de los servicios de internet, sino la continuidad en el servicio y la tendencia.
#
# * **los clientes que se retiron**, tanto hombres como mujeres, tenian el servicio de internet **FiberOptic** / contratado: 1.297 clientes, **el 17.85%**
#
# **Para los clientes que continuaron**, se observan dos servicios de internet como los mas seleccionados:
#
# ***los clientes que continuaron**, tanto hombres como mujeres, tenien el servicio de internet **DSL** / contratado: 1.962 clientes, **el 27%**
# ***los clientes que continuaron**, tanto hombres como mujeres, tenien el servicio de internet **FiberOptic** / contratado: 1.799 clientes,**el 24.75%****
#
# Para los clientes, **que se retiron**, las **mujeres** son las que tienen la mayor cantidad de servicios de **Fiber Optica contratados = 664 **, mientras los **hombres** son los que tenian la mayor cantidad de servicios **DSL = 240** contratados; para **aquellos que no tienen servicios de internet contratados**, las **cantidades son muy cercanas / similares 56/57**.
#
# Para los clientes, **que continuaron**, los **hombres** son los que tienen la mayor cantidad de servicios de internet contratados **DSL = 993**, **fiberOptic =910**, y **no tienen servicio de internet = 722.**
# --------------------------------------------------------------------------------
# *
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# *Churn en los usuarios / cuantos se retiraron / Analisis por/Genero\ Cargo mensual, total, cuentas diarias y total de contrato ****
# LOS CARGOS, PARA LOS 7267 CLIENTES, SEGUN SUS SERVICIOS CONTRATADOS Y TIPOS DE CONTRATOS, SUMAN: moneda / pesos colombianos
#
# Sum Monthly Charges,"$470.320,95"
# Sum Total Charges,"$16.548.281,85"
# Sum Daily Accounts,"$15.677,37"
# total_contracto,"$215.654.844,90"
# ,
# TOTALES,"$232.689.125,07"
# Para los cargos mensuales segun churn y contracto, tenemos:
#
# ´-------resumen---- analitico con churn-----´-
#
# charges.monthly
# ,,
# churn,contract,values
# ,Month-to-month,"$8.415,95"
# No,Month-to-month,"$136.447,05"
# Yes,Month-to-month,"$120.847,10"
# ,
# TOTALES, "$ 265710,1"
# charges.monthly,,,,,CARGO TOTAL / MENSUAL
# ,,,,,,,"$470.320,95"
# churn,contract,values,TOTAL,PORCENTAJE / Total Cargo Mensual / Month-to-month,PORCENTAJE / Total Cargo Mensual,,
# ,Month-to-month,"$8.415,95",,"3,17%","1,79%",,
# No,Month-to-month,"$136.447,05",,"51,35%","29,01%",,
# Yes,Month-to-month,"$120.847,10",,"45,48%","25,69%",,
# Cargo Mensual / contracto month_to_Month Conclusion: de los cargos mensuales, para los contratos mes a mes que representan _( 265710,1)el56.50 470.320,95), hubo un retiro (contratos cancelados); perdida de  120.847,10∗∗,representandounacancelaciondeestoscontratosdel∗∗45.48 136.447,05)_ de clientes que todavia tienen sus contratos vigentes con la compañia telecomX.
#
# Recomendacion: hacer enfasis y mayor analisis, en los contratos mes a mes de los cargos mensuales, ya que hay una perdida significativa en facturacion mensual, pues el 45.48% ( 120.847,10)deloscontratoscanceladosenloscargosmensuales,eranloscontratosmesames,querepresentanlamayorfacturaciondelcargomensual,dandounrepresentativototaldel∗∗56.50  265710,1)**
#
#
#
# -----´Tablas _ Cargo Mensual´------
# ,,,,,,,,,
# ,,,,CHURN
# TOTALES,Values,%Porcentaje / CARGO TOTAL MENSUAL,,,NO,YES,%,%nO,%YES
# Month-to-month,"$265.710,10","56,50%",,"$8.415,95","$136.447,05","$120.847,10","3,17%","51,35%","45,48%"
# One year,"$99.089,45","21,07%",,"$3.272,85","$81.698,15","$14.118,45","3,30%","82,45%","14,25%"
# Two year,"$105.521,40","22,44%",,"$2.515,55","$98.840,55","$4.165,30","2,38%","93,67%","3,95%"
# CARGO TOTAL / MENSUAL,"$470.320,95","100,00%","0,00%","$14.204,35","$316.985,75","$139.130,85","8,85%","227,47%","63,68%"
# ,,,,,,,,,
# ---------------------------´Cargos_Totales´-----------------------------------
#
# Para los cargos totales segun churn y contracto, tenemos:
#
# TOTALES,Values,%Porcentaje / Cargo Total
# Month-to-month,"$5.473.789,50","33,08%"
# One year,"$4.633.896,75","28,00%"
# Two year,"$6.440.595,60","38,92%"
# CARGO TOTAL / MENSUAL,"$16.548.281,85","100,00%"
# ,,,,CHURN
# TOTALES,Values,%Porcentaje / Cargo Total,,,NO,YES,%,%nO,%YES
# Month-to-month,"$5.473.789,50","33,08%",,"$167.928,00","$3.378.679,25","$1.927.182,25","3,07%","61,72%","35,21%"
# One year,"$4.633.896,75","28,00%",,"$166.843,25","$3.792.062,30","$674.991,20","3,60%","81,83%","14,57%"
# Two year,"$6.440.595,60","38,92%",,"$157.341,90","$6.022.500,25","$260.753,45","2,44%","93,51%","4,05%"
# CARGO TOTAL / MENSUAL,"$16.548.281,85","100,00%","0,00%","$492.113,15","$13.193.241,80","$2.862.926,90","9,11%","237,07%","53,82%"
# ----------------------------´´-------------------------------------------------
#
# ´-------resumen---- analitico con churn-----´- -----´Tablas _ Cargo Total´------
#
# CARGO TOTAL / TOTAL,,,,,,,,,
# "$16.548.281,85",,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,CHURN
# TOTALES,Values,%Porcentaje / Cargo Total,,,NO,YES,%,%nO,%YES
# Month-to-month,"$5.473.789,50","33,08%",,"$167.928,00","$3.378.679,25","$1.927.182,25","3,07%","61,72%","35,21%"
# One year,"$4.633.896,75","28,00%",,"$166.843,25","$3.792.062,30","$674.991,20","3,60%","81,83%","14,57%"
# Two year,"$6.440.595,60","38,92%",,"$157.341,90","$6.022.500,25","$260.753,45","2,44%","93,51%","4,05%"
# CARGO TOTAL / MENSUAL,"$16.548.281,85","100,00%","0,00%","$492.113,15","$13.193.241,80","$2.862.926,90","9,11%","237,07%","53,82%"
# --------------------------------------´Cargo Total´--------------------------- Observaciones: para el cargo total, tenemos la mayor facturacion (valor), por el contrato a dos años (6.440.595,60), representando el 38.92%, pero en condicion de retiros el contrato que mas retiros registra en los cargos totales, es el contrato mes a mes ( 1.927.182,25),representandoel35.21 260.753,45), representado en el 4.05%
#
# mientras que para los clientes que permanecieron, el contrato a dos años es el que mayor porcentaje y valor representa, en el cargo total con ($6.022.500,25), representando el 93,51%.
#
# Conclusion: En los cargos totales, el contrato a dos años, representa la mayor cantidad de facturacion y la mayor cantidad de clientes, ya que de los clientes que cancelaron sus contratos solo el 4.05% que habian contratado este tipo de contrato, cancelaron sus contratos, de los 1.743 clientes que eligieron este tipo de contrato, solo 48 clientes cancelaron.
#
# para el contrato mes a mes tenemos la gran mayoria de los clientes, para un registro de 4005 clientes y 1.655 clientes que cancelaron + 130 clientes, que no se han definido.
#
# por lo anterior podemos afirmar que el contrato mes a mes, marco tendencia, en el cargo total y en el retiro de los clientes.
#
# ----------------------------------------´´------------------------------------------------------------------´´----------------------------------------------------
#
# cuentas_diarias para las cuentas diarias el contrato:
#
# Month-to-month,"$8.857,00","56,50%", el mas representativo.
# y de los retiros el contrato:
#
# Month-to-month,"$8.857,00","56,50%",,"$280,53","$4.548,24","$4.028,24","3,17%","51,35%","45,48%" **con retiros de el 45,48% con cargos diarios que suman un total de ($4.028,24)**
# y de los clientes que permanecieron el contrato:
#
# ```
# Two year," 3.517,38","22,44 83,85"," 3.294,69"," 138,84","2,38%","93,67%","3,95%" ** con clientes que no cancelaron el 93,67% con cargos diarios que suman un total de ($3.294,69)**
#
# -----------------------------------´Tabla cuentas_Diarias´-------------------------------------------
#
# CUENTAS_DIARIAS / TOTAL,,
# "$15.677,37",,
# ,,
# ,,
# ,,
# ,,
# ,,
# ,,
# ,,
# TOTALES,Values,%Porcentaje / Cuenta_Diaria_ Total
# Month-to-month,"$8.857,00","56,50%"
# One year,"$3.302,98","21,07%"
# Two year,"$3.517,38","22,44%"
# CUENTAS_DIARIAS / MENSUAL,"$15.677,37","100,00%"
# -------------------´cuentas_diarias /churn´----------------------
#
# ,,,,,,,,,
# CUENTAS_DIARIAS / TOTAL,,,,,,,,,
# "$15.677,37",,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,CHURN
# TOTALES,Values,%Porcentaje / Cuenta_Diaria_ Total,,,NO,YES,%,%nO,%YES
# Month-to-month,"$8.857,00","56,50%",,"$280,53","$4.548,24","$4.028,24","3,17%","51,35%","45,48%"
# One year,"$3.302,98","21,07%",,"$109,10","$2.723,27","$470,62","3,30%","82,45%","14,25%"
# Two year,"$3.517,38","22,44%",,"$83,85","$3.294,69","$138,84","2,38%","93,67%","3,95%"
# CUENTAS_DIARIAS / MENSUAL,"$15.677,37","100,00%","0,00%","$473,48","$10.566,19","$4.637,70","8,85%","227,47%","63,68%"
# ,,,,,,,,,
# -----------------------------------´Tabla Total_Contrato´-------------------------------------------
#
# total_contrato para el total_contrato, el contrato: -```
#
# Two year, con un valor total (sum)"$154.574.294,40", y representa el "71,68%"
# para el total_contrato, los clientes que se retiron, el contrato:
# - **Month-to-month**,"$5.473.789,50","2,54%",,"$167.928,00","$3.378.679,25",**valor total de "$1.927.182,25"**,"3,07%","61,72%",** y representa el "35,21%"**
# para el total_contrato, los clientes que no se retiron, el contrato:
#
# - **Two year**,"$154.574.294,40","71,68%",,"$3.776.205,60",** valor_total de = "$144.540.006,00"**,"$6.258.082,80","2,44%",** representa el "93,51%"**,"4,05%"
# -------------------------------------´´-----------------------------------------
#
# TOTAL_CONTRATO/ TOTAL,,
# "$215.654.844,90",,
# ,,
# ,,
# ,,
# ,,
# ,,
# ,,
# ,,
# TOTALES,Values,%Porcentaje / Cuenta_Diaria_ Total
# Month-to-month,"$5.473.789,50","2,54%"
# One year,"$55.606.761,00","25,79%"
# Two year,"$154.574.294,40","71,68%"
# Total_Contrato / MENSUAL,"$215.654.844,90","100,00%"
# -------------------´Tabla Total_Contrato /churn´----------------------
#
# TOTAL_CONTRATO/ TOTAL,,,,,,,,,
# "$215.654.844,90",,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,,,,,,
# ,,,,CHURN
# TOTALES,Values,%Porcentaje / Cuenta_Diaria_ Total,,,NO,YES,%,%nO,%YES
# Month-to-month,"$5.473.789,50","2,54%",,"$167.928,00","$3.378.679,25","$1.927.182,25","3,07%","61,72%","35,21%"
# One year,"$55.606.761,00","25,79%",,"$2.002.119,00","$45.504.747,60","$8.099.894,40","3,60%","81,83%","14,57%"
# Two year,"$154.574.294,40","71,68%",,"$3.776.205,60","$144.540.006,00","$6.258.082,80","2,44%","93,51%","4,05%"
# Total_Contrato / MENSUAL,"$215.654.844,90","100,00%","0,00%","$5.946.252,60","$193.423.432,85","$16.285.159,45","9,11%","237,07%","53,82%"

# %% [markdown]
# #-**CONCLUSIONE**-
#
#
#  ** el genero no marco tendencia sobre el churn. PERO SI EL SERVICIO DE INTERNET **
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# **OBSERVACIONES** se observa una descongestion para el metodo de pago ElectronicCheck,
#
# ya que los clientes de la compañia TelecomX; ya que se retiron, la gran mayoria tanto hombres como mujeres, los que utilizaban el metodo de pago electronicCheck siendo un total de * 1.071 usuarios ** que dejaron de utilizar este metodo de pago, por que se retiron de la compañia; Lo cual representa ** un total de 43.45% *, sobre el total de usuarios que seleccionaron este metodo, que representa un total 2445 usuarios, representando un *1.374 usuarios, que no se retiron y utilizan este metodo de pago, representando un total de ** 56.2% ** que lo siguen utilizando. quedando un 43.45% descongestionado, ya que era el metodo de pago con mas clientes que lo utilizaban.
#
# paymentmethod / total de usuarios que lo usan sobre el total de clientes (7267 registros_clientes) de la compañia telecomX
#
# Electronic check 2445 Mailed check 1665 Bank transfer (automatic) 1589 Credit card (automatic) 1568
#
# Permitiendo asi que, despues del analisis los metodos de pago por usuario queden de la siguiente manera: (analisis y modificacion al mas usado /ElectronicCheck)
#
# Electronic check ** 1374 ** Mailed check 1665 Bank transfer (automatic) 1589 Credit card (automatic) 1568
#
# Generando que los metodos de pago utilizados tengan en proporcion de uso, la misma cantidad de usuarios y no exista un metodo mas congestionado que otros.
# para los clientes que no se retiron:
#
# HOMBRES -/- uso metodos de pago / porcentaje calculado sobre total de usuarios que utiliza este metodo de pago.
#
# Electronic check 26,4% Mailed check 40.6% Bank transfer (automatic) 39.9% Credit card (automatic) 42.66%
#
# MUJERES -/- uso metodos de pago / porcentaje calculado sobre total de usuarios que utiliza este metodo de pago.
#
# Electronic check 26,5% Mailed check 37.72% Bank transfer (automatic) 41% Credit card (automatic) 39.60%
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Generando que los metodos de pago utilizados tengan en proporcion de uso, la misma cantidad de usuarios y **no exista un metodo mas congestionado que otros.**
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# **OBSERVACIONES**
#
# la empresa TelecomX, tiene el % de clientes con servicio telefonico contratado y el % restante, con servicio telefonico no contratado, de esos 7267 clientes en total se observa lo siguiente:
#
# 1.699 clientes se han retirado y tenian servicio telefonico, representando el 23.38% y 170 clientes se retiron, pero no tenian servicio telefonico, representando el 2.34%.
#
# 4.662 clientes no se han retirado, continuan con el servicio contratado y tienen el servico de telefonia contratado, representado el 64.15%
#
# 512 clientes no se han retirado, pero no tienen el servicio telefonico, contratado, representando el 7.04%
#
# Segun las observaciones de estos datos, podemos afirmar que, la mayor cantidad de clientes que no cancelaron, tienen servicio telefonico, contratado. y la cantidad de hombres y mujeres que tienen servicio telefonico contratado y no se retiron es muy similar, para no igual de 32.53% a 31.62%.
#
# tambien se observa que la mayor cantidad de clientes que se retiraron, tienen servicio telefonico contratado, en una relacion de 23.38%; mientras que 2.34%, que son los clientes que se retiron y no tenian servicio telefonico contratado, siendo una de 170 clientes.
#
# Pudiendo afirmar que el genero, no determina la contratacion del servicio telefonico, pero la gran mayoria de clientes que se retiron tenian servicio telefonico contratado siendo 1699, que se retiron y tenian contratado servicio telefonico.
#
# Por lo anterior se puede afirmar que:_ tener servicio telefonico contratado, marca tendencia en los clientes que se retiran de la compañia, de una relacion de 23.38% a 2.34%, entres los clientes que se retiron.
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# **CONCLUSION** Por lo anterior se concluye, que el servicio de internet, esta marcando la pauta, en el retiro de los clientes, de la compañia, TelecomX. / COLOCAR ESPECIAL ATENCION EN LOS CLIENTES QUE TIENEN CONTRATADOS LOS SERVICIOS DSL /FIBER_OPTIC
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# --------------------------------------´Cargo Total´--------------------------- Observaciones: para el cargo total, tenemos la mayor facturacion (valor), por el contrato a dos años (6.440.595,60), representando el 38.92%, pero en condicion de retiros el contrato que mas retiros registra en los cargos totales, es el contrato mes a mes ( 1.927.182,25),representandoel35.21 260.753,45), representado en el 4.05%
#
# mientras que para los clientes que permanecieron, el contrato a dos años es el que mayor porcentaje y valor representa, en el cargo total con ($6.022.500,25), representando el 93,51%.

# %% [markdown]
# #-**RECOMENDACIONES**-
#
# **RECOMENDACIONES** se recomienda, definir este 3.1%, que representa 224 registros, para poder clasificarlos en el churn, poder generar las acciones necesarias para poder frenar la evacion. / se recomienda actualizar el archivo base de registro de telecomX, de sus usuarios y servicios contractados. Para una mejor clasificacion y Analisis.
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# **RECOMENDACION** recomendacion: revisar las clausulas y beneficios del contrato por un año, determinando y comprarando con los contrato mes a mes y el contrato por dos años. ademas revisar el contrato por dos años, para determinar que ventajas se pueden implementar en proporcion al servicio contratado sea en tarifa o beneficios, para poder mantener mas tiempo al usuario final en estos contratos contratados.
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# **Recomendaciones**, revisar por que los clientes que todavia se conservan (no )utilizando los servicios de telecomX, no se retiron, utilizan los 4 medios de pago con la misma frecuencia, como buscando alternativas de pago, cuando algun medio o muchos fallan y por que los clientes que se retiron el metodo de pago mas utilizado era electronic check, y los otros metodos, casi no eran utilizados.
#
# revisar que inconvenientes han tenido con estos metodos de pago, en el momento de hacer sus pagos, para determinar si, el metodo de pago pudo determinar la desicion del retiro de los clientes al utilizar los servicios de telecomX.
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# **RECOMENDACIONES:**
#
# Revisar el servicio telefonico, tarifa, precio, calidad y funcionalidad, para evitar que este servicio contratado, marque mas la pauta en el retiro de los clientes de la empresa TelecomX, y se convierta en una tendencia.
#
# count internetservice Fiber optic 3198 DSL 2488 No 1581 * *RETIROS DE CLIENTES / SERVICIO DE INTERNET**
#
# de los 7267 clientes registrados, tenemos que los servicios de internet utilizados son:
#
# internetservice
#
# Fiber optic 3198 clientes 44.01%
# DSL 2488 clientes 34.24%
# No 1581 clientes 21.75 Total de 7267 clientes =100%
# el genero no determina la eleccion de los servicios de internet, sino la continuidad en el servicio y la tendencia.
#
# los clientes que se retiron, tanto hombres como mujeres, tenian el servicio de internet FiberOptic / contratado: 1.297 clientes, el 17.85%
# Para los clientes que continuaron, se observan dos servicios de internet como los mas seleccionados:
#
# *los clientes que continuaron, tanto hombres como mujeres, tenien el servicio de internet DSL / contratado: 1.962 clientes, el 27% *los clientes que continuaron, tanto hombres como mujeres, tenien el servicio de internet FiberOptic / contratado: 1.799 clientes,el 24.75%**
#
# Para los clientes, que se retiron, las mujeres son las que tienen la mayor cantidad de servicios de Fiber Optica contratados = 664 *, mientras los *hombres son los que tenian la mayor cantidad de servicios DSL = 240 contratados; para aquellos que no tienen servicios de internet contratados, las cantidades son muy cercanas / similares 56/57.
#
# Para los clientes, que continuaron, los hombres son los que tienen la mayor cantidad de servicios de internet contratados DSL = 993, fiberOptic =910, y no tienen servicio de internet = 722.
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# **RECOMENDACIONES** revisar el servicio de FiberOptica, calidad, conectividad, tarifa, velocidad, ya que marca la tendencia en los clientes y sus servicios que fueron cancelados. / clientes que se retiraron.
#
# Tambien revisar el servicio DSL, pues es el servicio mas elegido, en los clientes que no se retiron, que continuaron con sus servicios.
#
# Revisar urgentemente estos dos servicios de internet, ya que la menor cantidad de clientes que se retiron, se registra, en aquellos clientes, que no tienen servicios de internet contratados.
#
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# **Recomendacion:** hacer enfasis y mayor analisis, en los contratos mes a mes de los cargos mensuales, ya que hay una perdida significativa en facturacion mensual, pues el 45.48% ( 120.847,10)deloscontratoscanceladosenloscargosmensuales,eranloscontratosmesames,querepresentanlamayorfacturaciondelcargomensual,dandounrepresentativototaldel∗∗56.50  265710,1)**
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Recomendaciones: revisar el contrato mes a mes, para los clientes, que tienen uno o mas de un servicio contratado.

# %% [markdown]
# # para saber mas: del tema Churn:
#
# ¿Qué implica el churn?
# Pérdida de ingresos:
# Un churn elevado significa que la empresa está perdiendo clientes, lo que a su vez afecta los ingresos recurrentes.
# Necesidad de adquisición de nuevos clientes:
# Para compensar la pérdida de clientes, la empresa debe invertir más recursos en adquirir nuevos clientes, lo que puede ser costoso.
# Impacto en la reputación:
# La pérdida de clientes puede dañar la reputación de la empresa y generar una percepción negativa en el mercado.
# Indicador de problemas:
# Un alto churn puede ser una señal de problemas con el producto, el servicio al cliente, la experiencia del cliente o la competencia.
# Tipos de churn:
# Churn voluntario: El cliente decide activamente dejar de utilizar el servicio.
# Churn involuntario: El cliente deja de utilizar el servicio por razones ajenas a su voluntad, como problemas técnicos o falta de pago.
# Causas comunes del churn:
# Servicio al cliente deficiente:
# Experiencias negativas con el servicio de atención al cliente pueden llevar a la frustración y la pérdida de clientes.
# Problemas con el producto/servicio:
# Insatisfacción con la calidad, funcionalidad o precio del producto/servicio.
# Competencia:
# Ofertas más atractivas de la competencia pueden atraer a los clientes.
# Falta de valor percibido:
# Los clientes pueden dejar de ver valor en el servicio o producto si no cumplen con sus expectativas.
# Falta de comunicación:
# La falta de comunicación con los clientes puede generar desinterés y abandono.
# ¿Cómo reducir el churn?
# Mejorar la experiencia del cliente:
# Brindar un excelente servicio al cliente, personalizar la experiencia y resolver problemas de manera eficiente.
# Invertir en programas de fidelización:
# Ofrecer recompensas, descuentos y beneficios exclusivos a los clientes leales.
# Analizar los datos de churn:
# Identificar patrones y razones por las que los clientes se van para abordar los problemas subyacentes.
# Comunicarse activamente con los clientes:
# Mantener una comunicación abierta y transparente para abordar inquietudes y construir relaciones sólidas.
# Segmentar a los clientes:
# Identificar a los clientes en riesgo de churn y adaptar las estrategias para retenerlos.
# En resumen, el churn es una métrica crítica que debe ser monitoreada y gestionada activamente para garantizar el éxito a largo plazo de cualquier negocio que dependa de la retención de clientes.

# %%
df_churn_telecomX_internet_data_anar3 = df_telecom_X.groupby(['churn','gender'])[['phone_service']].value_counts()
df_churn_telecomX_internet_data_anar3_percentage = df_churn_telecomX_internet_data_anar3 / df_churn_telecomX_internet_data_anar3.sum() * 100
df_churn_telecomX_internet_data_anar3_percentage
